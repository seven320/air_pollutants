# %% [markdown]
# <a href="https://colab.research.google.com/github/seven320/air_pollutants/blob/main/FP029_28_fold20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Env

# %%
# !nvidia-smi
# Out:
# Wed May 11 04:26:27 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os, sys
COLAB = "google.colab" in sys.modules

if COLAB:
    from google.colab import drive
    from google.colab import output
    drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
if COLAB:
    # !pip install transformers > /dev/null
    # !pip install einops > /dev/null
    # !pip install optuna > /dev/null
    # !pip install pyephem > /dev/null
    # !pip install timm > /dev/null
    # !pip install kaggle > /dev/null
    # !pip install kaggle_datasets > /dev/null
    # !pip install git+https://github.com/albumentations-team/albumentations
    # !pip install tensorflow-determinism
    # !pip install -q iterative-stratification
    # !pip install python-Levenshtein > /dev/null
    # !pip install geopy > /dev/null

    # for gpu
    # !git clone --recursive https://github.com/Microsoft/LightGBM
    # %cd /content/LightGBM/
    # !mkdir build
    # !cmake -DUSE_GPU=1 
    # !make -j$(nproc)
    # !sudo apt-get -y install python-pip

    # !sudo -H pip install setuptools pandas numpy scipy scikit-learn -U
    #pandasのエラーが出る場合は上記のコードからpandasを削除

    # !sudo -H pip install setuptools numpy scipy scikit-learn -U
    # %cd /content/LightGBM/python-package
    # !sudo python setup.py install --precompile

    output.clear()

# %%
import gc
import json
import math
import os
import random
import re
import time
import copy
import warnings
from requests import get
from contextlib import contextmanager
from typing import List, Optional, TypeVar, Type, Dict
import datetime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch
import torch.nn as nn
from pathlib import Path
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GroupKFold, train_test_split, KFold
from sklearn.preprocessing import RobustScaler, LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
# from einops.layers.torch import Rearrange, Reduce
# import timm
import Levenshtein
import ephem
from geopy.distance import geodesic

from tqdm.notebook import tqdm
from transformers import AdamW, get_cosine_schedule_with_warmup
from typing import Optional, Tuple
from xgboost import XGBRegressor
import lightgbm as lgb
import optuna

# %%
warnings.simplefilter('ignore')

# %%
if COLAB:    
    NOTEBOOK_NAME = get('http://172.28.0.2:9000/api/sessions').json()[0]['name']
    print(NOTEBOOK_NAME)
# Out:
# FP029-28-fold20

# %%
COMPE_NAME = "air_pollutants"
BASE_DIR = f"/content/drive/MyDrive/signate/{COMPE_NAME}"

# KAGGLE ONLY HAS 1, BUT OFFLINE, YOU CAN USE MORE
os.environ["CUDA_VISIBLE_DEVICES"]="0" #0,1,2,3 for four gpu

# %%
if COLAB:
    INPUT_DIR = Path(os.path.join(BASE_DIR ,f"input"))
    INPUT_DIR.mkdir(exist_ok=True, parents=True)

    SAVE_DIR = Path(os.path.join(BASE_DIR ,f"models/{NOTEBOOK_NAME}"))
    SAVE_DIR.mkdir(exist_ok=True, parents=True)

    OOF_DIR = Path(os.path.join(BASE_DIR, f"oof/{NOTEBOOK_NAME}"))
    OOF_DIR.mkdir(exist_ok=True, parents = True)

    SUB_DIR = Path(os.path.join(BASE_DIR, f"submission/{NOTEBOOK_NAME}"))
    SUB_DIR.mkdir(exist_ok=True, parents = True)

# %%
train_df = pd.read_csv(os.path.join(INPUT_DIR, "train.csv"))
test_df = pd.read_csv(os.path.join(INPUT_DIR, "test.csv"))
sample_df = pd.read_csv(os.path.join(INPUT_DIR, "submit_sample.csv"), names=["id", "predict"])

print(train_df.shape, test_df.shape, sample_df.shape)
# Out:
# (195941, 54) (53509, 53) (53509, 2)

# %% [markdown]
# ## add city population

# %%
population_df = pd.read_csv(os.path.join(INPUT_DIR, "city_population.csv"))
population_df["City"] = population_df["Name"]

# %%
# 同じ都市名かつ国名のものを削除する
population_df["CC"] = population_df["Country"] + population_df["City"]
population_df["CC"].value_counts()
for k, v in population_df["CC"].value_counts().items():
    # print(k, v)
    if v > 1:
        print(f"{k} の行を削除")
        population_df = population_df[population_df["CC"] != k]
# Out:
# ChinaSuzhou の行を削除

# %%
def df_to_country_dict(df: pd.DataFrame) -> Dict:
    country_city = {}

    for t_c in set(df["Country"].tolist()):
        country_city[t_c] = []

    for country, city in zip(df["Country"], df["City"]):
        country_city[country].append(city)

    for k, v in country_city.items():
        country_city[k] = set(v)

    return country_city

# %%
train_country_city = df_to_country_dict(pd.concat([train_df, test_df]))

p_country_city = df_to_country_dict(population_df)

# %%
def cal_leven(str1: str, str2: str) -> float:
    # レーベンシュタイン距離の取得
    lev_dist = Levenshtein.distance(str1, str2)
    # 標準化(長い方の文字列の長さで割る)
    divider = len(str1) if len(str1) > len(str2) else len(str2)
    lev_dist = lev_dist / divider
    # 指標を合わせる(0:完全不一致 → 1:完全一致)
    return 1 - lev_dist

# %%
city_pairs = {}

for t_k, t_values in train_country_city.items():
    for p_k, p_values in p_country_city.items():
        # countryが一致
        if t_k != p_k:
            continue
        for t_v in t_values:
            max_score = -1
            for p_v in p_values:
                score = cal_leven(t_v, p_v)
                if max_score < score:
                    pairs = [t_v, p_v]
                    max_score = score

            if max_score > 0.8:
                city_pairs[pairs[1]] = pairs[0]
print(f"pair cities:{len(city_pairs)}")
# Out:
# pair cities:177

# %%
a = population_df["City"]
for key, value in city_pairs.items():
    # print(key, value)
    a = copy.deepcopy(a.replace(key, value))

population_df["City"] = a

# %%
if not "Prev" in train_df.columns:
    train_df = train_df.merge(population_df[["rank", "City", "Country", "Population", "Prev", "Growth"]], on = ["City", "Country"], how="left")
    test_df = test_df.merge(population_df[["rank", "City", "Country",  "Population", "Prev", "Growth"]], on = ["City", "Country"], how="left")

assert len(test_df) == len(sample_df)

# %% [markdown]
# ## add target encode

# %%
if not "target_count" in train_df.columns:
    target_df = train_df[["Country", "pm25_mid"]].groupby("Country", as_index = 1).describe()

    target_df = target_df.rename(columns = {
        "count": "target_count",
        "mean": "target_mean",
        "std": "target_std",
        "25%": "target_25%",
        "50%": "target_50%",
        "75%": "target_75%",
        "max": "target_max"
    }).reset_index()
    train_df = train_df.merge(pd.concat([target_df["Country"], target_df["pm25_mid"]], axis = 1), on = "Country", how = "left")
    test_df = test_df.merge(pd.concat([target_df["Country"], target_df["pm25_mid"]], axis = 1), on = "Country", how = "left")

# %% [markdown]
# ### add days

# %% [markdown]
# ## 都市を近い順に入力(上位15)

# %%
use_city = 5

# %%
# 全ての都市を抽出
all_df = pd.concat([train_df, test_df])
lat_lons = all_df[["City", "lat", "lon"]].drop_duplicates()

# %%
 # 各都市ごとの距離を格納
 #
#  nearest_cities = {
#       City1 = {
            # City2: 500km
            # City3: 1000km
# }
# } 

nearest_cities = {}
for i in tqdm(range(len(lat_lons))):
    City1, lat1, lon1 = lat_lons.iloc[i]
    pos1 = np.array([lat1, lon1])
    
    nearest_city = {}
    for j in range(len(lat_lons)):
        if i == j:
            continue
        
        City2, lat2, lon2 = lat_lons.iloc[j]
        pos2 = np.array([lat2, lon2])
        
        dis = geodesic(pos1, pos2)
        
        nearest_city[City2] = dis

    nearest_cities[City1] = nearest_city
# Out:
#   0%|          | 0/302 [00:00<?, ?it/s]

# %%
target_en_bycities = train_df[["City","month", "pm25_mid"]].groupby(["City", "month"], as_index = 0).agg("mean").reset_index(drop=True)

# %%
nearest_sort_cities = []

for city1 in nearest_cities.keys():
    nearest_sort_city = dict(sorted(nearest_cities[city1].items(), key = lambda item: item[1])).keys()
    nearest_sort_cities.append([city1] + list(nearest_sort_city)[:use_city])

# %%
target_en_bycities_detail = train_df[["City","year", "month","day", "pm25_mid"]].groupby(["City", "year", "month", "day"], as_index = 0).agg("mean").reset_index(drop=True)

# %%
cities = pd.DataFrame(target_en_bycities_detail["City"].unique(), columns = ["City"])
year_month_day = target_en_bycities_detail.groupby(["year", "month", "day"], as_index=0).agg("mean")[["year", "month", "day"]]

city_year_month_day = pd.merge(cities, year_month_day, how = "cross")

# %%
target_en = pd.merge(city_year_month_day, target_en_bycities_detail, on = ["City", "year", "month", "day"], how = "left")
target_en_fillna = pd.merge(target_en, target_en_bycities, on = ["City", "month"], how = "left")
target_en_fillna["pm25_mid"] = target_en_fillna["pm25_mid_x"].combine_first(target_en_fillna["pm25_mid_y"])

# %%
# Config
NUM_FOLDS = 20

# %%
#############
## Utility ##
#############
@contextmanager
def timer(name: str):
    t0 = time.time()
    print(f"[{name}] start")
    yield
    print(f"[{name}] done - elapsed {time.time() - t0:.2f}s")

# %%
def seed_everything(seed):
    """
    Seeds basic parameters for reproductibility of results
    
    Arguments:
        seed {int} -- Number of the seed
    """
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def set_seed(seed):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(42)

# %%
train_df.head()
# Out:
#    id  year  month  day    Country       City       lat        lon  co_cnt  \
# 0   1  2019      1    1  Australia   Brisbane -27.46794  153.02809      38
# 1   2  2019      1    1  Australia     Darwin -12.46113  130.84185      47
# 2   3  2019      1    1  Australia  Melbourne -37.81400  144.96332      17
# 3   4  2019      1    1  Australia  Newcastle -32.92953  151.78010      63
# 4   5  2019      1    1  Australia      Perth -31.95224  115.86140      47
#
#    co_min  ...       Prev  Growth  target_count  target_mean  target_std  min  \
# 0   0.749  ...  2439467.0  0.0134        5656.0    37.362265   25.919644  0.0
# 1   2.594  ...        NaN     NaN        5656.0    37.362265   25.919644  0.0
# 2   1.190  ...  5061439.0  0.0176        5656.0    37.362265   25.919644  0.0
# 3   4.586  ...        NaN     NaN        5656.0    37.362265   25.919644  0.0
# 4   4.689  ...  2067333.0  0.0122        5656.0    37.362265   25.919644  0.0
#
#    target_25%  target_50%  target_75%  target_max
# 0      19.526     28.6445    52.50325     189.517
# 1      19.526     28.6445    52.50325     189.517
# 2      19.526     28.6445    52.50325     189.517
# 3      19.526     28.6445    52.50325     189.517
# 4      19.526     28.6445    52.50325     189.517
#
# [5 rows x 66 columns]

# %%
train_city = train_df["City"].unique().tolist()
test_city = test_df["City"].unique().tolist()

train_city_cnt = len(train_city)
test_city_cnt = len(test_city)

print(f"train city count: {train_city_cnt}")
print(f"test city count: {test_city_cnt}")

print(f"{len(set(train_city) & set(test_city))}")
# Out:
# train city count: 239
# test city count: 63
# 0

# %%
kf = GroupKFold(n_splits = NUM_FOLDS)

if not "kfold" in train_df.columns:
    folds = copy.deepcopy(train_df[["id"]])
    folds["kfold"] = -1

    for fold, (train_idx, valid_idx) in enumerate(kf.split(train_df, train_df["pm25_mid"], train_df["City"])):
        print(f"train_idx: {len(train_idx)}, valid_idx: {len(valid_idx)}")
        folds.loc[valid_idx, "kfold"] = fold

    train_df = train_df.merge(folds[["id", "kfold"]], on="id", how="left")
# Out:
# train_idx: 186092, valid_idx: 9849
# train_idx: 186170, valid_idx: 9771
# train_idx: 186176, valid_idx: 9765
# train_idx: 186097, valid_idx: 9844
# train_idx: 186144, valid_idx: 9797
# train_idx: 186174, valid_idx: 9767
# train_idx: 186147, valid_idx: 9794
# train_idx: 186147, valid_idx: 9794
# train_idx: 186097, valid_idx: 9844
# train_idx: 186152, valid_idx: 9789
# train_idx: 186163, valid_idx: 9778
# train_idx: 186140, valid_idx: 9801
# train_idx: 186129, valid_idx: 9812
# train_idx: 186146, valid_idx: 9795
# train_idx: 186144, valid_idx: 9797
# train_idx: 186166, valid_idx: 9775
# train_idx: 186133, valid_idx: 9808
# train_idx: 186140, valid_idx: 9801
# train_idx: 186147, valid_idx: 9794
# train_idx: 186175, valid_idx: 9766

# %% [markdown]
# # Train

# %%
import logging
from typing import List, Optional, TypeVar

import pandas as pd

class AbstractFeatureTransformer:
    def __init__(self):
        self.name = self.__class__.__name__

    def fit_transform(self, input_df: pd.DataFrame, y=None):
        self.fit(input_df, y)
        return self.transform(input_df)

    def fit(self, input_df: pd.DataFrame, y=None):
        pass

    def transform(self, input_df: pd.DataFrame) -> pd.DataFrame:
        raise NotImplementedError

Transformer = TypeVar("Transformer", bound=AbstractFeatureTransformer)

def extract_features(input_df: pd.DataFrame,
                     transformers: List[Transformer],
                     fit: bool = True,
                     logger: Optional[logging.Logger] = None):
    feature_dfs = []
    for transformer in transformers:
        # timerはブロックの実行時間を計測するユーティリティ
        with timer(f"Extract features with {transformer.name}", logger):
            if fit:
                feature_dfs.append(transformer.fit_transform(input_df))
            else:
                feature_dfs.append(transformer.transform(input_df))
    all_features = pd.concat(feature_dfs, axis=1)
    return all_features

# %%
class Numericals(AbstractFeatureTransformer):
    def transform(self, input_df: pd.DataFrame) -> pd.DataFrame:
        cols = [pd.api.types.is_numeric_dtype(dtype) for dtype in input_df.dtypes]
        return input_df.loc[:, cols]

class LabelEncoding(AbstractFeatureTransformer):
    def __init__(self, columns: List[str]):
        super().__init__()
        self.le_columns = columns
        self.encoders = {
            column: LabelEncoder()
            for column in self.le_columns
        }
        self.__is_fitted = False

    def fit(self, input_df: pd.DataFrame, y: Optional[np.ndarray] = None):
        """
        ラベルに変換する前に欠損値を埋める
        """
        for column in self.le_columns:
            self.encoders[column].fit(input_df[column].fillna(""))
        self.__is_fitted = True

    def transform(
        self, 
        input_df: pd.DataFrame, 
        y: Optional[np.ndarray] = None
    ) -> pd.DataFrame:
        assert self.__is_fitted, "You need to call `fit` first."
        encoded = {}
        for column in self.le_columns:
            encoded[column] = self.encoders[column].transform(
                input_df[column].fillna(""))
        return pd.DataFrame(encoded)

# %%
def preprocess_all(train_df:pd.DataFrame, test_df:pd.DataFrame)->pd.DataFrame:
    all_df = pd.concat([train_df, test_df])

    mids = ["co_mid", "o3_mid", "so2_mid", "no2_mid", "temperature_mid", "humidity_mid", "pressure_mid", "ws_mid", "dew_mid", 
            "co_max", "o3_max", "so2_max", "no2_max", "temperature_max", "humidity_max", "pressure_max", "ws_max", "dew_max"]
    cnt = 1
    for i in range(len(mids)):
        if f"scaled_{mids[i]}" in train_df.columns:
            break
        scaler = MinMaxScaler()
        scaler.fit(all_df[[mids[i]]])
        train_df[f"scaled_{mids[i]}"] = scaler.transform(train_df[[mids[i]]])
        test_df[f"scaled_{mids[i]}"] = scaler.transform(test_df[[mids[i]]])
        cnt += 1
    print("min max scaler")

    return train_df, test_df

# %%
def preprocess(df:pd.DataFrame)->pd.DataFrame:
    df_ = copy.deepcopy(df)
    # 年月/年月日を追加

    df_["year_month"] = df_["year"].astype("str") + df_["month"].astype("str")
    df_["year_month_day"] = df_["year"].astype("str") + df_["month"].astype("str") + df_["day"].astype("str")
    df_["month_day"] = df_["month"].astype("str") + df_["day"].astype("str")

    # 月日国/月日都市を追加
    df_["month_day_country"] = df_["month"].astype("str") + df_["day"].astype("str") + df_["Country"].astype("str") 
    df_["month_day_city"] =  df_["month"].astype("str") + df_["day"].astype("str") + df_["City"].astype("str") 

    # 経度をcosに変換
    cnt = 0

    if not "lon_cos" in df_.columns:
        df_["lon_cos"] = np.cos(np.radians((df_["lon"] + 180)))
        df_["lon_sin"] = np.sin(np.radians((df_["lon"] + 180)))
        df_["month_cos"] = np.cos(np.radians(df_["month"] / 12 * 360))
        df_["month_sin"] = np.sin(np.radians(df_["month"] / 12 * 360))
        print("add lon_cos, lon_sin, month_cos, month_sin")
        cnt += 4

    # 四則演算

    # 南半球を北半球のmonthに変更
    if not "month_world" in df_.columns:
        df_["month_world"] = df_["month"]
        df_.loc[df_["lat"] < 0, "month_world"] = df_["month"] + 6
        df_.loc[df_["month_world"] > 12, "month_world"] = df_["month"] - 6
        print("add month_world")
        cnt += 1
    # mid同士を4則
    columns = df_.columns
    mids = []
    for c in columns:
        if "_mid" in c and c != "pm25_mid":
            mids.append(c)

    # 曜日を追加
    def _cal_sun_time(lat:float, lon:float, year:float, month:float, day: float)->float:
        location = ephem.Observer()
        location.lat = str(lat)
        location.lon = str(lon)
        sun = ephem.Sun()

        location.date = datetime.date(year = int(year), month = int(month), day = int(day))
        sun_time_tmp1 = ephem.localtime(location.next_rising(sun)) - ephem.localtime(location.next_setting(sun))
        sun_time_tmp2 = ephem.localtime(location.next_setting(sun)) - ephem.localtime(location.next_rising(sun))

        sun_time = max(sun_time_tmp1.seconds, sun_time_tmp2.seconds)

        return sun_time
    if not "sun_time" in df_.columns:
        u_cols = ["lat", "lon", "year", "month", "day"]

        df_["sun_time"] = -1
        df_["week"] = -1

        mini_df = df_[u_cols]

        sun_time = np.zeros(len(df_))
        weeks = np.zeros(len(df_))
        for i in tqdm(range(len(mini_df))):
            lat, lon, year, month, day = mini_df.iloc[i]
            sun_time[i] = _cal_sun_time(lat, lon, year, month, day)

            # 曜日
            date = datetime.date(int(year), int(month), int(day))
            weeks[i] = date.weekday()

        df_["sun_time"] = sun_time
        df_["week"] = weeks

        print("add sun_time, weeks")
    cnt += 2

    mids = ["co_mid", "o3_mid", "so2_mid", "no2_mid", "temperature_mid", "humidity_mid", "pressure_mid", "ws_mid", "dew_mid"]
    for i in range(len(mids)):
        for j in range(i):
            mid0, mid1 = mids[i], mids[j]
            df_[f"{mid0}+{mid1}"] = df_[mid0] + df_[mid1]

            cnt += 1
    print("add mids + cal")
    scaled_mids = ["scaled_co_mid", "scaled_o3_mid", "scaled_so2_mid", "scaled_no2_mid"]
    for i in range(len(scaled_mids)):
        for j in range(i):
            mid0, mid1 = scaled_mids[i], scaled_mids[j]
            df_[f"{mid0}+{mid1}"] = df_[mid0] + df_[mid1]
            cnt += 1
            for k in range(j):
                mid2 = scaled_mids[k]
                df_[f"{mid0}+{mid1}+{mid2}"] = df_[mid0] + df_[mid1] + df_[mid2]
                cnt += 1
                for l in range(k):
                    mid3 = scaled_mids[l]
                    df_[f"{mid0}+{mid1}+{mid2}+{mid3}"] = df_[mid0] + df_[mid1] + df_[mid2] + df_[mid3]
                    cnt += 1
    print("add scaled mids")

    maxs = ["co_max", "o3_max", "so2_max", "no2_max", "temperature_max", "humidity_max", "pressure_max", "ws_max", "dew_max"]
    for i in range(len(maxs)):
        for j in range(i):
            max0, max1 = maxs[i], maxs[j]
            df_[f"{max0}+{max1}"] = df_[max0] + df_[max1]

    scaled_maxs = ["scaled_co_max", "scaled_o3_max", "scaled_so2_max", "scaled_no2_max"]
    for i in range(len(scaled_maxs)):
        for j in range(i):
            max0, max1 = scaled_maxs[i], scaled_maxs[j]
            df_[f"{max0}+{max1}"] = df_[max0] + df_[max1]
            cnt += 1
            for k in range(j):
                max2 = scaled_maxs[k]
                df_[f"{max0}+{max1}+{max2}"] = df_[max0] + df_[max1] + df_[max2]
                cnt += 1
                for l in range(k):
                    max3 = scaled_maxs[l]
                    df_[f"{max0}+{max1}+{max2}+{max3}"] = df_[max0] + df_[max1] + df_[max2] + df_[max3]
                    cnt += 1
    print("add scaled maxs")

    print(f"add {cnt} columns")

    return df_

# %%
# numericals = Numericals()
# 数字に関する変換
# train_df_num = numericals.transform(train_df)

# ラベルに関する変換
# labelencoding = LabelEncoding(columns = [])

# labelencoding.fit(train_df_num)
# train_df_labeled = labelencoding.transform(train_df_num)

# %%
class AbstractTreeModel:
    def __init__(self, prediction_type="regression"):
        self.model = None
        self.prediction_type = prediction_type

    def train(self,
              params: dict,
              X_train: pd.DataFrame,
              y_train: np.ndarray,
              X_val: pd.DataFrame,
              y_val: np.ndarray,
              train_weights: Optional[np.ndarray] = None,
              val_weights: Optional[np.ndarray] = None,
              train_params: Optional[dict] = None):
        if train_params is None:
            train_params = {}

        model = self._train(
            params,
            X_train, y_train,
            X_val, y_val,
            train_weights, val_weights,
            train_params)
        self.model = model
        return self

    def _train(self,
               params,
               X_train,
               y_train,
               X_val,
               y_val,
               train_weights,
               val_weights,
               train_params):
        raise NotImplementedError

    def predict(self, X: pd.DataFrame) -> np.ndarray:
        raise NotImplementedError

    @property
    def feature_names_(self):
        raise NotImplementedError

    @property
    def feature_importances_(self):
        raise NotImplementedError

    def _check_if_trained(self):
        assert self.model is not None, "You need to train the model first"

class LGBModel(AbstractTreeModel):
    def _train(self,
               params,
               X_train, y_train,
               X_val, y_val,
               train_weights, val_weights,
               train_params):
        trn_data = lgb.Dataset(X_train, y_train, weight=train_weights)
        val_data = lgb.Dataset(X_val, y_val, weight=val_weights)
        model = lgb.train(params=params,
                          train_set=trn_data,
                          valid_sets=[trn_data, val_data],
                          **train_params,)
                        #   verbose_eval=False)
        return model

    def predict(self, X: pd.DataFrame) -> np.ndarray:
        self._check_if_trained()
        return self.model.predict(X, num_iteration=self.model.best_iteration)

    @property
    def feature_names_(self):
        self._check_if_trained()
        return self.model.feature_name()

    @property
    def feature_importances_(self):
        self._check_if_trained()
        return self.model.feature_importance(importance_type="gain")

def get_tree_model(name: str) -> Type[AbstractTreeModel]:
    DEFINED_MODELS = {
        "lgb": LGBModel,
        # 実装していない
        # "xgb": XGBModel,
        # "cat": CatBoostModel
    }
    model = DEFINED_MODELS.get(name)
    if model is None:
        raise ValueError(
            """Invalid model name: {}.
            Pre-defined model names are as follows: {}""".format(
                name,
                ",".join(DEFINED_MODELS.keys())
            ))
    return model

# %%
def viz_feature_importances(feature_importances: pd.DataFrame)-> None:
    fi_gby = feature_importances.groupby("feature").agg({
        "importance": ["mean", "std"]
    }).sort_values(("importance", "mean"), ascending=0).index
    plt.figure(figsize=(30, 20))

    sns.barplot(x="importance", y="feature", data=feature_importances, order=fi_gby)

    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.show()
    # plt.savefig('lgbm_importances-01.png')

# %%
train_params = {
    "num_boost_round": 20000,
    "callbacks": [
                  lgb.early_stopping(stopping_rounds= 500, verbose=True),
                  lgb.log_evaluation(period = 500)
    ]
}

# %%
num_cols = [c for c in train_df.columns if train_df[c].dtype != np.object]
if "id" in num_cols:
    num_cols.remove("id")
if "kfold" in num_cols:
    num_cols.remove("kfold")
num_cols.remove("pm25_mid")

target_cols = "pm25_mid"

# %%
train_df.columns
# Out:
# Index(['id', 'year', 'month', 'day', 'Country', 'City', 'lat', 'lon', 'co_cnt',
#        'co_min', 'co_mid', 'co_max', 'co_var', 'o3_cnt', 'o3_min', 'o3_mid',
#        'o3_max', 'o3_var', 'so2_cnt', 'so2_min', 'so2_mid', 'so2_max',
#        'so2_var', 'no2_cnt', 'no2_min', 'no2_mid', 'no2_max', 'no2_var',
#        'temperature_cnt', 'temperature_min', 'temperature_mid',
#        'temperature_max', 'temperature_var', 'humidity_cnt', 'humidity_min',
#        'humidity_mid', 'humidity_max', 'humidity_var', 'pressure_cnt',
#        'pressure_min', 'pressure_mid', 'pressure_max', 'pressure_var',
#        'ws_cnt', 'ws_min', 'ws_mid', 'ws_max', 'ws_var', 'dew_cnt', 'dew_min',
#        'dew_mid', 'dew_max', 'dew_var', 'pm25_mid', 'rank', 'Population',
#        'Prev', 'Growth', 'target_count', 'target_mean', 'target_std', 'min',
#        'target_25%', 'target_50%', 'target_75%', 'target_max', 'kfold'],
#       dtype='object')

# %%
train_df, test_df = preprocess_all(train_df, test_df)

train_df_ = preprocess(train_df)
test_df_ = preprocess(test_df)
# Out:
# min max scaler
# add lon_cos, lon_sin, month_cos, month_sin
# add month_world
#   0%|          | 0/195941 [00:00<?, ?it/s]
# add sun_time, weeks
# add mids + cal
# add scaled mids
# add scaled maxs
# add 65 columns
# add lon_cos, lon_sin, month_cos, month_sin
# add month_world
#   0%|          | 0/53509 [00:00<?, ?it/s]
# add sun_time, weeks
# add mids + cal
# add scaled mids
# add scaled maxs
# add 65 columns

# %%
cat_cols = ["Country", "City", "year_month", "year_month_day", "month_day", "month_day_city", "month_day_country", "nearest_city"] 

num_cols = list(set(train_df_.columns) - set(cat_cols + ["pm25_mid", "kfold", "id", "year"])) + ["nearest_pm25_mid"]
use_cols = num_cols + cat_cols

# %%
train_df_.head(10)
# Out:
#    id  year  month  day    Country        City       lat        lon  co_cnt  \
# 0   1  2019      1    1  Australia    Brisbane -27.46794  153.02809      38
# 1   2  2019      1    1  Australia      Darwin -12.46113  130.84185      47
# 2   3  2019      1    1  Australia   Melbourne -37.81400  144.96332      17
# 3   4  2019      1    1  Australia   Newcastle -32.92953  151.78010      63
# 4   5  2019      1    1  Australia       Perth -31.95224  115.86140      47
# 5   6  2019      1    1  Australia  Wollongong -34.42400  150.89345     179
# 6   7  2019      1    1    Belgium   Antwerpen  51.22047    4.40026      93
# 7   8  2019      1    1    Belgium   Charleroi  50.41136    4.44448      11
# 8   9  2019      1    1    Belgium       Liège  50.63373    5.56749      12
# 9  10  2019      1    1     Brazil   São Paulo -23.54750  -46.63611     354
#
#    co_min  ...  scaled_so2_max+scaled_co_max  scaled_so2_max+scaled_o3_max  \
# 0   0.749  ...                      0.007066                      0.013632
# 1   2.594  ...                      0.041960                      0.056968
# 2   1.190  ...                      0.099704                      0.142168
# 3   4.586  ...                      0.057716                      0.104860
# 4   4.689  ...                      0.042144                      0.097144
# 5   4.554  ...                      0.056074                      0.132480
# 6   4.011  ...                      0.055416                      0.046528
# 7   0.096  ...                      0.001480                      0.045884
# 8   0.097  ...                      0.002400                      0.049650
# 9   1.048  ...                      0.024602                      0.119038
#
#    scaled_so2_max+scaled_o3_max+scaled_co_max  scaled_no2_max+scaled_co_max  \
# 0                                    0.018898                      0.009642
# 1                                    0.066624                      0.020478
# 2                                    0.146568                      0.028860
# 3                                    0.134464                      0.078046
# 4                                    0.119344                      0.087368
# 5                                    0.164118                      0.113938
# 6                                    0.072246                      0.078918
# 7                                    0.046078                      0.031764
# 8                                    0.049852                      0.036340
# 9                                    0.133952                      0.072426
#
#    scaled_no2_max+scaled_o3_max  scaled_no2_max+scaled_o3_max+scaled_co_max  \
# 0                      0.016208                                    0.021474
# 1                      0.035486                                    0.045142
# 2                      0.071324                                    0.075724
# 3                      0.125190                                    0.154794
# 4                      0.142368                                    0.164568
# 5                      0.190344                                    0.221982
# 6                      0.070030                                    0.095748
# 7                      0.076168                                    0.076362
# 8                      0.083590                                    0.083792
# 9                      0.166862                                    0.181776
#
#    scaled_no2_max+scaled_so2_max  scaled_no2_max+scaled_so2_max+scaled_co_max  \
# 0                       0.006176                                     0.011442
# 1                       0.043126                                     0.052782
# 2                       0.119764                                     0.124164
# 3                       0.076554                                     0.106158
# 4                       0.085112                                     0.107312
# 5                       0.106736                                     0.138374
# 6                       0.082898                                     0.108616
# 7                       0.032856                                     0.033050
# 8                       0.038336                                     0.038538
# 9                       0.067200                                     0.082114
#
#    scaled_no2_max+scaled_so2_max+scaled_o3_max  \
# 0                                     0.018008
# 1                                     0.067790
# 2                                     0.166628
# 3                                     0.153302
# 4                                     0.162312
# 5                                     0.214780
# 6                                     0.099728
# 7                                     0.077454
# 8                                     0.085788
# 9                                     0.176550
#
#    scaled_no2_max+scaled_so2_max+scaled_o3_max+scaled_co_max
# 0                                           0.023274
# 1                                           0.077446
# 2                                           0.171028
# 3                                           0.182906
# 4                                           0.184512
# 5                                           0.246418
# 6                                           0.125446
# 7                                           0.077648
# 8                                           0.085990
# 9                                           0.191464
#
# [10 rows x 191 columns]

# %%
params= {
        'boosting': 'gbdt',
        'objective': 'rmse',
        'metric': 'rmse',
        'learning_rate': 0.01,
        "max_depth": 16,
        "num_leaves": 64,
        'subsample': 0.7,
        'subsample_freq': 1,
        "min_data_in_leaf":30, 
        "device": "gpu",  
        "seed":2022,
}

# %%
models = []

oof_df = train_df_[["id"]]
oof_df["oof"] = -1

from lightgbm import early_stopping
from lightgbm import log_evaluation

for i in range(NUM_FOLDS):
    model = get_tree_model("lgb")()
    train_data = train_df_[train_df_["kfold"] != i].reset_index(drop = True)
    valid_data = train_df_[train_df_["kfold"] == i].reset_index(drop = True)
    print("-" * 5 + f"FOLD {i + 1}/{NUM_FOLDS}" + "-"*5)
    print(f"train_data nums: {len(train_data)}, valid_data nums: {len(valid_data)}")

    # fold内での最近傍を探す
    train_data = train_df_[train_df_["kfold"] != i].reset_index(drop = True)
    print(len(train_data["City"].unique()))

    # 同じfoldの中で最近傍な都市があった場合はその年のtarget_encodingを実施
    # nearest_city_fold_df = copy.deepcopy(nearest_city_df)
    fold_cities = train_data["City"].unique()

    fold_nearest_cities = []
    for (base_c, city1, city2, city3, city4, city5) in nearest_sort_cities:
        if city1 in fold_cities:
            nearest_city = city1
        elif city2 in fold_cities:
            nearest_city = city2
        elif city3 in fold_cities:
            nearest_city = city3
        elif city4 in fold_cities:
            nearest_city = city4
        elif city5 in fold_cities:
            nearest_city = city5
        fold_nearest_cities.append([base_c, nearest_city])
    fold_nearest_cities_df = pd.DataFrame(fold_nearest_cities, columns = ["City", "nearest_city"])

    target_en_fillna_ = target_en_fillna.rename(columns = {"City": "nearest_city", "pm25_mid": "nearest_pm25_mid"})
    fold_nearest_city_target_en = fold_nearest_cities_df.merge(target_en_fillna_, how = "left", on= "nearest_city")

    train_data = train_data.merge(fold_nearest_city_target_en, how = "left", on = ["City", "year", "month", "day"])
    valid_data = valid_data.merge(fold_nearest_city_target_en, how = "left", on = ["City", "year", "month", "day"])

# test
    if i == 0:
        test_nearest_cities = []
        for (base_c, city1, city2, city3, city4, city5) in nearest_sort_cities:
            nearest_city = city1
            test_nearest_cities.append([base_c, nearest_city])
        test_nearest_cities_df = pd.DataFrame(test_nearest_cities, columns = ["City", "nearest_city"])

        test_nearest_city_target_en = test_nearest_cities_df.merge(target_en_fillna_, how="left", on = "nearest_city")
        test_df_ = test_df_.merge(test_nearest_city_target_en, how="left", on=["City", "year", "month", "day"])
        test_df__ = copy.deepcopy(test_df_)

    for c in cat_cols:
        le = LabelEncoder()
        le.fit(pd.concat([train_data, valid_data, test_df_])[c])
        train_data[c] = le.transform(train_data[c])
        valid_data[c] = le.transform(valid_data[c])
        if i == 0:
            test_df__[c] = le.transform(test_df_[c])

    model.train(
        params,
        train_params = train_params,
        X_train = train_data[use_cols],
        y_train = train_data[target_cols],
        X_val = valid_data[use_cols],
        y_val = valid_data[target_cols],
    )
    models.append(model)

    feature_importance = pd.DataFrame()
    feature_importance["feature"] = model.feature_names_
    feature_importance["importance"] = model.feature_importances_
    feature_importance["fold"] = i

    oof = model.predict(
        valid_data[use_cols]
    )
    oof_df.loc[train_df["kfold"] == i, "oof"] = oof

train_oof = train_df.merge(oof_df[["id", "oof"]], on = "id", how = "left")
# Out:
# -----FOLD 1/20-----
# train_data nums: 186092, valid_data nums: 9849
# 228
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43706
# [LightGBM] [Info] Number of data points in the train set: 186092, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.07 MB) transferred to GPU in 0.022741 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.915934
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.665	valid_1's rmse: 24.8286
# [1000]	training's rmse: 18.4158	valid_1's rmse: 24.5669
# [1500]	training's rmse: 17.6348	valid_1's rmse: 24.4724
# [2000]	training's rmse: 17.0215	valid_1's rmse: 24.3662
# [2500]	training's rmse: 16.4939	valid_1's rmse: 24.3
# [3000]	training's rmse: 16.0226	valid_1's rmse: 24.2717
# [3500]	training's rmse: 15.5879	valid_1's rmse: 24.2145
# [4000]	training's rmse: 15.1905	valid_1's rmse: 24.1849
# [4500]	training's rmse: 14.8172	valid_1's rmse: 24.1598
# [5000]	training's rmse: 14.464	valid_1's rmse: 24.1619
# Early stopping, best iteration is:
# [4619]	training's rmse: 14.7289	valid_1's rmse: 24.1559
# -----FOLD 2/20-----
# train_data nums: 186170, valid_data nums: 9771
# 228
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43723
# [LightGBM] [Info] Number of data points in the train set: 186170, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.09 MB) transferred to GPU in 0.022566 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.248513
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.6724	valid_1's rmse: 22.5069
# [1000]	training's rmse: 18.4206	valid_1's rmse: 22.0189
# [1500]	training's rmse: 17.6437	valid_1's rmse: 21.8628
# [2000]	training's rmse: 17.0295	valid_1's rmse: 21.7804
# [2500]	training's rmse: 16.496	valid_1's rmse: 21.7429
# [3000]	training's rmse: 16.0223	valid_1's rmse: 21.7194
# [3500]	training's rmse: 15.586	valid_1's rmse: 21.6647
# [4000]	training's rmse: 15.1883	valid_1's rmse: 21.6324
# [4500]	training's rmse: 14.8124	valid_1's rmse: 21.6134
# [5000]	training's rmse: 14.4638	valid_1's rmse: 21.6152
# Early stopping, best iteration is:
# [4558]	training's rmse: 14.7708	valid_1's rmse: 21.6099
# -----FOLD 3/20-----
# train_data nums: 186176, valid_data nums: 9765
# 226
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43713
# [LightGBM] [Info] Number of data points in the train set: 186176, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.09 MB) transferred to GPU in 0.022078 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.499167
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.7052	valid_1's rmse: 20.7591
# [1000]	training's rmse: 18.4554	valid_1's rmse: 20.4919
# [1500]	training's rmse: 17.6738	valid_1's rmse: 20.3904
# [2000]	training's rmse: 17.058	valid_1's rmse: 20.3571
# [2500]	training's rmse: 16.5287	valid_1's rmse: 20.3307
# [3000]	training's rmse: 16.0549	valid_1's rmse: 20.314
# [3500]	training's rmse: 15.6243	valid_1's rmse: 20.3048
# [4000]	training's rmse: 15.2242	valid_1's rmse: 20.3027
# Early stopping, best iteration is:
# [3813]	training's rmse: 15.3708	valid_1's rmse: 20.2929
# -----FOLD 4/20-----
# train_data nums: 186097, valid_data nums: 9844
# 228
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43699
# [LightGBM] [Info] Number of data points in the train set: 186097, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.08 MB) transferred to GPU in 0.022010 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.440833
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.6833	valid_1's rmse: 21.5864
# [1000]	training's rmse: 18.4236	valid_1's rmse: 21.1845
# [1500]	training's rmse: 17.6457	valid_1's rmse: 21.0252
# [2000]	training's rmse: 17.0337	valid_1's rmse: 20.942
# [2500]	training's rmse: 16.4978	valid_1's rmse: 20.89
# [3000]	training's rmse: 16.0242	valid_1's rmse: 20.8592
# [3500]	training's rmse: 15.5879	valid_1's rmse: 20.8423
# [4000]	training's rmse: 15.19	valid_1's rmse: 20.8281
# [4500]	training's rmse: 14.8172	valid_1's rmse: 20.8206
# [5000]	training's rmse: 14.4616	valid_1's rmse: 20.8021
# Early stopping, best iteration is:
# [4930]	training's rmse: 14.5114	valid_1's rmse: 20.801
# -----FOLD 5/20-----
# train_data nums: 186144, valid_data nums: 9797
# 226
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43714
# [LightGBM] [Info] Number of data points in the train set: 186144, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.08 MB) transferred to GPU in 0.022597 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.118859
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.698	valid_1's rmse: 20.902
# [1000]	training's rmse: 18.4473	valid_1's rmse: 20.5013
# [1500]	training's rmse: 17.6659	valid_1's rmse: 20.3648
# [2000]	training's rmse: 17.0536	valid_1's rmse: 20.2893
# [2500]	training's rmse: 16.5172	valid_1's rmse: 20.2303
# [3000]	training's rmse: 16.0456	valid_1's rmse: 20.1976
# [3500]	training's rmse: 15.6075	valid_1's rmse: 20.1544
# [4000]	training's rmse: 15.207	valid_1's rmse: 20.1308
# [4500]	training's rmse: 14.8283	valid_1's rmse: 20.1186
# [5000]	training's rmse: 14.4756	valid_1's rmse: 20.1
# [5500]	training's rmse: 14.1355	valid_1's rmse: 20.0892
# [6000]	training's rmse: 13.8195	valid_1's rmse: 20.0723
# [6500]	training's rmse: 13.5147	valid_1's rmse: 20.0649
# [7000]	training's rmse: 13.2198	valid_1's rmse: 20.0538
# [7500]	training's rmse: 12.9399	valid_1's rmse: 20.0523
# [8000]	training's rmse: 12.6734	valid_1's rmse: 20.0448
# [8500]	training's rmse: 12.4121	valid_1's rmse: 20.0395
# [9000]	training's rmse: 12.1616	valid_1's rmse: 20.0321
# [9500]	training's rmse: 11.9182	valid_1's rmse: 20.0228
# [10000]	training's rmse: 11.6844	valid_1's rmse: 20.025
# Early stopping, best iteration is:
# [9820]	training's rmse: 11.7669	valid_1's rmse: 20.0218
# -----FOLD 6/20-----
# train_data nums: 186174, valid_data nums: 9767
# 226
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43699
# [LightGBM] [Info] Number of data points in the train set: 186174, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.09 MB) transferred to GPU in 0.025319 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.132060
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.6325	valid_1's rmse: 23.4016
# [1000]	training's rmse: 18.3898	valid_1's rmse: 22.868
# [1500]	training's rmse: 17.6168	valid_1's rmse: 22.7004
# [2000]	training's rmse: 17.0074	valid_1's rmse: 22.6493
# [2500]	training's rmse: 16.484	valid_1's rmse: 22.6048
# [3000]	training's rmse: 16.0107	valid_1's rmse: 22.5882
# [3500]	training's rmse: 15.5781	valid_1's rmse: 22.557
# [4000]	training's rmse: 15.1787	valid_1's rmse: 22.5435
# [4500]	training's rmse: 14.8043	valid_1's rmse: 22.5247
# [5000]	training's rmse: 14.4474	valid_1's rmse: 22.5083
# [5500]	training's rmse: 14.1123	valid_1's rmse: 22.5127
# [6000]	training's rmse: 13.7964	valid_1's rmse: 22.495
# [6500]	training's rmse: 13.4913	valid_1's rmse: 22.4723
# [7000]	training's rmse: 13.1986	valid_1's rmse: 22.4543
# Early stopping, best iteration is:
# [6983]	training's rmse: 13.2088	valid_1's rmse: 22.4527
# -----FOLD 7/20-----
# train_data nums: 186147, valid_data nums: 9794
# 227
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43714
# [LightGBM] [Info] Number of data points in the train set: 186147, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.08 MB) transferred to GPU in 0.022743 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.017673
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.7033	valid_1's rmse: 21.4876
# [1000]	training's rmse: 18.4434	valid_1's rmse: 20.7818
# [1500]	training's rmse: 17.6589	valid_1's rmse: 20.5137
# [2000]	training's rmse: 17.045	valid_1's rmse: 20.3968
# [2500]	training's rmse: 16.5124	valid_1's rmse: 20.312
# [3000]	training's rmse: 16.0346	valid_1's rmse: 20.2382
# [3500]	training's rmse: 15.5983	valid_1's rmse: 20.169
# [4000]	training's rmse: 15.1934	valid_1's rmse: 20.1249
# [4500]	training's rmse: 14.822	valid_1's rmse: 20.0829
# [5000]	training's rmse: 14.4673	valid_1's rmse: 20.0627
# [5500]	training's rmse: 14.1333	valid_1's rmse: 20.0427
# [6000]	training's rmse: 13.8141	valid_1's rmse: 20.0245
# [6500]	training's rmse: 13.5058	valid_1's rmse: 20.014
# [7000]	training's rmse: 13.2151	valid_1's rmse: 20.0004
# [7500]	training's rmse: 12.9327	valid_1's rmse: 19.9821
# [8000]	training's rmse: 12.6623	valid_1's rmse: 19.9693
# [8500]	training's rmse: 12.406	valid_1's rmse: 19.9552
# [9000]	training's rmse: 12.1551	valid_1's rmse: 19.9492
# [9500]	training's rmse: 11.9139	valid_1's rmse: 19.9423
# [10000]	training's rmse: 11.679	valid_1's rmse: 19.9392
# [10500]	training's rmse: 11.451	valid_1's rmse: 19.9307
# [11000]	training's rmse: 11.2285	valid_1's rmse: 19.9291
# Early stopping, best iteration is:
# [10630]	training's rmse: 11.3921	valid_1's rmse: 19.9274
# -----FOLD 8/20-----
# train_data nums: 186147, valid_data nums: 9794
# 226
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43708
# [LightGBM] [Info] Number of data points in the train set: 186147, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.08 MB) transferred to GPU in 0.025135 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.861590
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.6397	valid_1's rmse: 27.4501
# [1000]	training's rmse: 18.3951	valid_1's rmse: 26.9761
# [1500]	training's rmse: 17.6183	valid_1's rmse: 26.8398
# [2000]	training's rmse: 17.0087	valid_1's rmse: 26.7553
# [2500]	training's rmse: 16.4778	valid_1's rmse: 26.6442
# [3000]	training's rmse: 16.0097	valid_1's rmse: 26.5544
# [3500]	training's rmse: 15.5757	valid_1's rmse: 26.5662
# Early stopping, best iteration is:
# [3129]	training's rmse: 15.8935	valid_1's rmse: 26.5252
# -----FOLD 9/20-----
# train_data nums: 186097, valid_data nums: 9844
# 228
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43727
# [LightGBM] [Info] Number of data points in the train set: 186097, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.08 MB) transferred to GPU in 0.022786 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.169640
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.6089	valid_1's rmse: 22.5537
# [1000]	training's rmse: 18.3581	valid_1's rmse: 22.1636
# [1500]	training's rmse: 17.5814	valid_1's rmse: 22.0105
# [2000]	training's rmse: 16.9732	valid_1's rmse: 21.9225
# [2500]	training's rmse: 16.4429	valid_1's rmse: 21.8632
# [3000]	training's rmse: 15.9723	valid_1's rmse: 21.829
# [3500]	training's rmse: 15.5438	valid_1's rmse: 21.7913
# [4000]	training's rmse: 15.1405	valid_1's rmse: 21.7664
# [4500]	training's rmse: 14.7665	valid_1's rmse: 21.7397
# [5000]	training's rmse: 14.4146	valid_1's rmse: 21.7254
# [5500]	training's rmse: 14.0829	valid_1's rmse: 21.7084
# [6000]	training's rmse: 13.7642	valid_1's rmse: 21.6956
# [6500]	training's rmse: 13.4594	valid_1's rmse: 21.6841
# [7000]	training's rmse: 13.1693	valid_1's rmse: 21.6712
# [7500]	training's rmse: 12.8896	valid_1's rmse: 21.664
# [8000]	training's rmse: 12.6227	valid_1's rmse: 21.6548
# [8500]	training's rmse: 12.3619	valid_1's rmse: 21.6484
# [9000]	training's rmse: 12.1105	valid_1's rmse: 21.6473
# Early stopping, best iteration is:
# [8816]	training's rmse: 12.2009	valid_1's rmse: 21.6449
# -----FOLD 10/20-----
# train_data nums: 186152, valid_data nums: 9789
# 228
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43712
# [LightGBM] [Info] Number of data points in the train set: 186152, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.09 MB) transferred to GPU in 0.026383 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.187443
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.724	valid_1's rmse: 22.026
# [1000]	training's rmse: 18.4736	valid_1's rmse: 21.6227
# [1500]	training's rmse: 17.6955	valid_1's rmse: 21.4592
# [2000]	training's rmse: 17.0829	valid_1's rmse: 21.3786
# [2500]	training's rmse: 16.5542	valid_1's rmse: 21.3403
# [3000]	training's rmse: 16.0825	valid_1's rmse: 21.317
# [3500]	training's rmse: 15.6505	valid_1's rmse: 21.3119
# Early stopping, best iteration is:
# [3213]	training's rmse: 15.8941	valid_1's rmse: 21.3016
# -----FOLD 11/20-----
# train_data nums: 186163, valid_data nums: 9778
# 226
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43720
# [LightGBM] [Info] Number of data points in the train set: 186163, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.09 MB) transferred to GPU in 0.022215 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.714952
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.7313	valid_1's rmse: 21.0003
# [1000]	training's rmse: 18.4696	valid_1's rmse: 20.6806
# [1500]	training's rmse: 17.6943	valid_1's rmse: 20.5711
# [2000]	training's rmse: 17.0801	valid_1's rmse: 20.5009
# [2500]	training's rmse: 16.5515	valid_1's rmse: 20.4553
# [3000]	training's rmse: 16.0754	valid_1's rmse: 20.4262
# [3500]	training's rmse: 15.6417	valid_1's rmse: 20.4026
# [4000]	training's rmse: 15.2427	valid_1's rmse: 20.3777
# [4500]	training's rmse: 14.8652	valid_1's rmse: 20.3599
# [5000]	training's rmse: 14.5138	valid_1's rmse: 20.3452
# [5500]	training's rmse: 14.1778	valid_1's rmse: 20.3328
# [6000]	training's rmse: 13.8599	valid_1's rmse: 20.3279
# [6500]	training's rmse: 13.5589	valid_1's rmse: 20.3194
# [7000]	training's rmse: 13.2687	valid_1's rmse: 20.309
# [7500]	training's rmse: 12.9919	valid_1's rmse: 20.3054
# [8000]	training's rmse: 12.7222	valid_1's rmse: 20.2991
# [8500]	training's rmse: 12.4617	valid_1's rmse: 20.291
# [9000]	training's rmse: 12.2066	valid_1's rmse: 20.2864
# [9500]	training's rmse: 11.966	valid_1's rmse: 20.2817
# [10000]	training's rmse: 11.7312	valid_1's rmse: 20.2768
# [10500]	training's rmse: 11.5043	valid_1's rmse: 20.2759
# Early stopping, best iteration is:
# [10459]	training's rmse: 11.5225	valid_1's rmse: 20.2741
# -----FOLD 12/20-----
# train_data nums: 186140, valid_data nums: 9801
# 228
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43732
# [LightGBM] [Info] Number of data points in the train set: 186140, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.08 MB) transferred to GPU in 0.025637 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.328148
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.7239	valid_1's rmse: 20.57
# [1000]	training's rmse: 18.4655	valid_1's rmse: 20.3153
# [1500]	training's rmse: 17.6856	valid_1's rmse: 20.2277
# [2000]	training's rmse: 17.0693	valid_1's rmse: 20.2017
# [2500]	training's rmse: 16.5407	valid_1's rmse: 20.1861
# [3000]	training's rmse: 16.0659	valid_1's rmse: 20.1697
# [3500]	training's rmse: 15.6296	valid_1's rmse: 20.1807
# Early stopping, best iteration is:
# [3225]	training's rmse: 15.8671	valid_1's rmse: 20.163
# -----FOLD 13/20-----
# train_data nums: 186129, valid_data nums: 9812
# 226
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43708
# [LightGBM] [Info] Number of data points in the train set: 186129, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.08 MB) transferred to GPU in 0.022456 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.052579
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.7097	valid_1's rmse: 21.1026
# [1000]	training's rmse: 18.4468	valid_1's rmse: 20.6926
# [1500]	training's rmse: 17.6644	valid_1's rmse: 20.5533
# [2000]	training's rmse: 17.0468	valid_1's rmse: 20.4917
# [2500]	training's rmse: 16.5174	valid_1's rmse: 20.4547
# [3000]	training's rmse: 16.0448	valid_1's rmse: 20.4132
# [3500]	training's rmse: 15.6156	valid_1's rmse: 20.3834
# [4000]	training's rmse: 15.2141	valid_1's rmse: 20.3624
# [4500]	training's rmse: 14.8398	valid_1's rmse: 20.3433
# [5000]	training's rmse: 14.487	valid_1's rmse: 20.3306
# [5500]	training's rmse: 14.1533	valid_1's rmse: 20.3262
# [6000]	training's rmse: 13.8332	valid_1's rmse: 20.3092
# [6500]	training's rmse: 13.5312	valid_1's rmse: 20.3035
# [7000]	training's rmse: 13.2406	valid_1's rmse: 20.2856
# [7500]	training's rmse: 12.9637	valid_1's rmse: 20.2805
# [8000]	training's rmse: 12.6916	valid_1's rmse: 20.2771
# [8500]	training's rmse: 12.4339	valid_1's rmse: 20.2704
# [9000]	training's rmse: 12.1847	valid_1's rmse: 20.2687
# [9500]	training's rmse: 11.9425	valid_1's rmse: 20.2665
# [10000]	training's rmse: 11.7087	valid_1's rmse: 20.2662
# [10500]	training's rmse: 11.4777	valid_1's rmse: 20.2586
# [11000]	training's rmse: 11.2562	valid_1's rmse: 20.2533
# [11500]	training's rmse: 11.0419	valid_1's rmse: 20.2504
# [12000]	training's rmse: 10.8344	valid_1's rmse: 20.2478
# [12500]	training's rmse: 10.6309	valid_1's rmse: 20.2479
# Early stopping, best iteration is:
# [12135]	training's rmse: 10.7784	valid_1's rmse: 20.2444
# -----FOLD 14/20-----
# train_data nums: 186146, valid_data nums: 9795
# 227
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43724
# [LightGBM] [Info] Number of data points in the train set: 186146, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.08 MB) transferred to GPU in 0.033991 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.509375
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.7502	valid_1's rmse: 20.7968
# [1000]	training's rmse: 18.487	valid_1's rmse: 20.3935
# [1500]	training's rmse: 17.7077	valid_1's rmse: 20.2775
# [2000]	training's rmse: 17.0912	valid_1's rmse: 20.1835
# [2500]	training's rmse: 16.561	valid_1's rmse: 20.1463
# [3000]	training's rmse: 16.0859	valid_1's rmse: 20.0959
# [3500]	training's rmse: 15.6484	valid_1's rmse: 20.079
# [4000]	training's rmse: 15.2468	valid_1's rmse: 20.0666
# [4500]	training's rmse: 14.8673	valid_1's rmse: 20.0598
# [5000]	training's rmse: 14.5102	valid_1's rmse: 20.0512
# [5500]	training's rmse: 14.1766	valid_1's rmse: 20.0363
# Early stopping, best iteration is:
# [5283]	training's rmse: 14.3184	valid_1's rmse: 20.0356
# -----FOLD 15/20-----
# train_data nums: 186144, valid_data nums: 9797
# 226
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43726
# [LightGBM] [Info] Number of data points in the train set: 186144, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.08 MB) transferred to GPU in 0.029563 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.058220
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.6582	valid_1's rmse: 22.4002
# [1000]	training's rmse: 18.4214	valid_1's rmse: 22.138
# [1500]	training's rmse: 17.6488	valid_1's rmse: 22.0576
# [2000]	training's rmse: 17.033	valid_1's rmse: 21.9952
# [2500]	training's rmse: 16.5077	valid_1's rmse: 21.9684
# [3000]	training's rmse: 16.0339	valid_1's rmse: 21.96
# [3500]	training's rmse: 15.6038	valid_1's rmse: 21.9408
# [4000]	training's rmse: 15.205	valid_1's rmse: 21.9263
# [4500]	training's rmse: 14.8297	valid_1's rmse: 21.9155
# [5000]	training's rmse: 14.4787	valid_1's rmse: 21.8951
# [5500]	training's rmse: 14.1417	valid_1's rmse: 21.878
# [6000]	training's rmse: 13.8137	valid_1's rmse: 21.8722
# [6500]	training's rmse: 13.5109	valid_1's rmse: 21.8637
# [7000]	training's rmse: 13.2147	valid_1's rmse: 21.8613
# [7500]	training's rmse: 12.9364	valid_1's rmse: 21.8517
# [8000]	training's rmse: 12.6666	valid_1's rmse: 21.8432
# [8500]	training's rmse: 12.4093	valid_1's rmse: 21.8315
# [9000]	training's rmse: 12.1572	valid_1's rmse: 21.8299
# [9500]	training's rmse: 11.9116	valid_1's rmse: 21.8229
# [10000]	training's rmse: 11.6768	valid_1's rmse: 21.8166
# [10500]	training's rmse: 11.4511	valid_1's rmse: 21.8148
# Early stopping, best iteration is:
# [10214]	training's rmse: 11.5783	valid_1's rmse: 21.8127
# -----FOLD 16/20-----
# train_data nums: 186166, valid_data nums: 9775
# 228
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43727
# [LightGBM] [Info] Number of data points in the train set: 186166, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.09 MB) transferred to GPU in 0.024885 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.238306
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.7514	valid_1's rmse: 21.5074
# [1000]	training's rmse: 18.4919	valid_1's rmse: 21.2973
# [1500]	training's rmse: 17.7107	valid_1's rmse: 21.2582
# [2000]	training's rmse: 17.0922	valid_1's rmse: 21.2177
# [2500]	training's rmse: 16.5573	valid_1's rmse: 21.1822
# [3000]	training's rmse: 16.0832	valid_1's rmse: 21.1888
# Early stopping, best iteration is:
# [2672]	training's rmse: 16.3892	valid_1's rmse: 21.1759
# -----FOLD 17/20-----
# train_data nums: 186133, valid_data nums: 9808
# 226
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43695
# [LightGBM] [Info] Number of data points in the train set: 186133, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.08 MB) transferred to GPU in 0.027535 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.167310
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.7062	valid_1's rmse: 21.4207
# [1000]	training's rmse: 18.4567	valid_1's rmse: 21.022
# [1500]	training's rmse: 17.6721	valid_1's rmse: 20.9077
# [2000]	training's rmse: 17.0548	valid_1's rmse: 20.8162
# [2500]	training's rmse: 16.5283	valid_1's rmse: 20.7795
# [3000]	training's rmse: 16.053	valid_1's rmse: 20.7604
# [3500]	training's rmse: 15.62	valid_1's rmse: 20.7421
# [4000]	training's rmse: 15.2132	valid_1's rmse: 20.7183
# [4500]	training's rmse: 14.8371	valid_1's rmse: 20.7055
# [5000]	training's rmse: 14.4786	valid_1's rmse: 20.6894
# [5500]	training's rmse: 14.1426	valid_1's rmse: 20.674
# [6000]	training's rmse: 13.8275	valid_1's rmse: 20.6634
# [6500]	training's rmse: 13.5218	valid_1's rmse: 20.6596
# [7000]	training's rmse: 13.228	valid_1's rmse: 20.658
# [7500]	training's rmse: 12.9503	valid_1's rmse: 20.6602
# Early stopping, best iteration is:
# [7287]	training's rmse: 13.0668	valid_1's rmse: 20.6528
# -----FOLD 18/20-----
# train_data nums: 186140, valid_data nums: 9801
# 228
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43726
# [LightGBM] [Info] Number of data points in the train set: 186140, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.08 MB) transferred to GPU in 0.021679 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.201698
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.7222	valid_1's rmse: 21.0548
# [1000]	training's rmse: 18.4645	valid_1's rmse: 20.7605
# [1500]	training's rmse: 17.6856	valid_1's rmse: 20.6801
# [2000]	training's rmse: 17.0711	valid_1's rmse: 20.6476
# [2500]	training's rmse: 16.5416	valid_1's rmse: 20.6347
# [3000]	training's rmse: 16.0668	valid_1's rmse: 20.6238
# [3500]	training's rmse: 15.6335	valid_1's rmse: 20.5932
# [4000]	training's rmse: 15.2313	valid_1's rmse: 20.578
# [4500]	training's rmse: 14.8504	valid_1's rmse: 20.5749
# [5000]	training's rmse: 14.4909	valid_1's rmse: 20.5593
# [5500]	training's rmse: 14.1527	valid_1's rmse: 20.5499
# [6000]	training's rmse: 13.8372	valid_1's rmse: 20.5413
# [6500]	training's rmse: 13.531	valid_1's rmse: 20.5272
# Early stopping, best iteration is:
# [6497]	training's rmse: 13.5328	valid_1's rmse: 20.5267
# -----FOLD 19/20-----
# train_data nums: 186147, valid_data nums: 9794
# 228
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43717
# [LightGBM] [Info] Number of data points in the train set: 186147, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.08 MB) transferred to GPU in 0.023877 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.018386
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.6513	valid_1's rmse: 22.5537
# [1000]	training's rmse: 18.3896	valid_1's rmse: 22.2089
# [1500]	training's rmse: 17.611	valid_1's rmse: 22.0886
# [2000]	training's rmse: 16.9975	valid_1's rmse: 22.0276
# [2500]	training's rmse: 16.4649	valid_1's rmse: 21.9774
# [3000]	training's rmse: 15.9941	valid_1's rmse: 21.9553
# [3500]	training's rmse: 15.5644	valid_1's rmse: 21.9412
# [4000]	training's rmse: 15.1632	valid_1's rmse: 21.9211
# [4500]	training's rmse: 14.7894	valid_1's rmse: 21.9037
# [5000]	training's rmse: 14.4364	valid_1's rmse: 21.9012
# [5500]	training's rmse: 14.1002	valid_1's rmse: 21.9051
# Early stopping, best iteration is:
# [5062]	training's rmse: 14.3936	valid_1's rmse: 21.9002
# -----FOLD 20/20-----
# train_data nums: 186175, valid_data nums: 9766
# 227
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 43705
# [LightGBM] [Info] Number of data points in the train set: 186175, number of used features: 189
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 189 dense feature groups (34.09 MB) transferred to GPU in 0.026122 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.121930
# Training until validation scores don't improve for 500 rounds
# [500]	training's rmse: 19.6917	valid_1's rmse: 24.3985
# [1000]	training's rmse: 18.4456	valid_1's rmse: 24.0829
# [1500]	training's rmse: 17.6663	valid_1's rmse: 23.959
# [2000]	training's rmse: 17.0487	valid_1's rmse: 23.8672
# [2500]	training's rmse: 16.5183	valid_1's rmse: 23.819
# [3000]	training's rmse: 16.0396	valid_1's rmse: 23.7823
# [3500]	training's rmse: 15.6053	valid_1's rmse: 23.7508
# [4000]	training's rmse: 15.2048	valid_1's rmse: 23.7371
# [4500]	training's rmse: 14.8253	valid_1's rmse: 23.7343
# [5000]	training's rmse: 14.4728	valid_1's rmse: 23.7151
# Early stopping, best iteration is:
# [4847]	training's rmse: 14.5769	valid_1's rmse: 23.7058

# %%
viz_feature_importances(feature_importance)

# %%
a = np.clip(train_oof["oof"], 0, 450)
oof_score = np.sqrt(mean_squared_error(train_oof["pm25_mid"], a))
oof_score = format(oof_score, ".4f")
print(f"oof score: {oof_score}")

# fold5  21.83
# fold10 21.5
# Out:
# oof score: 21.5239

# %%
train_oof[["id","pm25_mid", "kfold", "oof"]].to_csv(os.path.join(OOF_DIR, "oof.csv"), index= False)

# %%
test_df_
# Out:
#            id  year  month  day                 Country                 City  \
# 0      195942  2019      1    1               Australia             Adelaide
# 1      195943  2019      1    1               Australia               Sydney
# 2      195944  2019      1    1                 Belgium             Brussels
# 3      195945  2019      1    1  Bosnia and Herzegovina             Sarajevo
# 4      195946  2019      1    1                  Brazil  São José dos Campos
# ...       ...   ...    ...  ...                     ...                  ...
# 53504  249446  2021     12   31                  Turkey                Adana
# 53505  249447  2021     12   31                  Turkey                Bursa
# 53506  249448  2021     12   31                  Turkey              Trabzon
# 53507  249449  2021     12   31          United Kingdom               London
# 53508  249450  2021     12   31                 Vietnam             Haiphong
#
#             lat        lon  co_cnt  co_min  ...  scaled_no2_max+scaled_o3_max  \
# 0     -34.92866  138.59863     155   0.091  ...                      0.000210
# 1     -33.86785  151.20732      23   1.037  ...                      0.168338
# 2      50.85045    4.34878      28   0.096  ...                      0.087028
# 3      43.84864   18.35644     122   0.479  ...                      0.165226
# 4     -23.17944  -45.88694     158   6.198  ...                      0.152822
# ...         ...        ...     ...     ...  ...                           ...
# 53504  36.98615   35.32531      97   4.674  ...                      0.142348
# 53505  40.19559   29.06013     123  17.621  ...                      0.090196
# 53506  41.00500   39.72694     150   0.128  ...                      0.132594
# 53507  51.50853   -0.12574      21   0.057  ...                      0.068634
# 53508  20.86481  106.68345      47   0.060  ...                      0.079260
#
#        scaled_no2_max+scaled_o3_max+scaled_co_max  \
# 0                                        0.000600
# 1                                        0.175120
# 2                                        0.087236
# 3                                        0.198346
# 4                                        0.193476
# ...                                           ...
# 53504                                    0.171648
# 53505                                    0.133950
# 53506                                    0.174842
# 53507                                    0.072810
# 53508                                    0.079532
#
#        scaled_no2_max+scaled_so2_max  \
# 0                           0.000422
# 1                           0.060120
# 2                           0.033788
# 3                           0.183052
# 4                           0.126950
# ...                              ...
# 53504                       0.173122
# 53505                       0.179444
# 53506                       0.080600
# 53507                       0.021444
# 53508                       0.042458
#
#        scaled_no2_max+scaled_so2_max+scaled_co_max  \
# 0                                         0.000812
# 1                                         0.066902
# 2                                         0.033996
# 3                                         0.216172
# 4                                         0.167604
# ...                                            ...
# 53504                                     0.202422
# 53505                                     0.223198
# 53506                                     0.122848
# 53507                                     0.025620
# 53508                                     0.042730
#
#        scaled_no2_max+scaled_so2_max+scaled_o3_max  \
# 0                                         0.000422
# 1                                         0.179098
# 2                                         0.088280
# 3                                         0.286328
# 4                                         0.182738
# ...                                            ...
# 53504                                     0.230508
# 53505                                     0.209032
# 53506                                     0.148512
# 53507                                     0.070402
# 53508                                     0.091814
#
#        scaled_no2_max+scaled_so2_max+scaled_o3_max+scaled_co_max  \
# 0                                               0.000812
# 1                                               0.185880
# 2                                               0.088488
# 3                                               0.319448
# 4                                               0.223392
# ...                                                  ...
# 53504                                           0.259808
# 53505                                           0.252786
# 53506                                           0.190760
# 53507                                           0.074578
# 53508                                           0.092086
#
#           nearest_city  pm25_mid_x  pm25_mid_y  nearest_pm25_mid
# 0            Melbourne      25.918   43.757293         25.918000
# 1           Wollongong     110.224   54.181153        110.224000
# 2            Antwerpen      73.848   64.552842         73.848000
# 3               Zenica         NaN  137.160667        137.160667
# 4            São Paulo      67.872   59.879795         67.872000
# ...                ...         ...         ...               ...
# 53504          Antakya     143.083  112.648742        143.083000
# 53505         Istanbul      67.132   69.052822         67.132000
# 53506          Erzurum     152.706  127.241122        152.706000
# 53507  Southend-on-Sea         NaN   41.818333         41.818333
# 53508          Hạ Long      62.021   56.097736         62.021000
#
# [53509 rows x 193 columns]

# %% [markdown]
# # predict

# %%
sum_predict = None
for model in models:
    predict = model.predict(
        test_df__[use_cols],
    )
    if sum_predict is None:
        sum_predict = predict
    else:
        sum_predict += predict

mean_predict = sum_predict / len(models)

# %%
print(len(mean_predict))
print(sample_df.shape)
print(test_df.shape)
# Out:
# 53509
# (53509, 2)
# (53509, 83)

# %%
sample_df.loc[:,"predict"] = np.clip(mean_predict, 0, 450)

# %%
sample_df.head()
# Out:
#        id     predict
# 0  195942   26.999124
# 1  195943   37.355540
# 2  195944   25.868742
# 3  195945   58.430781
# 4  195946  132.131645

# %%
sample_df.to_csv(os.path.join(SUB_DIR, "submission.csv"), index= False, header = False)

# %%
plt.hist(sample_df["predict"], bins = 100)
plt.show()

# %% [markdown]
# # submit

# %%
# !pip install signate > /dev/null
# !mkdir /root/.signate
# !cp /content/drive/MyDrive/signate/signate.json /root/.signate/signate.json
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.9 which is incompatible.
# google-colab 1.0.0 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.

# %%
submission_file = os.path.join(SUB_DIR, "submission.csv")

# %%
comment = f"cv:{oof_score}_" + NOTEBOOK_NAME
comment
# Out:
# 'cv:21.5239_FP029-28-fold20'

# %% [markdown]
# # Submit

# %%
# !signate submit --competition-id=624 {submission_file} --note {comment}
# Out:
# You have successfully submitted your predictions.We will send you the submission result to your email address.

# %% [markdown]
# https://signate.jp/competitions/624/submissions

# %%
train_df[["City", "month", "pm25_mid"]].groupby(["City"]).describe()
# Out:
#               month                                                pm25_mid  \
#               count      mean       std  min  25%  50%   75%   max    count
# City
# Adapazarı     962.0  6.536383  3.356269  1.0  4.0  6.0   9.0  12.0    962.0
# Akita         978.0  6.527607  3.436774  1.0  4.0  6.0  10.0  12.0    978.0
# Albuquerque   917.0  6.679389  3.347707  1.0  4.0  7.0  10.0  12.0    917.0
# Andong       1011.0  6.608309  3.431492  1.0  4.0  7.0  10.0  12.0   1011.0
# Antakya       734.0  6.779292  3.200069  1.0  4.0  7.0  10.0  12.0    734.0
# ...             ...       ...       ...  ...  ...  ...   ...   ...      ...
# Zhuzhou      1059.0  6.610954  3.425374  1.0  4.0  7.0  10.0  12.0   1059.0
# Ürümqi       1033.0  6.642788  3.399611  1.0  4.0  7.0  10.0  12.0   1033.0
# İzmit        1013.0  6.553801  3.346923  1.0  4.0  7.0   9.0  12.0   1013.0
# Łódź          753.0  6.701195  3.238681  1.0  4.0  7.0   9.0  12.0    753.0
# Ōita         1057.0  6.621570  3.406298  1.0  4.0  7.0  10.0  12.0   1057.0
#
#                                                                          \
#                   mean        std     min       25%      50%        75%
# City
# Adapazarı    63.232831  35.395245   6.460  39.56125  55.6930   73.47475
# Akita        45.871133  25.458542   6.364  28.59525  40.5160   57.69725
# Albuquerque  42.865439  28.188976   7.736  22.31000  34.6630   57.03700
# Andong       59.396874  31.321281   6.600  37.84050  56.9850   69.45200
# Antakya      58.372569  41.630375   2.125  27.77575  53.3615   68.76650
# ...                ...        ...     ...       ...      ...        ...
# Zhuzhou      88.612365  43.927142  13.978  57.70200  75.5570  117.65500
# Ürümqi       81.598576  57.824517   9.867  47.92700  61.1770   92.37700
# İzmit        57.312069  29.037306   8.437  36.52600  54.2140   68.27100
# Łódź         61.209457  30.803510  11.894  40.49800  56.6420   73.41000
# Ōita         43.637044  20.845038   6.685  26.33400  40.2000   57.08000
#
#
#                  max
# City
# Adapazarı    181.469
# Akita        218.085
# Albuquerque  173.738
# Andong       191.630
# Antakya      286.452
# ...              ...
# Zhuzhou      236.485
# Ürümqi       406.464
# İzmit        176.600
# Łódź         216.704
# Ōita         135.558
#
# [239 rows x 16 columns]

# %%
train_df.columns
# Out:
# Index(['id', 'year', 'month', 'day', 'Country', 'City', 'lat', 'lon', 'co_cnt',
#        'co_min', 'co_mid', 'co_max', 'co_var', 'o3_cnt', 'o3_min', 'o3_mid',
#        'o3_max', 'o3_var', 'so2_cnt', 'so2_min', 'so2_mid', 'so2_max',
#        'so2_var', 'no2_cnt', 'no2_min', 'no2_mid', 'no2_max', 'no2_var',
#        'temperature_cnt', 'temperature_min', 'temperature_mid',
#        'temperature_max', 'temperature_var', 'humidity_cnt', 'humidity_min',
#        'humidity_mid', 'humidity_max', 'humidity_var', 'pressure_cnt',
#        'pressure_min', 'pressure_mid', 'pressure_max', 'pressure_var',
#        'ws_cnt', 'ws_min', 'ws_mid', 'ws_max', 'ws_var', 'dew_cnt', 'dew_min',
#        'dew_mid', 'dew_max', 'dew_var', 'pm25_mid', 'rank', 'Population',
#        'Prev', 'Growth', 'target_count', 'target_mean', 'target_std', 'min',
#        'target_25%', 'target_50%', 'target_75%', 'target_max', 'kfold',
#        'scaled_co_mid', 'scaled_o3_mid', 'scaled_so2_mid', 'scaled_no2_mid',
#        'scaled_temperature_mid', 'scaled_humidity_mid', 'scaled_pressure_mid',
#        'scaled_ws_mid', 'scaled_dew_mid', 'scaled_co_max', 'scaled_o3_max',
#        'scaled_so2_max', 'scaled_no2_max', 'scaled_temperature_max',
#        'scaled_humidity_max', 'scaled_pressure_max', 'scaled_ws_max',
#        'scaled_dew_max'],
#       dtype='object')

# %%
train_df[["co_cnt", "co_var", "co_min", "co_max", "co_mid"]]
# Out:
#         co_cnt  co_var  co_min  co_max  co_mid
# 0           38   0.850   0.749   2.633   2.590
# 1           47   1.208   2.594   4.828   3.181
# 2           17   0.248   1.190   2.200   1.197
# 3           63  24.186   4.586  14.802  11.044
# 4           47  10.011   4.689  11.100   8.681
# ...        ...     ...     ...     ...     ...
# 195936      12   0.090   0.694   1.301   0.995
# 195937      14   1.743   0.528   3.226   1.256
# 195938     171   5.293   1.975   6.639   6.627
# 195939      31   4.317   2.613   8.767   2.704
# 195940      26   0.003   0.069   0.184   0.120
#
# [195941 rows x 5 columns]

# %%
gen = np.random.default_rng()

rnd = gen.normal(size=38)

print(len(rnd), rnd.mean(), rnd.std())
# Out:
# 38 -0.022493964616329902 1.008050121779444

# %%
plt.hist(train_df[train_df["City"] == "Adapazarı"]["pm25_mid"], bins = 100)
# Out:
# (array([ 1.,  0.,  0.,  2.,  5.,  5., 10.,  9., 13., 17., 19., 22., 14.,
#         17., 22., 20., 25., 25., 16., 27., 19., 20., 23., 21., 27., 27.,
#         32., 38., 47., 41., 31., 34., 13., 22., 18.,  3., 13., 20., 11.,
#         15., 11.,  8.,  7.,  7.,  6.,  3.,  3.,  9.,  6.,  6.,  9.,  4.,
#          2.,  6.,  2.,  4.,  2.,  2.,  4.,  1.,  5.,  2.,  6.,  4.,  9.,
#          7.,  2.,  4.,  2.,  3.,  1.,  1.,  2.,  4.,  2.,  2.,  2.,  2.,
#          4.,  0.,  3.,  2.,  2.,  3.,  4.,  3.,  2.,  7.,  5.,  5.,  1.,
#          3.,  3.,  0.,  2.,  1.,  2.,  2.,  0.,  2.]),
#  array([  6.46   ,   8.21009,   9.96018,  11.71027,  13.46036,  15.21045,
#          16.96054,  18.71063,  20.46072,  22.21081,  23.9609 ,  25.71099,
#          27.46108,  29.21117,  30.96126,  32.71135,  34.46144,  36.21153,
#          37.96162,  39.71171,  41.4618 ,  43.21189,  44.96198,  46.71207,
#          48.46216,  50.21225,  51.96234,  53.71243,  55.46252,  57.21261,
#          58.9627 ,  60.71279,  62.46288,  64.21297,  65.96306,  67.71315,
#          69.46324,  71.21333,  72.96342,  74.71351,  76.4636 ,  78.21369,
#          79.96378,  81.71387,  83.46396,  85.21405,  86.96414,  88.71423,
#          90.46432,  92.21441,  93.9645 ,  95.71459,  97.46468,  99.21477,
#         100.96486, 102.71495, 104.46504, 106.21513, 107.96522, 109.71531,
#         111.4654 , 113.21549, 114.96558, 116.71567, 118.46576, 120.21585,
#         121.96594, 123.71603, 125.46612, 127.21621, 128.9663 , 130.71639,
#         132.46648, 134.21657, 135.96666, 137.71675, 139.46684, 141.21693,
#         142.96702, 144.71711, 146.4672 , 148.21729, 149.96738, 151.71747,
#         153.46756, 155.21765, 156.96774, 158.71783, 160.46792, 162.21801,
#         163.9681 , 165.71819, 167.46828, 169.21837, 170.96846, 172.71855,
#         174.46864, 176.21873, 177.96882, 179.71891, 181.469  ]),
#  <a list of 100 Patch objects>)
