# %% [markdown]
# <a href="https://colab.research.google.com/github/seven320/air_pollutants/blob/main/FP011_010_foldadd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Env

# %%
# !nvidia-smi
# Out:
# Tue Apr 19 15:09:11 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os, sys
COLAB = "google.colab" in sys.modules

if COLAB:
    from google.colab import drive
    from google.colab import output
    drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
if COLAB:
    # !pip install transformers > /dev/null
    # !pip install einops > /dev/null
    # !pip install optuna > /dev/null
    # !pip install pyephem > /dev/null
    # !pip install timm > /dev/null
    # !pip install kaggle > /dev/null
    # !pip install kaggle_datasets > /dev/null
    # !pip install git+https://github.com/albumentations-team/albumentations
    # !pip install tensorflow-determinism
    # !pip install -q iterative-stratification
    # !pip install python-Levenshtein > /dev/null

    # for gpu
    # !git clone --recursive https://github.com/Microsoft/LightGBM
    # %cd /content/LightGBM/
    # !mkdir build
    # !cmake -DUSE_GPU=1 
    # !make -j$(nproc)
    # !sudo apt-get -y install python-pip

    # !sudo -H pip install setuptools pandas numpy scipy scikit-learn -U
    #pandasのエラーが出る場合は上記のコードからpandasを削除

    # !sudo -H pip install setuptools numpy scipy scikit-learn -U
    # %cd /content/LightGBM/python-package
    # !sudo python setup.py install --precompile

    output.clear()

# %%
import gc
import json
import math
import os
import random
import re
import time
import copy
import warnings
from requests import get
from contextlib import contextmanager
from typing import List, Optional, TypeVar, Type, Dict
import datetime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch
import torch.nn as nn
from pathlib import Path
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GroupKFold, train_test_split, KFold
from sklearn.preprocessing import RobustScaler, LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
# from einops.layers.torch import Rearrange, Reduce
# import timm
import Levenshtein
import ephem

from tqdm.notebook import tqdm
from transformers import AdamW, get_cosine_schedule_with_warmup
from typing import Optional, Tuple
from xgboost import XGBRegressor
import lightgbm as lgb
import optuna

# %%
warnings.simplefilter('ignore')

# %%
if COLAB:    
    NOTEBOOK_NAME = get('http://172.28.0.2:9000/api/sessions').json()[0]['name']
    print(NOTEBOOK_NAME)
# Out:
# FP011-010-foldadd

# %%
COMPE_NAME = "air_pollutants"
BASE_DIR = f"/content/drive/MyDrive/signate/{COMPE_NAME}"

# KAGGLE ONLY HAS 1, BUT OFFLINE, YOU CAN USE MORE
os.environ["CUDA_VISIBLE_DEVICES"]="0" #0,1,2,3 for four gpu

# %%
if COLAB:
    INPUT_DIR = Path(os.path.join(BASE_DIR ,f"input"))
    INPUT_DIR.mkdir(exist_ok=True, parents=True)

    SAVE_DIR = Path(os.path.join(BASE_DIR ,f"models/{NOTEBOOK_NAME}"))
    SAVE_DIR.mkdir(exist_ok=True, parents=True)

    OOF_DIR = Path(os.path.join(BASE_DIR, f"oof/{NOTEBOOK_NAME}"))
    OOF_DIR.mkdir(exist_ok=True, parents = True)

    SUB_DIR = Path(os.path.join(BASE_DIR, f"submission/{NOTEBOOK_NAME}"))
    SUB_DIR.mkdir(exist_ok=True, parents = True)

# %%
train_df = pd.read_csv(os.path.join(INPUT_DIR, "train.csv"))
test_df = pd.read_csv(os.path.join(INPUT_DIR, "test.csv"))
sample_df = pd.read_csv(os.path.join(INPUT_DIR, "submit_sample.csv"), names=["id", "predict"])

print(train_df.shape, test_df.shape, sample_df.shape)
# Out:
# (195941, 54) (53509, 53) (53509, 2)

# %% [markdown]
# # add city population

# %%
population_df = pd.read_csv(os.path.join(INPUT_DIR, "city_population.csv"))
population_df["City"] = population_df["Name"]

# %%
# 同じ都市名かつ国名のものを削除する
population_df["CC"] = population_df["Country"] + population_df["City"]
population_df["CC"].value_counts()
for k, v in population_df["CC"].value_counts().items():
    # print(k, v)
    if v > 1:
        print(f"{k} の行を削除")
        population_df = population_df[population_df["CC"] != k]
# Out:
# ChinaSuzhou の行を削除

# %%
def df_to_country_dict(df: pd.DataFrame) -> Dict:
    country_city = {}

    for t_c in set(df["Country"].tolist()):
        country_city[t_c] = []

    for country, city in zip(df["Country"], df["City"]):
        country_city[country].append(city)

    for k, v in country_city.items():
        country_city[k] = set(v)

    return country_city

# %%
train_country_city = df_to_country_dict(pd.concat([train_df, test_df]))

p_country_city = df_to_country_dict(population_df)

# %%
def cal_leven(str1: str, str2: str) -> float:
    # レーベンシュタイン距離の取得
    lev_dist = Levenshtein.distance(str1, str2)
    # 標準化(長い方の文字列の長さで割る)
    divider = len(str1) if len(str1) > len(str2) else len(str2)
    lev_dist = lev_dist / divider
    # 指標を合わせる(0:完全不一致 → 1:完全一致)
    return 1 - lev_dist

# %%
city_pairs = {}

for t_k, t_values in train_country_city.items():
    for p_k, p_values in p_country_city.items():
        # countryが一致
        if t_k != p_k:
            continue
        for t_v in t_values:
            max_score = -1
            for p_v in p_values:
                score = cal_leven(t_v, p_v)
                if max_score < score:
                    pairs = [t_v, p_v]
                    max_score = score

            if max_score > 0.8:
                city_pairs[pairs[1]] = pairs[0]
print(f"pair cities:{len(city_pairs)}")
# Out:
# pair cities:177

# %%
a = population_df["City"]
for key, value in city_pairs.items():
    # print(key, value)
    a = copy.deepcopy(a.replace(key, value))

population_df["City"] = a

# %%
train_df
# Out:
#             id  year  month  day        Country          City       lat  \
# 0            1  2019      1    1      Australia      Brisbane -27.46794
# 1            2  2019      1    1      Australia        Darwin -12.46113
# 2            3  2019      1    1      Australia     Melbourne -37.81400
# 3            4  2019      1    1      Australia     Newcastle -32.92953
# 4            5  2019      1    1      Australia         Perth -31.95224
# ...        ...   ...    ...  ...            ...           ...       ...
# 195936  195937  2021     12   31  United States  Jacksonville  30.33218
# 195937  195938  2021     12   31  United States     Las Vegas  36.17497
# 195938  195939  2021     12   31  United States     Milwaukee  43.03890
# 195939  195940  2021     12   31        Vietnam         Hanoi  21.02450
# 195940  195941  2021     12   31        Vietnam       Hạ Long  20.95045
#
#               lon  co_cnt  co_min  ...  ws_min  ws_mid  ws_max  ws_var  \
# 0       153.02809      38   0.749  ...   0.241   1.088   3.101   1.983
# 1       130.84185      47   2.594  ...   0.828   3.473   7.396  10.411
# 2       144.96332      17   1.190  ...   0.000   2.107   8.089  15.719
# 3       151.78010      63   4.586  ...   0.284   0.503   3.592   2.485
# 4       115.86140      47   4.689  ...   0.500   0.755   3.396   1.937
# ...           ...     ...     ...  ...     ...     ...     ...     ...
# 195936  -81.65565      12   0.694  ...   2.195   2.710   6.125   3.757
# 195937 -115.13722      14   0.528  ...   1.002   2.974   6.861   8.354
# 195938  -87.90647     171   1.975  ...   0.994   1.087   2.578   0.612
# 195939  105.84117      31   2.613  ...   1.005   3.058   6.005   6.085
# 195940  107.07336      26   0.069  ...   0.190   2.775   3.412   2.528
#
#         dew_cnt  dew_min  dew_mid  dew_max  dew_var  pm25_mid
# 0            17    7.671   10.358   15.112   13.424    19.901
# 1            62   21.324   23.813   24.221    2.021    13.741
# 2            22   10.309   13.133   15.422    6.355    25.918
# 3           116    7.146   10.685   13.344    9.417   174.370
# 4            93    1.091    3.277   12.272    4.109   167.063
# ...         ...      ...      ...      ...      ...       ...
# 195936       12   16.774   22.679   26.058   13.252    16.150
# 195937       12   10.432   14.741   15.827    7.078    16.895
# 195938       26    2.049    3.531    6.686    5.286    86.299
# 195939       51    1.922    7.443    7.716    4.642    36.523
# 195940       16    8.448   10.372   18.886   11.536    62.021
#
# [195941 rows x 54 columns]

# %%
if not "Prev" in train_df.columns:
    train_df = train_df.merge(population_df[["rank", "City", "Country", "Population", "Prev", "Growth"]], on = ["City", "Country"], how="left")
    test_df = test_df.merge(population_df[["rank", "City", "Country",  "Population", "Prev", "Growth"]], on = ["City", "Country"], how="left")

assert len(test_df) == len(sample_df)

# %%
# Config
NUM_FOLDS = 20

# %%
#############
## Utility ##
#############
@contextmanager
def timer(name: str):
    t0 = time.time()
    print(f"[{name}] start")
    yield
    print(f"[{name}] done - elapsed {time.time() - t0:.2f}s")

# %%
def seed_everything(seed):
    """
    Seeds basic parameters for reproductibility of results
    
    Arguments:
        seed {int} -- Number of the seed
    """
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def set_seed(seed):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(42)

# %%
train_df.head()
# Out:
#    id  year  month  day    Country       City       lat        lon  co_cnt  \
# 0   1  2019      1    1  Australia   Brisbane -27.46794  153.02809      38
# 1   2  2019      1    1  Australia     Darwin -12.46113  130.84185      47
# 2   3  2019      1    1  Australia  Melbourne -37.81400  144.96332      17
# 3   4  2019      1    1  Australia  Newcastle -32.92953  151.78010      63
# 4   5  2019      1    1  Australia      Perth -31.95224  115.86140      47
#
#    co_min  ...  dew_cnt  dew_min  dew_mid  dew_max  dew_var  pm25_mid   rank  \
# 0   0.749  ...       17    7.671   10.358   15.112   13.424    19.901  201.0
# 1   2.594  ...       62   21.324   23.813   24.221    2.021    13.741    NaN
# 2   1.190  ...       22   10.309   13.133   15.422    6.355    25.918   79.0
# 3   4.586  ...      116    7.146   10.685   13.344    9.417   174.370    NaN
# 4   4.689  ...       93    1.091    3.277   12.272    4.109   167.063  242.0
#
#    Population       Prev  Growth
# 0   2472222.0  2439467.0  0.0134
# 1         NaN        NaN     NaN
# 2   5150766.0  5061439.0  0.0176
# 3         NaN        NaN     NaN
# 4   2092649.0  2067333.0  0.0122
#
# [5 rows x 58 columns]

# %%
train_city = train_df["City"].unique().tolist()
test_city = test_df["City"].unique().tolist()

train_city_cnt = len(train_city)
test_city_cnt = len(test_city)

print(f"train city count: {train_city_cnt}")
print(f"test city count: {test_city_cnt}")

print(f"{len(set(train_city) & set(test_city))}")
# Out:
# train city count: 239
# test city count: 63
# 0

# %%
kf = GroupKFold(n_splits = NUM_FOLDS)

if not "kfold" in train_df.columns:
    folds = copy.deepcopy(train_df[["id"]])
    folds["kfold"] = -1

    for fold, (train_idx, valid_idx) in enumerate(kf.split(train_df, train_df["pm25_mid"], train_df["City"])):
        print(f"train_idx: {len(train_idx)}, valid_idx: {len(valid_idx)}")
        folds.loc[valid_idx, "kfold"] = fold

    train_df = train_df.merge(folds[["id", "kfold"]], on="id", how="left")
# Out:
# train_idx: 186092, valid_idx: 9849
# train_idx: 186170, valid_idx: 9771
# train_idx: 186176, valid_idx: 9765
# train_idx: 186097, valid_idx: 9844
# train_idx: 186144, valid_idx: 9797
# train_idx: 186174, valid_idx: 9767
# train_idx: 186147, valid_idx: 9794
# train_idx: 186147, valid_idx: 9794
# train_idx: 186097, valid_idx: 9844
# train_idx: 186152, valid_idx: 9789
# train_idx: 186163, valid_idx: 9778
# train_idx: 186140, valid_idx: 9801
# train_idx: 186129, valid_idx: 9812
# train_idx: 186146, valid_idx: 9795
# train_idx: 186144, valid_idx: 9797
# train_idx: 186166, valid_idx: 9775
# train_idx: 186133, valid_idx: 9808
# train_idx: 186140, valid_idx: 9801
# train_idx: 186147, valid_idx: 9794
# train_idx: 186175, valid_idx: 9766

# %% [markdown]
# # Train

# %%
import logging
from typing import List, Optional, TypeVar

import pandas as pd

class AbstractFeatureTransformer:
    def __init__(self):
        self.name = self.__class__.__name__

    def fit_transform(self, input_df: pd.DataFrame, y=None):
        self.fit(input_df, y)
        return self.transform(input_df)

    def fit(self, input_df: pd.DataFrame, y=None):
        pass

    def transform(self, input_df: pd.DataFrame) -> pd.DataFrame:
        raise NotImplementedError

Transformer = TypeVar("Transformer", bound=AbstractFeatureTransformer)

def extract_features(input_df: pd.DataFrame,
                     transformers: List[Transformer],
                     fit: bool = True,
                     logger: Optional[logging.Logger] = None):
    feature_dfs = []
    for transformer in transformers:
        # timerはブロックの実行時間を計測するユーティリティ
        with timer(f"Extract features with {transformer.name}", logger):
            if fit:
                feature_dfs.append(transformer.fit_transform(input_df))
            else:
                feature_dfs.append(transformer.transform(input_df))
    all_features = pd.concat(feature_dfs, axis=1)
    return all_features

# %%
class Numericals(AbstractFeatureTransformer):
    def transform(self, input_df: pd.DataFrame) -> pd.DataFrame:
        cols = [pd.api.types.is_numeric_dtype(dtype) for dtype in input_df.dtypes]
        return input_df.loc[:, cols]

class LabelEncoding(AbstractFeatureTransformer):
    def __init__(self, columns: List[str]):
        super().__init__()
        self.le_columns = columns
        self.encoders = {
            column: LabelEncoder()
            for column in self.le_columns
        }
        self.__is_fitted = False

    def fit(self, input_df: pd.DataFrame, y: Optional[np.ndarray] = None):
        """
        ラベルに変換する前に欠損値を埋める
        """
        for column in self.le_columns:
            self.encoders[column].fit(input_df[column].fillna(""))
        self.__is_fitted = True

    def transform(
        self, 
        input_df: pd.DataFrame, 
        y: Optional[np.ndarray] = None
    ) -> pd.DataFrame:
        assert self.__is_fitted, "You need to call `fit` first."
        encoded = {}
        for column in self.le_columns:
            encoded[column] = self.encoders[column].transform(
                input_df[column].fillna(""))
        return pd.DataFrame(encoded)

# %%
def preprocess(df:pd.DataFrame)->pd.DataFrame:
    df_ = copy.deepcopy(df)
    # 経度をcosに変換
    cnt = 0

    df_["lon_cos"] = np.cos(np.radians((df_["lon"] + 180)))
    df_["lon_sin"] = np.sin(np.radians((df_["lon"] + 180)))
    df_["month_cos"] = np.cos(np.radians(df_["month"] / 12 * 360))
    df_["month_sin"] = np.sin(np.radians(df_["month"] / 12 * 360))
    print("add lon_cos, lon_sin, month_cos, month_sin")
    cnt += 4

    # 四則演算

    # 南半球を北半球のmonthに変更
    df_["month_world"] = df_["month"]
    df_.loc[df_["lat"] < 0, "month_world"] = df_["month"] + 6
    df_.loc[df_["month_world"] > 12, "month_world"] = df_["month"] - 6
    print("add month_world")
    cnt += 1
    # mid同士を4則
    columns = df_.columns
    mids = []
    for c in columns:
        if "_mid" in c and c != "pm25_mid":
            mids.append(c)
    scaler = MinMaxScaler()

    # 日の出時間を計算 (sun_time)
    def _cal_sun_time(lat:float, lon:float, year:float, month:float, day: float)->float:
        location = ephem.Observer()
        location.lat = str(lat)
        location.lon = str(lon)
        sun = ephem.Sun()

        location.date = datetime.date(year = int(year), month = int(month), day = int(day))
        sun_time_tmp1 = ephem.localtime(location.next_rising(sun)) - ephem.localtime(location.next_setting(sun))
        sun_time_tmp2 = ephem.localtime(location.next_setting(sun)) - ephem.localtime(location.next_rising(sun))

        sun_time = max(sun_time_tmp1.seconds, sun_time_tmp2.seconds)

        return sun_time

    if not "sun_time" in df_.columns:
        u_cols = ["lat", "lon", "year", "month", "day"]

        df_["sun_time"] = -1

        mini_df = df_[u_cols]

        sun_time = np.zeros(len(df_))
        for i in tqdm(range(len(mini_df))):
            lat, lon, year, month, day = mini_df.iloc[i]
            sun_time[i] = _cal_sun_time(lat, lon, year, month, day)
        df_["sun_time"] = sun_time

        print("add sun_time")
    cnt += 1

    # scaling_columns = []
    # for i in range(len(mids)):
    #     for j in range(i):
    #         df_[f"{mids[i]}x{mids[j]}"] = df_[mids[i]] * df_[mids[j]]
    #         df_[f"{mids[i]}/{mids[j]}"] = df_[mids[i]] / (df_[mids[j]] + 1e-6)
    #         df_[f"{mids[i]}+{mids[j]}"] = df_[mids[i]] + df_[mids[j]]
    #         df_[f"{mids[i]}-{mids[j]}"] = df_[mids[i]] - df_[mids[j]]
    #         cnt += 4

    #         scaling_columns += [f"{mids[i]}x{mids[j]}", f"{mids[i]}/{mids[j]}", f"{mids[i]}+{mids[j]}", f"{mids[i]}-{mids[j]}"]
    print(f"add {cnt} columns")

    return df_

# %%
# label encoding

cat_cols = ["Country", "City"]

for c in cat_cols:
    le = LabelEncoder()
    le.fit(pd.concat([train_df, test_df])[c])
    train_df[c] = le.transform(train_df[c])
    test_df[c] = le.transform(test_df[c])

# %%
train_df_ = preprocess(train_df)
test_df_ = preprocess(test_df)
# Out:
# add lon_cos, lon_sin, month_cos, month_sin
# add month_world
#   0%|          | 0/195941 [00:00<?, ?it/s]
# add sun_time
# add 6 columns
# add lon_cos, lon_sin, month_cos, month_sin
# add month_world
#   0%|          | 0/53509 [00:00<?, ?it/s]
# add sun_time
# add 6 columns

# %%
train_df_.head(20)
# Out:
#     id  year  month  day  Country  City       lat        lon  co_cnt  co_min  \
# 0    1  2019      1    1        0    24 -27.46794  153.02809      38   0.749
# 1    2  2019      1    1        0    54 -12.46113  130.84185      47   2.594
# 2    3  2019      1    1        0   146 -37.81400  144.96332      17   1.190
# 3    4  2019      1    1        0   176 -32.92953  151.78010      63   4.586
# 4    5  2019      1    1        0   193 -31.95224  115.86140      47   4.689
# 5    6  2019      1    1        0   278 -34.42400  150.89345     179   4.554
# 6    7  2019      1    1        1     8  51.22047    4.40026      93   4.011
# 7    8  2019      1    1        1    38  50.41136    4.44448      11   0.096
# 8    9  2019      1    1        1   137  50.63373    5.56749      12   0.097
# 9   10  2019      1    1        3   247 -23.54750  -46.63611     354   1.048
# 10  11  2019      1    1        3   275 -20.31944  -40.33778      29   0.117
# 11  12  2019      1    1        4   272  49.24966 -123.11934      34   0.110
# 12  13  2019      1    1        5    31 -22.45667  -68.92371      22   2.320
# 13  14  2019      1    1        5   208 -33.04752  -71.44249      28   0.078
# 14  15  2019      1    1        5   255 -35.42640  -71.65542     241   0.058
# 15  16  2019      1    1        6    15  39.90750  116.39723     199   5.209
# 16  17  2019      1    1        6    35  28.19874  112.97087      47   0.073
# 17  18  2019      1    1        6    40  30.66667  104.06667     336   5.015
# 18  19  2019      1    1        6    65  23.02677  113.13148     162   2.152
# 19  20  2019      1    1        6    68  41.88669  123.94363     103   2.543
#
#     ...  Population        Prev  Growth  kfold   lon_cos   lon_sin  month_cos  \
# 0   ...   2472222.0   2439467.0  0.0134     10  0.891229 -0.453554   0.866025
# 1   ...         NaN         NaN     NaN     10  0.653973 -0.756518   0.866025
# 2   ...   5150766.0   5061439.0  0.0176      0  0.818785 -0.574101   0.866025
# 3   ...         NaN         NaN     NaN     10  0.881139 -0.472857   0.866025
# 4   ...   2092649.0   2067333.0  0.0122     14  0.436196 -0.899852   0.866025
# 5   ...         NaN         NaN     NaN      5  0.873717 -0.486435   0.866025
# 6   ...         NaN         NaN     NaN      7 -0.997052 -0.076724   0.866025
# 7   ...         NaN         NaN     NaN     15 -0.996993 -0.077493   0.866025
# 8   ...         NaN         NaN     NaN      3 -0.995283 -0.097018   0.866025
# 9   ...  22429800.0  22237472.0  0.0086      9 -0.686629  0.727008   0.866025
# 10  ...         NaN         NaN     NaN      7 -0.762242  0.647293   0.866025
# 11  ...   2631690.0   2606351.0  0.0097      3  0.546385  0.837534   0.866025
# 12  ...         NaN         NaN     NaN     18 -0.359611  0.933102   0.866025
# 13  ...         NaN         NaN     NaN      8 -0.318256  0.948005   0.866025
# 14  ...         NaN         NaN     NaN     13 -0.314731  0.949181   0.866025
# 15  ...  21333332.0  20896820.0  0.0209     14  0.444592 -0.895733   0.866025
# 16  ...   4809887.0   4694722.0  0.0245     12  0.390263 -0.920703   0.866025
# 17  ...   9478521.0   9305116.0  0.0186     18  0.243051 -0.970014   0.866025
# 18  ...   7497263.0   7406751.0  0.0122     12  0.392842 -0.919606   0.866025
# 19  ...         NaN         NaN     NaN      8  0.558377 -0.829587   0.866025
#
#     month_sin  month_world  sun_time
# 0         0.5            7   49842.0
# 1         0.5            7   46246.0
# 2         0.5            7   53041.0
# 3         0.5            7   51421.0
# 4         0.5            7   51120.0
# 5         0.5            7   51893.0
# 6         0.5            1   57633.0
# 7         0.5            1   57173.0
# 8         0.5            1   57298.0
# 9         0.5            7   48845.0
# 10        0.5            7   48056.0
# 11        0.5            1   56582.0
# 12        0.5            7   48572.0
# 13        0.5            7   51482.0
# 14        0.5            7   52234.0
# 15        0.5            1   52545.0
# 16        0.5            1   48985.0
# 17        0.5            1   49636.0
# 18        0.5            1   47688.0
# 19        0.5            1   53278.0
#
# [20 rows x 65 columns]

# %%
# numericals = Numericals()
# 数字に関する変換
# train_df_num = numericals.transform(train_df)

# ラベルに関する変換
# labelencoding = LabelEncoding(columns = [])

# labelencoding.fit(train_df_num)
# train_df_labeled = labelencoding.transform(train_df_num)

# %%
class AbstractTreeModel:
    def __init__(self, prediction_type="regression"):
        self.model = None
        self.prediction_type = prediction_type

    def train(self,
              params: dict,
              X_train: pd.DataFrame,
              y_train: np.ndarray,
              X_val: pd.DataFrame,
              y_val: np.ndarray,
              train_weights: Optional[np.ndarray] = None,
              val_weights: Optional[np.ndarray] = None,
              train_params: Optional[dict] = None):
        if train_params is None:
            train_params = {}

        model = self._train(
            params,
            X_train, y_train,
            X_val, y_val,
            train_weights, val_weights,
            train_params)
        self.model = model
        return self

    def _train(self,
               params,
               X_train,
               y_train,
               X_val,
               y_val,
               train_weights,
               val_weights,
               train_params):
        raise NotImplementedError

    def predict(self, X: pd.DataFrame) -> np.ndarray:
        raise NotImplementedError

    @property
    def feature_names_(self):
        raise NotImplementedError

    @property
    def feature_importances_(self):
        raise NotImplementedError

    def _check_if_trained(self):
        assert self.model is not None, "You need to train the model first"


class LGBModel(AbstractTreeModel):
    def _train(self,
               params,
               X_train, y_train,
               X_val, y_val,
               train_weights, val_weights,
               train_params):
        trn_data = lgb.Dataset(X_train, y_train, weight=train_weights)
        val_data = lgb.Dataset(X_val, y_val, weight=val_weights)
        model = lgb.train(params=params,
                          train_set=trn_data,
                          valid_sets=[trn_data, val_data],
                          **train_params,)
                        #   verbose_eval=False)
        return model

    def predict(self, X: pd.DataFrame) -> np.ndarray:
        self._check_if_trained()
        return self.model.predict(X, num_iteration=self.model.best_iteration)

    @property
    def feature_names_(self):
        self._check_if_trained()
        return self.model.feature_name()

    @property
    def feature_importances_(self):
        self._check_if_trained()
        return self.model.feature_importance(importance_type="gain")


def get_tree_model(name: str) -> Type[AbstractTreeModel]:
    DEFINED_MODELS = {
        "lgb": LGBModel,
        # 実装していない
        # "xgb": XGBModel,
        # "cat": CatBoostModel
    }
    model = DEFINED_MODELS.get(name)
    if model is None:
        raise ValueError(
            """Invalid model name: {}.
            Pre-defined model names are as follows: {}""".format(
                name,
                ",".join(DEFINED_MODELS.keys())
            ))
    return model

# %%
def viz_feature_importances(feature_importances: pd.DataFrame)-> None:
    fi_gby = feature_importances.groupby("feature").agg({
        "importance": ["mean", "std"]
    }).sort_values(("importance", "mean"), ascending=0).index
    plt.figure(figsize=(20, 10))

    sns.barplot(x="importance", y="feature", data=feature_importances, order=fi_gby)

    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.show()
    # plt.savefig('lgbm_importances-01.png')

# %%
train_params = {
    "num_boost_round": 100000,
    "callbacks": [
                  lgb.early_stopping(stopping_rounds= 200, verbose=True),
                  lgb.log_evaluation(period = 500)
    ]
}

# %%
model = get_tree_model("lgb")()

num_cols = [c for c in train_df_.columns if train_df_[c].dtype != np.object]
if "id" in num_cols:
    num_cols.remove("id")
if "kfold" in num_cols:
    num_cols.remove("kfold")
num_cols.remove("pm25_mid")

target_cols = "pm25_mid"

# %%
use_cols = [
'year',
'month', 
'day', 
'lat', 'lon',
 'co_cnt', 'co_min', 'co_mid', 'co_max', 'co_var', 
 'o3_cnt', 'o3_min', 'o3_mid', 'o3_max', 'o3_var', 
 'so2_cnt', 'so2_min', 'so2_mid', 'so2_max', 'so2_var', 'no2_cnt', 
 'no2_min', 'no2_mid', 'no2_max', 'no2_var',
'temperature_cnt', 'temperature_min', 'temperature_mid', 'temperature_max', 'temperature_var', 
'humidity_cnt', 'humidity_min', 'humidity_mid', 'humidity_max', 'humidity_var', 
'pressure_cnt', 'pressure_min', 'pressure_mid', 'pressure_max', 'pressure_var', 
'ws_cnt', 'ws_min', 'ws_mid', 'ws_max', 'ws_var', 
'dew_cnt', 'dew_min', 'dew_mid', 'dew_max', 'dew_var', 
'rank', 'Population', 'Prev', 'Growth', 'lon_cos', 'lon_sin', 'month_cos', 'month_sin', 'month_world', 
"sun_time"
] + cat_cols

# %%
params= {
        'boosting': 'gbdt',
        'objective': 'rmse',
        'metric': 'rmse',
        "max_bin":255,
        'learning_rate': 0.01,
        "max_depth": 8,
        "num_leaves": 8,
        'subsample': 0.7,
        'subsample_freq': 1,
        "min_data_in_leaf":30, 
        "device": "gpu",  
        "seed":2022,
}

# %%
models = []

oof_df = train_df_[["id"]]
oof_df["oof"] = -1

from lightgbm import early_stopping
from lightgbm import log_evaluation

for i in range(NUM_FOLDS):
    train_data = train_df_[train_df_["kfold"] != i].reset_index(drop = True)
    valid_data = train_df_[train_df_["kfold"] == i].reset_index(drop = True)

    print(f"train_data nums: {len(train_data)}, valid_data nums: {len(valid_data)}")

    model.train(
        params,
        train_params = train_params,
        X_train = train_data[use_cols],
        y_train = train_data[target_cols],
        X_val = valid_data[use_cols],
        y_val = valid_data[target_cols],
    )
    models.append(model)

    feature_importance = pd.DataFrame()
    feature_importance["feature"] = model.feature_names_
    feature_importance["importance"] = model.feature_importances_
    feature_importance["fold"] = i

    oof = model.predict(
        valid_data[use_cols]
    )
    oof_df.loc[train_df["kfold"] == i, "oof"] = oof

train_oof = train_df.merge(oof_df[["id", "oof"]], on = "id", how = "left")
# Out:
# train_data nums: 186092, valid_data nums: 9849
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13435
# [LightGBM] [Info] Number of data points in the train set: 186092, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.008359 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.915934
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.84	valid_1's rmse: 26.6549
# [1000]	training's rmse: 21.7549	valid_1's rmse: 25.8454
# [1500]	training's rmse: 21.2137	valid_1's rmse: 25.421
# [2000]	training's rmse: 20.8325	valid_1's rmse: 25.2646
# [2500]	training's rmse: 20.5486	valid_1's rmse: 25.1378
# [3000]	training's rmse: 20.3276	valid_1's rmse: 25.092
# Early stopping, best iteration is:
# [2929]	training's rmse: 20.3563	valid_1's rmse: 25.0823
# train_data nums: 186170, valid_data nums: 9771
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13451
# [LightGBM] [Info] Number of data points in the train set: 186170, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.008655 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.248513
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.9277	valid_1's rmse: 23.9021
# [1000]	training's rmse: 21.8037	valid_1's rmse: 23.2082
# [1500]	training's rmse: 21.2386	valid_1's rmse: 22.9188
# [2000]	training's rmse: 20.8659	valid_1's rmse: 22.6809
# [2500]	training's rmse: 20.5864	valid_1's rmse: 22.5561
# [3000]	training's rmse: 20.3691	valid_1's rmse: 22.4815
# [3500]	training's rmse: 20.1805	valid_1's rmse: 22.438
# [4000]	training's rmse: 20.0157	valid_1's rmse: 22.4145
# [4500]	training's rmse: 19.8718	valid_1's rmse: 22.3811
# [5000]	training's rmse: 19.7393	valid_1's rmse: 22.3562
# Early stopping, best iteration is:
# [5296]	training's rmse: 19.6666	valid_1's rmse: 22.3381
# train_data nums: 186176, valid_data nums: 9765
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13444
# [LightGBM] [Info] Number of data points in the train set: 186176, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.009125 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.499167
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 23.0115	valid_1's rmse: 21.9959
# [1000]	training's rmse: 21.8708	valid_1's rmse: 21.5202
# [1500]	training's rmse: 21.3039	valid_1's rmse: 21.3212
# [2000]	training's rmse: 20.9272	valid_1's rmse: 21.1722
# [2500]	training's rmse: 20.6415	valid_1's rmse: 21.0541
# [3000]	training's rmse: 20.4186	valid_1's rmse: 20.96
# [3500]	training's rmse: 20.227	valid_1's rmse: 20.8973
# [4000]	training's rmse: 20.066	valid_1's rmse: 20.8427
# [4500]	training's rmse: 19.9205	valid_1's rmse: 20.7858
# [5000]	training's rmse: 19.7875	valid_1's rmse: 20.7484
# [5500]	training's rmse: 19.6667	valid_1's rmse: 20.7334
# [6000]	training's rmse: 19.5564	valid_1's rmse: 20.7182
# [6500]	training's rmse: 19.4507	valid_1's rmse: 20.697
# [7000]	training's rmse: 19.3487	valid_1's rmse: 20.6719
# Early stopping, best iteration is:
# [7163]	training's rmse: 19.318	valid_1's rmse: 20.6686
# train_data nums: 186097, valid_data nums: 9844
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13436
# [LightGBM] [Info] Number of data points in the train set: 186097, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.008863 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.440833
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.9759	valid_1's rmse: 22.4382
# [1000]	training's rmse: 21.8217	valid_1's rmse: 22.2606
# Early stopping, best iteration is:
# [1200]	training's rmse: 21.5647	valid_1's rmse: 22.2121
# train_data nums: 186144, valid_data nums: 9797
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13447
# [LightGBM] [Info] Number of data points in the train set: 186144, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.010406 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.118859
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.9768	valid_1's rmse: 22.4477
# [1000]	training's rmse: 21.8333	valid_1's rmse: 21.8599
# [1500]	training's rmse: 21.2669	valid_1's rmse: 21.6064
# [2000]	training's rmse: 20.8848	valid_1's rmse: 21.4461
# [2500]	training's rmse: 20.6056	valid_1's rmse: 21.3418
# [3000]	training's rmse: 20.3837	valid_1's rmse: 21.2522
# [3500]	training's rmse: 20.198	valid_1's rmse: 21.1761
# [4000]	training's rmse: 20.0391	valid_1's rmse: 21.1248
# [4500]	training's rmse: 19.8961	valid_1's rmse: 21.0856
# [5000]	training's rmse: 19.7686	valid_1's rmse: 21.0446
# [5500]	training's rmse: 19.651	valid_1's rmse: 21.0083
# [6000]	training's rmse: 19.5433	valid_1's rmse: 20.9758
# [6500]	training's rmse: 19.4375	valid_1's rmse: 20.9476
# [7000]	training's rmse: 19.34	valid_1's rmse: 20.9206
# [7500]	training's rmse: 19.2466	valid_1's rmse: 20.9012
# [8000]	training's rmse: 19.1602	valid_1's rmse: 20.8845
# [8500]	training's rmse: 19.0754	valid_1's rmse: 20.8546
# [9000]	training's rmse: 18.9942	valid_1's rmse: 20.8427
# [9500]	training's rmse: 18.9178	valid_1's rmse: 20.8189
# [10000]	training's rmse: 18.8443	valid_1's rmse: 20.8098
# [10500]	training's rmse: 18.7696	valid_1's rmse: 20.7879
# [11000]	training's rmse: 18.6995	valid_1's rmse: 20.7661
# [11500]	training's rmse: 18.6315	valid_1's rmse: 20.7466
# [12000]	training's rmse: 18.5661	valid_1's rmse: 20.7263
# [12500]	training's rmse: 18.5011	valid_1's rmse: 20.7128
# [13000]	training's rmse: 18.4389	valid_1's rmse: 20.7061
# [13500]	training's rmse: 18.3771	valid_1's rmse: 20.689
# [14000]	training's rmse: 18.3169	valid_1's rmse: 20.6761
# [14500]	training's rmse: 18.2591	valid_1's rmse: 20.6641
# [15000]	training's rmse: 18.2017	valid_1's rmse: 20.6585
# Early stopping, best iteration is:
# [14940]	training's rmse: 18.2085	valid_1's rmse: 20.6567
# train_data nums: 186174, valid_data nums: 9767
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13431
# [LightGBM] [Info] Number of data points in the train set: 186174, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.008653 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.132060
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.8508	valid_1's rmse: 26.2903
# [1000]	training's rmse: 21.737	valid_1's rmse: 25.1016
# [1500]	training's rmse: 21.1875	valid_1's rmse: 24.4941
# [2000]	training's rmse: 20.8189	valid_1's rmse: 24.0836
# [2500]	training's rmse: 20.5448	valid_1's rmse: 23.8441
# [3000]	training's rmse: 20.3182	valid_1's rmse: 23.655
# [3500]	training's rmse: 20.1356	valid_1's rmse: 23.5485
# [4000]	training's rmse: 19.9744	valid_1's rmse: 23.4562
# [4500]	training's rmse: 19.8299	valid_1's rmse: 23.384
# [5000]	training's rmse: 19.6989	valid_1's rmse: 23.3192
# [5500]	training's rmse: 19.5821	valid_1's rmse: 23.261
# [6000]	training's rmse: 19.4747	valid_1's rmse: 23.2269
# [6500]	training's rmse: 19.3722	valid_1's rmse: 23.1886
# [7000]	training's rmse: 19.2764	valid_1's rmse: 23.1645
# [7500]	training's rmse: 19.1841	valid_1's rmse: 23.1224
# [8000]	training's rmse: 19.0986	valid_1's rmse: 23.082
# Early stopping, best iteration is:
# [8146]	training's rmse: 19.0733	valid_1's rmse: 23.0721
# train_data nums: 186147, valid_data nums: 9794
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13443
# [LightGBM] [Info] Number of data points in the train set: 186147, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.008509 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.017673
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.9425	valid_1's rmse: 24.3608
# [1000]	training's rmse: 21.834	valid_1's rmse: 23.1745
# [1500]	training's rmse: 21.2733	valid_1's rmse: 22.7216
# [2000]	training's rmse: 20.8965	valid_1's rmse: 22.3149
# [2500]	training's rmse: 20.6195	valid_1's rmse: 22.0315
# [3000]	training's rmse: 20.3943	valid_1's rmse: 21.8647
# [3500]	training's rmse: 20.2022	valid_1's rmse: 21.727
# [4000]	training's rmse: 20.0423	valid_1's rmse: 21.6053
# [4500]	training's rmse: 19.8958	valid_1's rmse: 21.5069
# [5000]	training's rmse: 19.7634	valid_1's rmse: 21.4351
# [5500]	training's rmse: 19.643	valid_1's rmse: 21.3599
# [6000]	training's rmse: 19.5346	valid_1's rmse: 21.2927
# [6500]	training's rmse: 19.4306	valid_1's rmse: 21.2553
# [7000]	training's rmse: 19.3341	valid_1's rmse: 21.2173
# [7500]	training's rmse: 19.2421	valid_1's rmse: 21.1892
# [8000]	training's rmse: 19.1527	valid_1's rmse: 21.153
# [8500]	training's rmse: 19.0693	valid_1's rmse: 21.134
# [9000]	training's rmse: 18.9888	valid_1's rmse: 21.1129
# [9500]	training's rmse: 18.9112	valid_1's rmse: 21.0872
# [10000]	training's rmse: 18.836	valid_1's rmse: 21.0683
# [10500]	training's rmse: 18.7632	valid_1's rmse: 21.0489
# [11000]	training's rmse: 18.6935	valid_1's rmse: 21.0233
# [11500]	training's rmse: 18.6253	valid_1's rmse: 21.0149
# [12000]	training's rmse: 18.5593	valid_1's rmse: 21.0008
# [12500]	training's rmse: 18.4947	valid_1's rmse: 20.9867
# [13000]	training's rmse: 18.4315	valid_1's rmse: 20.9793
# [13500]	training's rmse: 18.3703	valid_1's rmse: 20.9615
# [14000]	training's rmse: 18.3097	valid_1's rmse: 20.9544
# [14500]	training's rmse: 18.2507	valid_1's rmse: 20.9486
# [15000]	training's rmse: 18.1935	valid_1's rmse: 20.9382
# [15500]	training's rmse: 18.1358	valid_1's rmse: 20.9274
# [16000]	training's rmse: 18.0795	valid_1's rmse: 20.9223
# [16500]	training's rmse: 18.0242	valid_1's rmse: 20.9137
# [17000]	training's rmse: 17.9704	valid_1's rmse: 20.9051
# Early stopping, best iteration is:
# [17183]	training's rmse: 17.9507	valid_1's rmse: 20.8999
# train_data nums: 186147, valid_data nums: 9794
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13431
# [LightGBM] [Info] Number of data points in the train set: 186147, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.008707 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.861590
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.7751	valid_1's rmse: 30.4601
# [1000]	training's rmse: 21.6577	valid_1's rmse: 29.509
# [1500]	training's rmse: 21.1094	valid_1's rmse: 28.9522
# [2000]	training's rmse: 20.7448	valid_1's rmse: 28.4386
# [2500]	training's rmse: 20.478	valid_1's rmse: 28.0865
# [3000]	training's rmse: 20.2642	valid_1's rmse: 27.8792
# [3500]	training's rmse: 20.0864	valid_1's rmse: 27.7346
# Early stopping, best iteration is:
# [3730]	training's rmse: 20.012	valid_1's rmse: 27.6883
# train_data nums: 186097, valid_data nums: 9844
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13457
# [LightGBM] [Info] Number of data points in the train set: 186097, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.008710 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.169640
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.8988	valid_1's rmse: 24.157
# [1000]	training's rmse: 21.7589	valid_1's rmse: 23.6968
# [1500]	training's rmse: 21.1908	valid_1's rmse: 23.4159
# [2000]	training's rmse: 20.8099	valid_1's rmse: 23.231
# [2500]	training's rmse: 20.5237	valid_1's rmse: 23.106
# [3000]	training's rmse: 20.2993	valid_1's rmse: 22.9998
# [3500]	training's rmse: 20.1128	valid_1's rmse: 22.9192
# [4000]	training's rmse: 19.9504	valid_1's rmse: 22.8421
# [4500]	training's rmse: 19.8063	valid_1's rmse: 22.7865
# [5000]	training's rmse: 19.6767	valid_1's rmse: 22.7318
# [5500]	training's rmse: 19.5578	valid_1's rmse: 22.6826
# [6000]	training's rmse: 19.4484	valid_1's rmse: 22.6324
# [6500]	training's rmse: 19.3455	valid_1's rmse: 22.6003
# [7000]	training's rmse: 19.2489	valid_1's rmse: 22.5648
# [7500]	training's rmse: 19.1576	valid_1's rmse: 22.5393
# [8000]	training's rmse: 19.0687	valid_1's rmse: 22.5197
# [8500]	training's rmse: 18.9854	valid_1's rmse: 22.4932
# [9000]	training's rmse: 18.9065	valid_1's rmse: 22.4729
# [9500]	training's rmse: 18.8281	valid_1's rmse: 22.4517
# [10000]	training's rmse: 18.7548	valid_1's rmse: 22.438
# [10500]	training's rmse: 18.682	valid_1's rmse: 22.4169
# [11000]	training's rmse: 18.6121	valid_1's rmse: 22.4043
# [11500]	training's rmse: 18.5445	valid_1's rmse: 22.3945
# [12000]	training's rmse: 18.4795	valid_1's rmse: 22.3723
# [12500]	training's rmse: 18.4158	valid_1's rmse: 22.3623
# [13000]	training's rmse: 18.3533	valid_1's rmse: 22.3461
# [13500]	training's rmse: 18.2916	valid_1's rmse: 22.3416
# [14000]	training's rmse: 18.2325	valid_1's rmse: 22.3249
# [14500]	training's rmse: 18.1735	valid_1's rmse: 22.3158
# [15000]	training's rmse: 18.1153	valid_1's rmse: 22.2994
# [15500]	training's rmse: 18.059	valid_1's rmse: 22.2838
# Early stopping, best iteration is:
# [15543]	training's rmse: 18.0541	valid_1's rmse: 22.2825
# train_data nums: 186152, valid_data nums: 9789
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13443
# [LightGBM] [Info] Number of data points in the train set: 186152, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.009006 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.187443
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.9471	valid_1's rmse: 24.0142
# [1000]	training's rmse: 21.8228	valid_1's rmse: 22.9758
# [1500]	training's rmse: 21.27	valid_1's rmse: 22.5962
# [2000]	training's rmse: 20.8963	valid_1's rmse: 22.383
# [2500]	training's rmse: 20.6204	valid_1's rmse: 22.1813
# [3000]	training's rmse: 20.4007	valid_1's rmse: 22.0741
# [3500]	training's rmse: 20.214	valid_1's rmse: 21.9988
# [4000]	training's rmse: 20.0519	valid_1's rmse: 21.9224
# [4500]	training's rmse: 19.9082	valid_1's rmse: 21.8824
# [5000]	training's rmse: 19.7777	valid_1's rmse: 21.838
# [5500]	training's rmse: 19.6604	valid_1's rmse: 21.796
# [6000]	training's rmse: 19.5518	valid_1's rmse: 21.7795
# [6500]	training's rmse: 19.4501	valid_1's rmse: 21.7443
# [7000]	training's rmse: 19.3554	valid_1's rmse: 21.7071
# [7500]	training's rmse: 19.2659	valid_1's rmse: 21.6824
# [8000]	training's rmse: 19.1806	valid_1's rmse: 21.6577
# [8500]	training's rmse: 19.0978	valid_1's rmse: 21.6232
# Early stopping, best iteration is:
# [8602]	training's rmse: 19.0813	valid_1's rmse: 21.6132
# train_data nums: 186163, valid_data nums: 9778
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13450
# [LightGBM] [Info] Number of data points in the train set: 186163, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.008622 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.714952
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 23.0053	valid_1's rmse: 22.8827
# [1000]	training's rmse: 21.8666	valid_1's rmse: 22.2423
# [1500]	training's rmse: 21.3009	valid_1's rmse: 21.9086
# [2000]	training's rmse: 20.9222	valid_1's rmse: 21.6589
# [2500]	training's rmse: 20.6403	valid_1's rmse: 21.511
# [3000]	training's rmse: 20.4174	valid_1's rmse: 21.3841
# [3500]	training's rmse: 20.2286	valid_1's rmse: 21.2904
# [4000]	training's rmse: 20.0643	valid_1's rmse: 21.2392
# [4500]	training's rmse: 19.9183	valid_1's rmse: 21.1914
# [5000]	training's rmse: 19.7886	valid_1's rmse: 21.1644
# [5500]	training's rmse: 19.6692	valid_1's rmse: 21.1316
# [6000]	training's rmse: 19.5602	valid_1's rmse: 21.1051
# [6500]	training's rmse: 19.4585	valid_1's rmse: 21.0832
# [7000]	training's rmse: 19.3594	valid_1's rmse: 21.0684
# [7500]	training's rmse: 19.2683	valid_1's rmse: 21.0562
# [8000]	training's rmse: 19.1805	valid_1's rmse: 21.0412
# Early stopping, best iteration is:
# [8246]	training's rmse: 19.139	valid_1's rmse: 21.032
# train_data nums: 186140, valid_data nums: 9801
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13461
# [LightGBM] [Info] Number of data points in the train set: 186140, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.014467 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.328148
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.9692	valid_1's rmse: 22.7125
# [1000]	training's rmse: 21.838	valid_1's rmse: 22.1613
# [1500]	training's rmse: 21.276	valid_1's rmse: 22.0489
# [2000]	training's rmse: 20.8971	valid_1's rmse: 21.9452
# [2500]	training's rmse: 20.6186	valid_1's rmse: 21.8767
# Early stopping, best iteration is:
# [2516]	training's rmse: 20.6105	valid_1's rmse: 21.8733
# train_data nums: 186129, valid_data nums: 9812
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13448
# [LightGBM] [Info] Number of data points in the train set: 186129, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.008644 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.052579
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.9668	valid_1's rmse: 22.7497
# [1000]	training's rmse: 21.8463	valid_1's rmse: 22.1392
# [1500]	training's rmse: 21.2856	valid_1's rmse: 21.7578
# [2000]	training's rmse: 20.9021	valid_1's rmse: 21.5376
# [2500]	training's rmse: 20.6248	valid_1's rmse: 21.3939
# [3000]	training's rmse: 20.4012	valid_1's rmse: 21.3003
# [3500]	training's rmse: 20.2112	valid_1's rmse: 21.2327
# [4000]	training's rmse: 20.0444	valid_1's rmse: 21.1742
# [4500]	training's rmse: 19.8976	valid_1's rmse: 21.1226
# [5000]	training's rmse: 19.7691	valid_1's rmse: 21.0903
# [5500]	training's rmse: 19.6479	valid_1's rmse: 21.0529
# [6000]	training's rmse: 19.5391	valid_1's rmse: 21.0264
# [6500]	training's rmse: 19.4355	valid_1's rmse: 20.9913
# [7000]	training's rmse: 19.3381	valid_1's rmse: 20.9612
# [7500]	training's rmse: 19.2469	valid_1's rmse: 20.9388
# [8000]	training's rmse: 19.159	valid_1's rmse: 20.9247
# [8500]	training's rmse: 19.0748	valid_1's rmse: 20.9056
# [9000]	training's rmse: 18.9949	valid_1's rmse: 20.8813
# [9500]	training's rmse: 18.9171	valid_1's rmse: 20.865
# [10000]	training's rmse: 18.8426	valid_1's rmse: 20.8401
# [10500]	training's rmse: 18.7701	valid_1's rmse: 20.8242
# [11000]	training's rmse: 18.7	valid_1's rmse: 20.8014
# [11500]	training's rmse: 18.6332	valid_1's rmse: 20.7832
# [12000]	training's rmse: 18.5676	valid_1's rmse: 20.7702
# [12500]	training's rmse: 18.5029	valid_1's rmse: 20.7547
# [13000]	training's rmse: 18.44	valid_1's rmse: 20.7389
# [13500]	training's rmse: 18.3792	valid_1's rmse: 20.718
# [14000]	training's rmse: 18.3192	valid_1's rmse: 20.6953
# [14500]	training's rmse: 18.2606	valid_1's rmse: 20.685
# [15000]	training's rmse: 18.2027	valid_1's rmse: 20.6806
# [15500]	training's rmse: 18.1461	valid_1's rmse: 20.6702
# [16000]	training's rmse: 18.0914	valid_1's rmse: 20.6538
# Early stopping, best iteration is:
# [16130]	training's rmse: 18.0769	valid_1's rmse: 20.6497
# train_data nums: 186146, valid_data nums: 9795
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13449
# [LightGBM] [Info] Number of data points in the train set: 186146, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.008721 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.509375
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.9969	valid_1's rmse: 22.1909
# [1000]	training's rmse: 21.8608	valid_1's rmse: 21.8165
# [1500]	training's rmse: 21.3	valid_1's rmse: 21.6204
# [2000]	training's rmse: 20.9253	valid_1's rmse: 21.4767
# [2500]	training's rmse: 20.6448	valid_1's rmse: 21.3381
# [3000]	training's rmse: 20.4255	valid_1's rmse: 21.2328
# [3500]	training's rmse: 20.2359	valid_1's rmse: 21.1401
# [4000]	training's rmse: 20.0756	valid_1's rmse: 21.0841
# [4500]	training's rmse: 19.9295	valid_1's rmse: 21.0254
# [5000]	training's rmse: 19.8007	valid_1's rmse: 20.9934
# [5500]	training's rmse: 19.6826	valid_1's rmse: 20.9486
# [6000]	training's rmse: 19.5752	valid_1's rmse: 20.9192
# [6500]	training's rmse: 19.4724	valid_1's rmse: 20.893
# [7000]	training's rmse: 19.3759	valid_1's rmse: 20.8559
# [7500]	training's rmse: 19.2854	valid_1's rmse: 20.8251
# [8000]	training's rmse: 19.1984	valid_1's rmse: 20.7928
# [8500]	training's rmse: 19.1148	valid_1's rmse: 20.7782
# [9000]	training's rmse: 19.0364	valid_1's rmse: 20.7641
# [9500]	training's rmse: 18.9588	valid_1's rmse: 20.7447
# [10000]	training's rmse: 18.8841	valid_1's rmse: 20.7384
# [10500]	training's rmse: 18.8119	valid_1's rmse: 20.7166
# [11000]	training's rmse: 18.7412	valid_1's rmse: 20.6929
# Early stopping, best iteration is:
# [11107]	training's rmse: 18.7261	valid_1's rmse: 20.6911
# train_data nums: 186144, valid_data nums: 9797
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13452
# [LightGBM] [Info] Number of data points in the train set: 186144, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.008819 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.058220
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.8845	valid_1's rmse: 24.8412
# [1000]	training's rmse: 21.7682	valid_1's rmse: 23.7074
# [1500]	training's rmse: 21.2014	valid_1's rmse: 23.4304
# [2000]	training's rmse: 20.8129	valid_1's rmse: 23.2781
# [2500]	training's rmse: 20.5292	valid_1's rmse: 23.1665
# [3000]	training's rmse: 20.3042	valid_1's rmse: 23.0687
# [3500]	training's rmse: 20.1196	valid_1's rmse: 22.9959
# [4000]	training's rmse: 19.9606	valid_1's rmse: 22.942
# [4500]	training's rmse: 19.8185	valid_1's rmse: 22.907
# [5000]	training's rmse: 19.6904	valid_1's rmse: 22.8587
# [5500]	training's rmse: 19.5708	valid_1's rmse: 22.8242
# [6000]	training's rmse: 19.4644	valid_1's rmse: 22.7946
# [6500]	training's rmse: 19.364	valid_1's rmse: 22.7687
# [7000]	training's rmse: 19.2692	valid_1's rmse: 22.7409
# [7500]	training's rmse: 19.1784	valid_1's rmse: 22.729
# [8000]	training's rmse: 19.0928	valid_1's rmse: 22.7147
# [8500]	training's rmse: 19.0102	valid_1's rmse: 22.6987
# [9000]	training's rmse: 18.93	valid_1's rmse: 22.6852
# [9500]	training's rmse: 18.8528	valid_1's rmse: 22.6687
# [10000]	training's rmse: 18.7792	valid_1's rmse: 22.6508
# [10500]	training's rmse: 18.7072	valid_1's rmse: 22.6444
# [11000]	training's rmse: 18.6372	valid_1's rmse: 22.6361
# [11500]	training's rmse: 18.5708	valid_1's rmse: 22.6264
# [12000]	training's rmse: 18.506	valid_1's rmse: 22.6192
# [12500]	training's rmse: 18.4428	valid_1's rmse: 22.6155
# Early stopping, best iteration is:
# [12352]	training's rmse: 18.4614	valid_1's rmse: 22.6123
# train_data nums: 186166, valid_data nums: 9775
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13455
# [LightGBM] [Info] Number of data points in the train set: 186166, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.009027 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.238306
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.9789	valid_1's rmse: 22.6295
# Early stopping, best iteration is:
# [724]	training's rmse: 22.3258	valid_1's rmse: 22.4396
# train_data nums: 186133, valid_data nums: 9808
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13444
# [LightGBM] [Info] Number of data points in the train set: 186133, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.009269 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.167310
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.976	valid_1's rmse: 22.8738
# [1000]	training's rmse: 21.8334	valid_1's rmse: 22.2008
# [1500]	training's rmse: 21.264	valid_1's rmse: 21.9365
# [2000]	training's rmse: 20.8872	valid_1's rmse: 21.7418
# [2500]	training's rmse: 20.6066	valid_1's rmse: 21.58
# [3000]	training's rmse: 20.3824	valid_1's rmse: 21.4715
# [3500]	training's rmse: 20.199	valid_1's rmse: 21.3866
# [4000]	training's rmse: 20.0382	valid_1's rmse: 21.3072
# [4500]	training's rmse: 19.8956	valid_1's rmse: 21.2488
# [5000]	training's rmse: 19.7666	valid_1's rmse: 21.2057
# [5500]	training's rmse: 19.647	valid_1's rmse: 21.1545
# [6000]	training's rmse: 19.5383	valid_1's rmse: 21.1184
# [6500]	training's rmse: 19.4363	valid_1's rmse: 21.0844
# [7000]	training's rmse: 19.3407	valid_1's rmse: 21.0608
# [7500]	training's rmse: 19.2504	valid_1's rmse: 21.0396
# [8000]	training's rmse: 19.1613	valid_1's rmse: 21.0154
# [8500]	training's rmse: 19.078	valid_1's rmse: 20.9828
# Early stopping, best iteration is:
# [8603]	training's rmse: 19.0608	valid_1's rmse: 20.978
# train_data nums: 186140, valid_data nums: 9801
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13451
# [LightGBM] [Info] Number of data points in the train set: 186140, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.008713 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.201698
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.9595	valid_1's rmse: 22.8753
# [1000]	training's rmse: 21.818	valid_1's rmse: 22.1147
# [1500]	training's rmse: 21.259	valid_1's rmse: 21.9577
# [2000]	training's rmse: 20.8848	valid_1's rmse: 21.8314
# [2500]	training's rmse: 20.6061	valid_1's rmse: 21.7444
# [3000]	training's rmse: 20.3857	valid_1's rmse: 21.7088
# [3500]	training's rmse: 20.2025	valid_1's rmse: 21.6729
# Early stopping, best iteration is:
# [3335]	training's rmse: 20.26	valid_1's rmse: 21.6652
# train_data nums: 186147, valid_data nums: 9794
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13448
# [LightGBM] [Info] Number of data points in the train set: 186147, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.008966 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.018386
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.9022	valid_1's rmse: 24.3629
# [1000]	training's rmse: 21.7658	valid_1's rmse: 23.5586
# [1500]	training's rmse: 21.2034	valid_1's rmse: 23.2409
# [2000]	training's rmse: 20.8236	valid_1's rmse: 23.0782
# [2500]	training's rmse: 20.5453	valid_1's rmse: 22.9581
# [3000]	training's rmse: 20.3264	valid_1's rmse: 22.8666
# [3500]	training's rmse: 20.1406	valid_1's rmse: 22.801
# [4000]	training's rmse: 19.9784	valid_1's rmse: 22.7575
# [4500]	training's rmse: 19.8302	valid_1's rmse: 22.7091
# [5000]	training's rmse: 19.7003	valid_1's rmse: 22.6725
# [5500]	training's rmse: 19.5802	valid_1's rmse: 22.631
# [6000]	training's rmse: 19.4692	valid_1's rmse: 22.5976
# [6500]	training's rmse: 19.366	valid_1's rmse: 22.5745
# [7000]	training's rmse: 19.2705	valid_1's rmse: 22.5558
# [7500]	training's rmse: 19.179	valid_1's rmse: 22.5275
# [8000]	training's rmse: 19.0912	valid_1's rmse: 22.5055
# [8500]	training's rmse: 19.0082	valid_1's rmse: 22.4872
# [9000]	training's rmse: 18.93	valid_1's rmse: 22.4708
# [9500]	training's rmse: 18.8543	valid_1's rmse: 22.4612
# [10000]	training's rmse: 18.7782	valid_1's rmse: 22.4392
# Early stopping, best iteration is:
# [10181]	training's rmse: 18.7522	valid_1's rmse: 22.4337
# train_data nums: 186175, valid_data nums: 9766
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 13439
# [LightGBM] [Info] Number of data points in the train set: 186175, number of used features: 62
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 62 dense feature groups (11.36 MB) transferred to GPU in 0.008781 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.121930
# Training until validation scores don't improve for 200 rounds
# [500]	training's rmse: 22.8577	valid_1's rmse: 26.5406
# [1000]	training's rmse: 21.7792	valid_1's rmse: 25.8448
# [1500]	training's rmse: 21.2274	valid_1's rmse: 25.5706
# [2000]	training's rmse: 20.856	valid_1's rmse: 25.3343
# [2500]	training's rmse: 20.5856	valid_1's rmse: 25.1821
# [3000]	training's rmse: 20.3662	valid_1's rmse: 25.0438
# [3500]	training's rmse: 20.1787	valid_1's rmse: 24.9433
# [4000]	training's rmse: 20.0155	valid_1's rmse: 24.8465
# [4500]	training's rmse: 19.8722	valid_1's rmse: 24.7699
# [5000]	training's rmse: 19.7437	valid_1's rmse: 24.7174
# [5500]	training's rmse: 19.6234	valid_1's rmse: 24.656
# [6000]	training's rmse: 19.5133	valid_1's rmse: 24.5915
# [6500]	training's rmse: 19.4096	valid_1's rmse: 24.5319
# [7000]	training's rmse: 19.3141	valid_1's rmse: 24.4885
# [7500]	training's rmse: 19.2223	valid_1's rmse: 24.4323
# [8000]	training's rmse: 19.1346	valid_1's rmse: 24.3931
# [8500]	training's rmse: 19.0495	valid_1's rmse: 24.3532
# [9000]	training's rmse: 18.9705	valid_1's rmse: 24.3247
# [9500]	training's rmse: 18.8933	valid_1's rmse: 24.2849
# [10000]	training's rmse: 18.8184	valid_1's rmse: 24.2675
# [10500]	training's rmse: 18.7473	valid_1's rmse: 24.2507
# [11000]	training's rmse: 18.6773	valid_1's rmse: 24.212
# [11500]	training's rmse: 18.6086	valid_1's rmse: 24.192
# [12000]	training's rmse: 18.543	valid_1's rmse: 24.1754
# Early stopping, best iteration is:
# [11806]	training's rmse: 18.5686	valid_1's rmse: 24.1735

# %%
viz_feature_importances(feature_importance)

# %%
oof_score = np.sqrt(mean_squared_error(train_oof["pm25_mid"], train_oof["oof"]))
oof_score = format(oof_score, ".3f")
print(f"oof score: {oof_score}")

# 22.162
# Out:
# oof score: 22.319

# %%
train_oof[["id","pm25_mid", "kfold", "oof"]].to_csv(os.path.join(OOF_DIR, "oof.csv"), index= False)

# %% [markdown]
# # predict

# %%
sum_predict = None
for model in models:
    predict = model.predict(
        test_df_[use_cols],
    )
    if sum_predict is None:
        sum_predict = predict
    else:
        sum_predict += predict

mean_predict = sum_predict / len(models)

# %%
print(len(mean_predict))
print(sample_df.shape)
print(test_df.shape)
# Out:
# 53509
# (53509, 2)
# (53509, 57)

# %%
sample_df.loc[:,"predict"] = mean_predict

# %%
sample_df.head()
# Out:
#        id     predict
# 0  195942   22.857743
# 1  195943   37.674790
# 2  195944   24.448794
# 3  195945   62.060218
# 4  195946  131.751733

# %%
sample_df.to_csv(os.path.join(SUB_DIR, "submission.csv"), index= False, header = False)

# %% [markdown]
# # submit

# %%
# !pip install signate > /dev/null
# !mkdir /root/.signate
# !cp /content/drive/MyDrive/signate/signate.json /root/.signate/signate.json
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.9 which is incompatible.
# google-colab 1.0.0 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.

# %%
submission_file = os.path.join(SUB_DIR, "submission.csv")

# %%
comment = f"cv:{oof_score}_" + NOTEBOOK_NAME
comment
# Out:
# 'cv:22.319_FP011-010-foldadd'

# %% [markdown]
# # Submit

# %%
# !signate submit --competition-id=624 {submission_file} --note {comment}
# Out:
# You have successfully submitted your predictions.We will send you the submission result to your email address.

# %% [markdown]
# https://signate.jp/competitions/624/submissions
