# %% [markdown]
# <a href="https://colab.research.google.com/github/seven320/air_pollutants/blob/main/FP049_047.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Env

# %%
# !nvidia-smi
# Out:
# Fri May 20 16:01:55 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os, sys
COLAB = "google.colab" in sys.modules

if COLAB:
    from google.colab import drive
    from google.colab import output
    drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
if COLAB:
    # !pip install transformers > /dev/null
    # !pip install einops > /dev/null
    # !pip install optuna > /dev/null
    # !pip install pyephem > /dev/null
    # !pip install timm > /dev/null
    # !pip install kaggle > /dev/null
    # !pip install kaggle_datasets > /dev/null
    # !pip install git+https://github.com/albumentations-team/albumentations
    # !pip install tensorflow-determinism
    # !pip install -q iterative-stratification
    # !pip install python-Levenshtein > /dev/null
    # !pip install geopy > /dev/null

    # for gpu
    # !git clone --recursive https://github.com/Microsoft/LightGBM
    # %cd /content/LightGBM/
    # !mkdir build
    # !cmake -DUSE_GPU=1 
    # !make -j$(nproc)
    # !sudo apt-get -y install python-pip

    # !sudo -H pip install setuptools pandas numpy scipy scikit-learn -U
    #pandasのエラーが出る場合は上記のコードからpandasを削除

    # !sudo -H pip install setuptools numpy scipy scikit-learn -U
    # %cd /content/LightGBM/python-package
    # !sudo python setup.py install --precompile

    output.clear()

# %%
import gc
import json
import math
import os
import random
import re
import time
import copy
import warnings
from requests import get
from contextlib import contextmanager
from typing import List, Optional, TypeVar, Type, Dict
import datetime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch
import torch.nn as nn
from pathlib import Path
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GroupKFold, train_test_split, KFold
from sklearn.preprocessing import RobustScaler, LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
# from einops.layers.torch import Rearrange, Reduce
# import timm
import Levenshtein
import ephem
from geopy.distance import geodesic
import pickle

from tqdm.notebook import tqdm
from transformers import AdamW, get_cosine_schedule_with_warmup
from typing import Optional, Tuple
from xgboost import XGBRegressor
import lightgbm as lgb
import optuna

# %%
warnings.simplefilter('ignore')

# %%
if COLAB:    
    NOTEBOOK_NAME = get('http://172.28.0.2:9000/api/sessions').json()[0]['name']
    print(NOTEBOOK_NAME)
# Out:
# FP049-047

# %%
COMPE_NAME = "air_pollutants"
BASE_DIR = f"/content/drive/MyDrive/signate/{COMPE_NAME}"

# KAGGLE ONLY HAS 1, BUT OFFLINE, YOU CAN USE MORE
os.environ["CUDA_VISIBLE_DEVICES"]="0" #0,1,2,3 for four gpu

# %%
if COLAB:
    INPUT_DIR = Path(os.path.join(BASE_DIR ,f"input"))
    INPUT_DIR.mkdir(exist_ok=True, parents=True)

    SAVE_DIR = Path(os.path.join(BASE_DIR ,f"models/{NOTEBOOK_NAME}"))
    SAVE_DIR.mkdir(exist_ok=True, parents=True)

    OOF_DIR = Path(os.path.join(BASE_DIR, f"oof/{NOTEBOOK_NAME}"))
    OOF_DIR.mkdir(exist_ok=True, parents = True)

    SUB_DIR = Path(os.path.join(BASE_DIR, f"submission/{NOTEBOOK_NAME}"))
    SUB_DIR.mkdir(exist_ok=True, parents = True)

# %%
train_df = pd.read_csv(os.path.join(INPUT_DIR, "train.csv"))
test_df = pd.read_csv(os.path.join(INPUT_DIR, "test.csv"))
sample_df = pd.read_csv(os.path.join(INPUT_DIR, "submit_sample.csv"), names=["id", "predict"])

print(train_df.shape, test_df.shape, sample_df.shape)
# Out:
# (195941, 54) (53509, 53) (53509, 2)

# %%
train_df
# Out:
#             id  year  month  day        Country          City       lat  \
# 0            1  2019      1    1      Australia      Brisbane -27.46794
# 1            2  2019      1    1      Australia        Darwin -12.46113
# 2            3  2019      1    1      Australia     Melbourne -37.81400
# 3            4  2019      1    1      Australia     Newcastle -32.92953
# 4            5  2019      1    1      Australia         Perth -31.95224
# ...        ...   ...    ...  ...            ...           ...       ...
# 195936  195937  2021     12   31  United States  Jacksonville  30.33218
# 195937  195938  2021     12   31  United States     Las Vegas  36.17497
# 195938  195939  2021     12   31  United States     Milwaukee  43.03890
# 195939  195940  2021     12   31        Vietnam         Hanoi  21.02450
# 195940  195941  2021     12   31        Vietnam       Hạ Long  20.95045
#
#               lon  co_cnt  co_min  ...  ws_min  ws_mid  ws_max  ws_var  \
# 0       153.02809      38   0.749  ...   0.241   1.088   3.101   1.983
# 1       130.84185      47   2.594  ...   0.828   3.473   7.396  10.411
# 2       144.96332      17   1.190  ...   0.000   2.107   8.089  15.719
# 3       151.78010      63   4.586  ...   0.284   0.503   3.592   2.485
# 4       115.86140      47   4.689  ...   0.500   0.755   3.396   1.937
# ...           ...     ...     ...  ...     ...     ...     ...     ...
# 195936  -81.65565      12   0.694  ...   2.195   2.710   6.125   3.757
# 195937 -115.13722      14   0.528  ...   1.002   2.974   6.861   8.354
# 195938  -87.90647     171   1.975  ...   0.994   1.087   2.578   0.612
# 195939  105.84117      31   2.613  ...   1.005   3.058   6.005   6.085
# 195940  107.07336      26   0.069  ...   0.190   2.775   3.412   2.528
#
#         dew_cnt  dew_min  dew_mid  dew_max  dew_var  pm25_mid
# 0            17    7.671   10.358   15.112   13.424    19.901
# 1            62   21.324   23.813   24.221    2.021    13.741
# 2            22   10.309   13.133   15.422    6.355    25.918
# 3           116    7.146   10.685   13.344    9.417   174.370
# 4            93    1.091    3.277   12.272    4.109   167.063
# ...         ...      ...      ...      ...      ...       ...
# 195936       12   16.774   22.679   26.058   13.252    16.150
# 195937       12   10.432   14.741   15.827    7.078    16.895
# 195938       26    2.049    3.531    6.686    5.286    86.299
# 195939       51    1.922    7.443    7.716    4.642    36.523
# 195940       16    8.448   10.372   18.886   11.536    62.021
#
# [195941 rows x 54 columns]

# %% [markdown]
# ## pseude label

# %%
oof_df = pd.read_csv(os.path.join(BASE_DIR, "oof", "FP046-043", "oof.csv"))
submit_df = pd.read_csv(os.path.join(BASE_DIR, "submission", "FP046-043", "submission.csv"), names = ["id", "pm25_mid"])

# %%
oof_df_ = oof_df.rename(columns = {"oof":"pseude_pm25_mid"})
submit_df_ = submit_df.rename(columns = {"pm25_mid":"pseude_pm25_mid"})

# %% [markdown]
# ## add city population

# %%
# population_df = pd.read_csv(os.path.join(INPUT_DIR, "city_population.csv"))
# population_df["City"] = population_df["Name"]

# %%
# # 同じ都市名かつ国名のものを削除する
# population_df["CC"] = population_df["Country"] + population_df["City"]
# population_df["CC"].value_counts()
# for k, v in population_df["CC"].value_counts().items():
#     # print(k, v)
#     if v > 1:
#         print(f"{k} の行を削除")
#         population_df = population_df[population_df["CC"] != k]

# %%
# def df_to_country_dict(df: pd.DataFrame) -> Dict:
#     country_city = {}

#     for t_c in set(df["Country"].tolist()):
#         country_city[t_c] = []

#     for country, city in zip(df["Country"], df["City"]):
#         country_city[country].append(city)

#     for k, v in country_city.items():
#         country_city[k] = set(v)

#     return country_city

# %%
# train_country_city = df_to_country_dict(pd.concat([train_df, test_df]))

# p_country_city = df_to_country_dict(population_df)

# %%
# def cal_leven(str1: str, str2: str) -> float:
#     # レーベンシュタイン距離の取得
#     lev_dist = Levenshtein.distance(str1, str2)
#     # 標準化(長い方の文字列の長さで割る)
#     divider = len(str1) if len(str1) > len(str2) else len(str2)
#     lev_dist = lev_dist / divider
#     # 指標を合わせる(0:完全不一致 → 1:完全一致)
#     return 1 - lev_dist

# %%
# city_pairs = {}

# for t_k, t_values in train_country_city.items():
#     for p_k, p_values in p_country_city.items():
#         # countryが一致
#         if t_k != p_k:
#             continue
#         for t_v in t_values:
#             max_score = -1
#             for p_v in p_values:
#                 score = cal_leven(t_v, p_v)
#                 if max_score < score:
#                     pairs = [t_v, p_v]
#                     max_score = score

#             if max_score > 0.8:
#                 city_pairs[pairs[1]] = pairs[0]
# print(f"pair cities:{len(city_pairs)}")

# %%
# a = population_df["City"]
# for key, value in city_pairs.items():
#     # print(key, value)
#     a = copy.deepcopy(a.replace(key, value))

# population_df["City"] = a

# %%
# if not "Prev" in train_df.columns:
#     train_df = train_df.merge(population_df[["rank", "City", "Country", "Population", "Prev", "Growth"]], on = ["City", "Country"], how="left")
#     test_df = test_df.merge(population_df[["rank", "City", "Country",  "Population", "Prev", "Growth"]], on = ["City", "Country"], how="left")

# assert len(test_df) == len(sample_df)

# %% [markdown]
# ## add target encode

# %%
if not "target_count" in train_df.columns:
    target_df = train_df[["Country", "pm25_mid"]].groupby("Country", as_index = 1).describe()

    target_df = target_df.rename(columns = {
        "count": "target_count",
        "mean": "target_mean",
        "std": "target_std",
        "25%": "target_25%",
        "50%": "target_50%",
        "75%": "target_75%",
        "max": "target_max"
    }).reset_index()
    train_df = train_df.merge(pd.concat([target_df["Country"], target_df["pm25_mid"]], axis = 1), on = "Country", how = "left")
    test_df = test_df.merge(pd.concat([target_df["Country"], target_df["pm25_mid"]], axis = 1), on = "Country", how = "left")

# %% [markdown]
# ### add days

# %% [markdown]
# ## 都市を近い順に入力(上位15)

# %%
use_city = 5

# %%
# 全ての都市を抽出
all_df = pd.concat([train_df, test_df])
lat_lons = all_df[["City", "lat", "lon"]].drop_duplicates()

train_cities = train_df["City"].unique()
test_cities = test_df["City"].unique()
all_cities = all_df["City"].unique()

# %%
 # 各都市ごとの距離を格納
 #
#  nearest_cities = {
#       City1 = {
            # City2: 500km
            # City3: 1000km
# }
# } 

nearest_cities = {}
for i in tqdm(range(len(lat_lons))):
    City1, lat1, lon1 = lat_lons.iloc[i]
    pos1 = np.array([lat1, lon1])
    
    nearest_city = {}
    for j in range(len(lat_lons)):
        if i == j:
            continue
        
        City2, lat2, lon2 = lat_lons.iloc[j]
        pos2 = np.array([lat2, lon2])
        
        dis = geodesic(pos1, pos2)
        
        nearest_city[City2] = dis

    nearest_cities[City1] = nearest_city
# Out:
#   0%|          | 0/302 [00:00<?, ?it/s]

# %%
target_en_bycities = train_df[["City","month", "pm25_mid"]].groupby(["City", "month"], as_index = 0).agg("mean").reset_index(drop=True)

# %%
nearest_sort_cities = []

for city1 in nearest_cities.keys():
    nearest_sort_city = dict(sorted(nearest_cities[city1].items(), key = lambda item: item[1])).keys()
    nearest_sort_cities.append([city1] + list(nearest_sort_city)[:use_city])

# %%
target_en_bycities_detail = train_df[["City","year", "month","day", "pm25_mid"]].groupby(["City", "year", "month", "day"], as_index = 0).agg("mean").reset_index(drop=True)

# %%
# cities = pd.DataFrame(target_en_bycities_detail["City"].unique(), columns = ["City"])
cities = pd.DataFrame(all_df["City"].unique(), columns=["City"])
year_month_day = target_en_bycities_detail.groupby(["year", "month", "day"], as_index=0).agg("mean")[["year", "month", "day"]]

city_year_month_day = pd.merge(cities, year_month_day, how = "cross")

# %%
target_en = pd.merge(city_year_month_day, target_en_bycities_detail, on = ["City", "year", "month", "day"], how = "left")
target_en_fillna = pd.merge(target_en, target_en_bycities, on = ["City", "month"], how = "left")
target_en_fillna["pm25_mid"] = target_en_fillna["pm25_mid_x"].combine_first(target_en_fillna["pm25_mid_y"])

target_en_fillna = target_en_fillna.drop(columns = ["pm25_mid_x", "pm25_mid_y"])

# %%
# Config
NUM_FOLDS = 5

# %%
#############
## Utility ##
#############
@contextmanager
def timer(name: str):
    t0 = time.time()
    print(f"[{name}] start")
    yield
    print(f"[{name}] done - elapsed {time.time() - t0:.2f}s")

# %%
def seed_everything(seed):
    """
    Seeds basic parameters for reproductibility of results
    
    Arguments:
        seed {int} -- Number of the seed
    """
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def set_seed(seed):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(42)

# %%
train_df.head()
# Out:
#    id  year  month  day    Country       City       lat        lon  co_cnt  \
# 0   1  2019      1    1  Australia   Brisbane -27.46794  153.02809      38
# 1   2  2019      1    1  Australia     Darwin -12.46113  130.84185      47
# 2   3  2019      1    1  Australia  Melbourne -37.81400  144.96332      17
# 3   4  2019      1    1  Australia  Newcastle -32.92953  151.78010      63
# 4   5  2019      1    1  Australia      Perth -31.95224  115.86140      47
#
#    co_min  ...  dew_var  pm25_mid  target_count  target_mean  target_std  min  \
# 0   0.749  ...   13.424    19.901        5656.0    37.362265   25.919644  0.0
# 1   2.594  ...    2.021    13.741        5656.0    37.362265   25.919644  0.0
# 2   1.190  ...    6.355    25.918        5656.0    37.362265   25.919644  0.0
# 3   4.586  ...    9.417   174.370        5656.0    37.362265   25.919644  0.0
# 4   4.689  ...    4.109   167.063        5656.0    37.362265   25.919644  0.0
#
#    target_25%  target_50%  target_75%  target_max
# 0      19.526     28.6445    52.50325     189.517
# 1      19.526     28.6445    52.50325     189.517
# 2      19.526     28.6445    52.50325     189.517
# 3      19.526     28.6445    52.50325     189.517
# 4      19.526     28.6445    52.50325     189.517
#
# [5 rows x 62 columns]

# %%
train_city = train_df["City"].unique().tolist()
test_city = test_df["City"].unique().tolist()

train_city_cnt = len(train_city)
test_city_cnt = len(test_city)

print(f"train city count: {train_city_cnt}")
print(f"test city count: {test_city_cnt}")

print(f"{len(set(train_city) & set(test_city))}")
# Out:
# train city count: 239
# test city count: 63
# 0

# %%
kf = GroupKFold(n_splits = NUM_FOLDS)

if not "kfold" in train_df.columns:
    folds = copy.deepcopy(train_df[["id"]])
    folds["kfold"] = -1

    for fold, (train_idx, valid_idx) in enumerate(kf.split(train_df, train_df["pm25_mid"], train_df["City"])):
        print(f"train_idx: {len(train_idx)}, valid_idx: {len(valid_idx)}")
        folds.loc[valid_idx, "kfold"] = fold

    train_df = train_df.merge(folds[["id", "kfold"]], on="id", how="left")
# Out:
# train_idx: 156755, valid_idx: 39186
# train_idx: 156758, valid_idx: 39183
# train_idx: 156760, valid_idx: 39181
# train_idx: 156730, valid_idx: 39211
# train_idx: 156761, valid_idx: 39180

# %% [markdown]
# # Train

# %%
import logging
from typing import List, Optional, TypeVar

import pandas as pd

class AbstractFeatureTransformer:
    def __init__(self):
        self.name = self.__class__.__name__

    def fit_transform(self, input_df: pd.DataFrame, y=None):
        self.fit(input_df, y)
        return self.transform(input_df)

    def fit(self, input_df: pd.DataFrame, y=None):
        pass

    def transform(self, input_df: pd.DataFrame) -> pd.DataFrame:
        raise NotImplementedError

Transformer = TypeVar("Transformer", bound=AbstractFeatureTransformer)

def extract_features(input_df: pd.DataFrame,
                     transformers: List[Transformer],
                     fit: bool = True,
                     logger: Optional[logging.Logger] = None):
    feature_dfs = []
    for transformer in transformers:
        # timerはブロックの実行時間を計測するユーティリティ
        with timer(f"Extract features with {transformer.name}", logger):
            if fit:
                feature_dfs.append(transformer.fit_transform(input_df))
            else:
                feature_dfs.append(transformer.transform(input_df))
    all_features = pd.concat(feature_dfs, axis=1)
    return all_features

# %%
class Numericals(AbstractFeatureTransformer):
    def transform(self, input_df: pd.DataFrame) -> pd.DataFrame:
        cols = [pd.api.types.is_numeric_dtype(dtype) for dtype in input_df.dtypes]
        return input_df.loc[:, cols]

class LabelEncoding(AbstractFeatureTransformer):
    def __init__(self, columns: List[str]):
        super().__init__()
        self.le_columns = columns
        self.encoders = {
            column: LabelEncoder()
            for column in self.le_columns
        }
        self.__is_fitted = False

    def fit(self, input_df: pd.DataFrame, y: Optional[np.ndarray] = None):
        """
        ラベルに変換する前に欠損値を埋める
        """
        for column in self.le_columns:
            self.encoders[column].fit(input_df[column].fillna(""))
        self.__is_fitted = True

    def transform(
        self, 
        input_df: pd.DataFrame, 
        y: Optional[np.ndarray] = None
    ) -> pd.DataFrame:
        assert self.__is_fitted, "You need to call `fit` first."
        encoded = {}
        for column in self.le_columns:
            encoded[column] = self.encoders[column].transform(
                input_df[column].fillna(""))
        return pd.DataFrame(encoded)

# %%
def preprocess_all(train_df:pd.DataFrame, test_df:pd.DataFrame)->pd.DataFrame:
    all_df = pd.concat([train_df, test_df])

    mids = ["co_mid", "o3_mid", "so2_mid", "no2_mid", "temperature_mid", "humidity_mid", "pressure_mid", "ws_mid", "dew_mid", 
            "co_max", "o3_max", "so2_max", "no2_max", "temperature_max", "humidity_max", "pressure_max", "ws_max", "dew_max"]
    cnt = 1
    for i in range(len(mids)):
        if f"scaled_{mids[i]}" in train_df.columns:
            break
        scaler = MinMaxScaler()
        scaler.fit(all_df[[mids[i]]])
        train_df[f"scaled_{mids[i]}"] = scaler.transform(train_df[[mids[i]]])
        test_df[f"scaled_{mids[i]}"] = scaler.transform(test_df[[mids[i]]])
        cnt += 1
    print("min max scaler")

    return train_df, test_df

# %%
def preprocess(df:pd.DataFrame)->pd.DataFrame:
    df_ = copy.deepcopy(df)
    # 年月/年月日を追加

    df_["year_month"] = df_["year"].astype("str") + df_["month"].astype("str")
    df_["year_month_day"] = df_["year"].astype("str") + df_["month"].astype("str") + df_["day"].astype("str")
    df_["month_day"] = df_["month"].astype("str") + df_["day"].astype("str")

    # 月日国/月日都市を追加
    df_["month_day_country"] = df_["month"].astype("str") + df_["day"].astype("str") + df_["Country"].astype("str") 
    df_["month_day_city"] =  df_["month"].astype("str") + df_["day"].astype("str") + df_["City"].astype("str") 

    # 経度をcosに変換
    cnt = 0

    if not "lon_cos" in df_.columns:
        df_["lon_cos"] = np.cos(np.radians((df_["lon"] + 180)))
        df_["lon_sin"] = np.sin(np.radians((df_["lon"] + 180)))
        df_["month_cos"] = np.cos(np.radians(df_["month"] / 12 * 360))
        df_["month_sin"] = np.sin(np.radians(df_["month"] / 12 * 360))
        print("add lon_cos, lon_sin, month_cos, month_sin")
        cnt += 4

    # 四則演算

    # 南半球を北半球のmonthに変更
    if not "month_world" in df_.columns:
        df_["month_world"] = df_["month"]
        df_.loc[df_["lat"] < 0, "month_world"] = df_["month"] + 6
        df_.loc[df_["month_world"] > 12, "month_world"] = df_["month"] - 6
        print("add month_world")
        cnt += 1
    # mid同士を4則
    columns = df_.columns
    mids = []
    for c in columns:
        if "_mid" in c and c != "pm25_mid":
            mids.append(c)

    # 曜日を追加
    def _cal_sun_time(lat:float, lon:float, year:float, month:float, day: float)->float:
        location = ephem.Observer()
        location.lat = str(lat)
        location.lon = str(lon)
        sun = ephem.Sun()

        location.date = datetime.date(year = int(year), month = int(month), day = int(day))
        sun_time_tmp1 = ephem.localtime(location.next_rising(sun)) - ephem.localtime(location.next_setting(sun))
        sun_time_tmp2 = ephem.localtime(location.next_setting(sun)) - ephem.localtime(location.next_rising(sun))

        sun_time = max(sun_time_tmp1.seconds, sun_time_tmp2.seconds)

        return sun_time
    if not "sun_time" in df_.columns:
        u_cols = ["lat", "lon", "year", "month", "day"]

        df_["sun_time"] = -1
        df_["week"] = -1

        mini_df = df_[u_cols]

        sun_time = np.zeros(len(df_))
        weeks = np.zeros(len(df_))
        for i in tqdm(range(len(mini_df))):
            lat, lon, year, month, day = mini_df.iloc[i]
            sun_time[i] = _cal_sun_time(lat, lon, year, month, day)

            # 曜日
            date = datetime.date(int(year), int(month), int(day))
            weeks[i] = date.weekday()

        df_["sun_time"] = sun_time
        df_["week"] = weeks

        print("add sun_time, weeks")
    cnt += 2

    mids = ["co_mid", "o3_mid", "so2_mid", "no2_mid", "temperature_mid", "humidity_mid", "pressure_mid", "ws_mid", "dew_mid"]
    for i in range(len(mids)):
        for j in range(i):
            mid0, mid1 = mids[i], mids[j]
            df_[f"{mid0}+{mid1}"] = df_[mid0] + df_[mid1]

            cnt += 1
    print("add mids + cal")
    scaled_mids = ["scaled_co_mid", "scaled_o3_mid", "scaled_so2_mid", "scaled_no2_mid"]
    for i in range(len(scaled_mids)):
        for j in range(i):
            mid0, mid1 = scaled_mids[i], scaled_mids[j]
            df_[f"{mid0}+{mid1}"] = df_[mid0] + df_[mid1]
            cnt += 1
            for k in range(j):
                mid2 = scaled_mids[k]
                df_[f"{mid0}+{mid1}+{mid2}"] = df_[mid0] + df_[mid1] + df_[mid2]
                cnt += 1
                for l in range(k):
                    mid3 = scaled_mids[l]
                    df_[f"{mid0}+{mid1}+{mid2}+{mid3}"] = df_[mid0] + df_[mid1] + df_[mid2] + df_[mid3]
                    cnt += 1
    print("add scaled mids")

    maxs = ["co_max", "o3_max", "so2_max", "no2_max", "temperature_max", "humidity_max", "pressure_max", "ws_max", "dew_max"]
    for i in range(len(maxs)):
        for j in range(i):
            max0, max1 = maxs[i], maxs[j]
            df_[f"{max0}+{max1}"] = df_[max0] + df_[max1]

    scaled_maxs = ["scaled_co_max", "scaled_o3_max", "scaled_so2_max", "scaled_no2_max"]
    for i in range(len(scaled_maxs)):
        for j in range(i):
            max0, max1 = scaled_maxs[i], scaled_maxs[j]
            df_[f"{max0}+{max1}"] = df_[max0] + df_[max1]
            cnt += 1
            for k in range(j):
                max2 = scaled_maxs[k]
                df_[f"{max0}+{max1}+{max2}"] = df_[max0] + df_[max1] + df_[max2]
                cnt += 1
                for l in range(k):
                    max3 = scaled_maxs[l]
                    df_[f"{max0}+{max1}+{max2}+{max3}"] = df_[max0] + df_[max1] + df_[max2] + df_[max3]
                    cnt += 1
    print("add scaled maxs")

    print(f"add {cnt} columns")

    return df_

# %%
class AbstractTreeModel:
    def __init__(self, prediction_type="regression"):
        self.model = None
        self.prediction_type = prediction_type

    def train(self,
              params: dict,
              X_train: pd.DataFrame,
              y_train: np.ndarray,
              X_val: pd.DataFrame,
              y_val: np.ndarray,
              train_weights: Optional[np.ndarray] = None,
              val_weights: Optional[np.ndarray] = None,
              train_params: Optional[dict] = None):
        if train_params is None:
            train_params = {}

        model = self._train(
            params,
            X_train, y_train,
            X_val, y_val,
            train_weights, val_weights,
            train_params)
        self.model = model
        return self

    def _train(self,
               params,
               X_train,
               y_train,
               X_val,
               y_val,
               train_weights,
               val_weights,
               train_params):
        raise NotImplementedError

    def predict(self, X: pd.DataFrame) -> np.ndarray:
        raise NotImplementedError

    @property
    def feature_names_(self):
        raise NotImplementedError

    @property
    def feature_importances_(self):
        raise NotImplementedError

    def _check_if_trained(self):
        assert self.model is not None, "You need to train the model first"

class LGBModel(AbstractTreeModel):
    def _train(self,
               params,
               X_train, y_train,
               X_val, y_val,
               train_weights, val_weights,
               train_params):
        trn_data = lgb.Dataset(X_train, y_train, weight=train_weights)
        val_data = lgb.Dataset(X_val, y_val, weight=val_weights)
        model = lgb.train(params=params,
                          train_set=trn_data,
                          valid_sets=[trn_data, val_data],
                          **train_params,)
                        #   verbose_eval=False)
        return model

    def predict(self, X: pd.DataFrame) -> np.ndarray:
        self._check_if_trained()
        return self.model.predict(X, num_iteration=self.model.best_iteration)

    @property
    def feature_names_(self):
        self._check_if_trained()
        return self.model.feature_name()

    @property
    def feature_importances_(self):
        self._check_if_trained()
        return self.model.feature_importance(importance_type="gain")

def get_tree_model(name: str) -> Type[AbstractTreeModel]:
    DEFINED_MODELS = {
        "lgb": LGBModel,
        # 実装していない
        # "xgb": XGBModel,
        # "cat": CatBoostModel
    }
    model = DEFINED_MODELS.get(name)
    if model is None:
        raise ValueError(
            """Invalid model name: {}.
            Pre-defined model names are as follows: {}""".format(
                name,
                ",".join(DEFINED_MODELS.keys())
            ))
    return model

# %%
def viz_feature_importances(feature_importances: pd.DataFrame)-> None:
    fi_gby = feature_importances.groupby("feature").agg({
        "importance": ["mean", "std"]
    }).sort_values(("importance", "mean"), ascending=0).index
    plt.figure(figsize=(30, 20))

    sns.barplot(x="importance", y="feature", data=feature_importances, order=fi_gby)

    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.show()

# %%
train_params = {
    "num_boost_round": 30000,
    "callbacks": [
                  lgb.early_stopping(stopping_rounds= 500, verbose=True),
                  lgb.log_evaluation(period = 3000)
    ]
}

# %%
num_cols = [c for c in train_df.columns if train_df[c].dtype != np.object]
if "id" in num_cols:
    num_cols.remove("id")
if "kfold" in num_cols:
    num_cols.remove("kfold")
num_cols.remove("pm25_mid")

target_cols = "pm25_mid"

# %%
train_df0, test_df0 = preprocess_all(train_df, test_df)

train_df1 = preprocess(train_df0)
test_df1 = preprocess(test_df0)
# Out:
# min max scaler
# add lon_cos, lon_sin, month_cos, month_sin
# add month_world
#   0%|          | 0/195941 [00:00<?, ?it/s]
# add sun_time, weeks
# add mids + cal
# add scaled mids
# add scaled maxs
# add 65 columns
# add lon_cos, lon_sin, month_cos, month_sin
# add month_world
#   0%|          | 0/53509 [00:00<?, ?it/s]
# add sun_time, weeks
# add mids + cal
# add scaled mids
# add scaled maxs
# add 65 columns

# %%
# all_df1 = pd.concat([train_df1, test_df1])

# after_before_cs = ["year", "month", "day", "co_mid", "o3_mid", "so2_mid", "no2_mid", "temperature_mid", "humidity_mid", "pressure_mid", "ws_mid", "dew_mid",
#             "scaled_no2_mid+scaled_so2_mid+scaled_co_mid"]

# today_df = pd.merge(city_year_month_day, 
#             all_df1[after_before_cs + ["City"]],
#             on=["City", "year", "month", "day"], how = "left")

# daybefore_df= today_df.groupby(["City"]).shift()
# dayafter_df = today_df.groupby(["City"]).shift(-1)

# columns_dic = {}
# daybefore_cs = []
# for c in after_before_cs:
#     columns_dic[c] = f"1dbefore_{c}"
#     daybefore_cs.append(f"1dbefore_{c}")

# daybefore_df = daybefore_df.rename(columns = columns_dic)

# columns_dic = {}
# dayafter_cs = []
# for c in after_before_cs:
#     columns_dic[c] = f"1dafter_{c}"
#     dayafter_cs.append(f"1dafter_{c}")

# dayafter_df = dayafter_df.rename(columns = columns_dic)

# beforeafterday_df = pd.concat([today_df[["City", "year", "month", "day"]], daybefore_df[daybefore_cs], dayafter_df[dayafter_cs]], axis =1)

# %%
IDW_ps = [1, 1.2, 1.5, 2]
days = [-2, -1, 0, 1, 2]

# %%
cat_cols = ["Country", "City", "year_month", "year_month_day", "month_day", "month_day_city", "month_day_country", "nearest_city"] 

day_columns = ["co_mid", "o3_mid", "so2_mid", "no2_mid", "temperature_mid", "humidity_mid", "pressure_mid", "ws_mid", "dew_mid"] + \
["scaled_no2_mid+scaled_so2_mid+scaled_o3_mid+scaled_co_mid", "scaled_co_mid", "so2_mid+co_mid"] + \
["nearest_pm25_mid", ] + \
[f"IDW_p{p}_pm25_mid" for p in IDW_ps] 

num_cols = list(set(train_df1.columns) - set(cat_cols + ["pm25_mid", "kfold", "id", "year"])) + \
 ["nearest_pm25_mid"] + \
[f"dis{i}km_pm25_mid" for i in [100, 300, 500, 1000]] +\
[f"IDW_p{p}_pm25_mid" for p in IDW_ps] \
# + ["pseude_pm25_mid"]

for day in days:
    for day_column in day_columns:
        if day == 0:
            continue
        num_cols += [f"{day}d_{day_column}"]

use_cols = num_cols + cat_cols

# %%
for c in use_cols:
    print(c)
# Out:
# pressure_mid+no2_mid
# ws_cnt
# ws_mid+pressure_mid
# target_50%
# o3_max
# humidity_min
# pressure_var
# scaled_o3_mid
# humidity_mid+no2_mid
# scaled_no2_mid
# pressure_cnt
# scaled_humidity_mid
# dew_max+temperature_max
# co_var
# lon_sin
# scaled_so2_max+scaled_o3_max
# scaled_o3_mid+scaled_co_mid
# so2_max+co_max
# no2_max+co_max
# o3_max+co_max
# so2_mid
# humidity_max+o3_max
# target_mean
# scaled_no2_mid+scaled_so2_mid
# ws_mid+temperature_mid
# temperature_cnt
# week
# dew_max
# temperature_max+co_max
# temperature_var
# humidity_mid+so2_mid
# temperature_mid+co_mid
# pressure_max+o3_max
# no2_max+o3_max
# target_std
# scaled_no2_max+scaled_so2_max+scaled_o3_max+scaled_co_max
# pressure_mid+humidity_mid
# humidity_mid+temperature_mid
# pressure_mid+so2_mid
# pressure_max+so2_max
# scaled_no2_mid+scaled_so2_mid+scaled_co_mid
# scaled_no2_max+scaled_o3_max+scaled_co_max
# co_max
# humidity_mid+co_mid
# lon
# co_mid
# o3_var
# pressure_max+temperature_max
# dew_max+ws_max
# scaled_so2_max+scaled_co_max
# no2_mid
# dew_max+no2_max
# so2_mid+o3_mid
# dew_max+humidity_max
# target_count
# scaled_so2_mid+scaled_co_mid
# ws_mid+so2_mid
# humidity_max
# scaled_no2_max+scaled_so2_max+scaled_co_max
# humidity_cnt
# day
# ws_mid
# sun_time
# temperature_max+no2_max
# dew_mid+no2_mid
# scaled_humidity_max
# scaled_no2_mid+scaled_so2_mid+scaled_o3_mid
# ws_max+pressure_max
# so2_max
# temperature_max+o3_max
# target_25%
# temperature_min
# scaled_ws_mid
# scaled_so2_max+scaled_o3_max+scaled_co_max
# no2_max+so2_max
# pressure_max+co_max
# pressure_max
# target_max
# o3_mid+co_mid
# scaled_dew_max
# dew_mid
# scaled_so2_mid
# ws_max+no2_max
# scaled_no2_max+scaled_co_max
# pressure_min
# scaled_so2_mid+scaled_o3_mid+scaled_co_mid
# scaled_no2_max+scaled_so2_max
# ws_var
# temperature_mid+no2_mid
# no2_mid+co_mid
# no2_mid+o3_mid
# lat
# temperature_mid+o3_mid
# ws_max+co_max
# pressure_mid
# humidity_mid+o3_mid
# dew_mid+temperature_mid
# dew_var
# so2_min
# scaled_co_mid
# scaled_dew_mid
# humidity_var
# dew_mid+so2_mid
# humidity_max+co_max
# dew_max+o3_max
# pressure_mid+temperature_mid
# humidity_max+temperature_max
# no2_max
# scaled_o3_max+scaled_co_max
# scaled_no2_max+scaled_so2_max+scaled_o3_max
# ws_min
# month_cos
# ws_mid+no2_mid
# so2_mid+co_mid
# no2_mid+so2_mid
# o3_min
# co_min
# month_sin
# pressure_mid+o3_mid
# temperature_max
# temperature_mid+so2_mid
# ws_mid+o3_mid
# no2_var
# lon_cos
# scaled_co_max
# scaled_no2_mid+scaled_so2_mid+scaled_o3_mid+scaled_co_mid
# ws_max+humidity_max
# ws_max+so2_max
# dew_max+pressure_max
# pressure_max+no2_max
# dew_mid+o3_mid
# ws_mid+co_mid
# scaled_ws_max
# pressure_max+humidity_max
# scaled_no2_mid+scaled_o3_mid
# target_75%
# scaled_so2_max
# temperature_mid
# dew_cnt
# dew_mid+co_mid
# scaled_no2_mid+scaled_co_mid
# scaled_no2_mid+scaled_o3_mid+scaled_co_mid
# month
# humidity_mid
# dew_mid+pressure_mid
# scaled_temperature_mid
# dew_min
# humidity_max+so2_max
# so2_cnt
# scaled_no2_max
# ws_max+o3_max
# dew_mid+ws_mid
# no2_cnt
# scaled_pressure_mid
# pressure_mid+co_mid
# ws_max
# temperature_max+so2_max
# dew_max+so2_max
# humidity_max+no2_max
# o3_mid
# scaled_so2_mid+scaled_o3_mid
# min
# scaled_pressure_max
# ws_mid+humidity_mid
# dew_max+co_max
# so2_max+o3_max
# dew_mid+humidity_mid
# scaled_no2_max+scaled_o3_max
# o3_cnt
# co_cnt
# scaled_o3_max
# scaled_temperature_max
# so2_var
# no2_min
# month_world
# ws_max+temperature_max
# nearest_pm25_mid
# dis100km_pm25_mid
# dis300km_pm25_mid
# dis500km_pm25_mid
# dis1000km_pm25_mid
# IDW_p1_pm25_mid
# IDW_p1.2_pm25_mid
# IDW_p1.5_pm25_mid
# IDW_p2_pm25_mid
# -2d_co_mid
# -2d_o3_mid
# -2d_so2_mid
# -2d_no2_mid
# -2d_temperature_mid
# -2d_humidity_mid
# -2d_pressure_mid
# -2d_ws_mid
# -2d_dew_mid
# -2d_scaled_no2_mid+scaled_so2_mid+scaled_o3_mid+scaled_co_mid
# -2d_scaled_co_mid
# -2d_so2_mid+co_mid
# -2d_nearest_pm25_mid
# -2d_IDW_p1_pm25_mid
# -2d_IDW_p1.2_pm25_mid
# -2d_IDW_p1.5_pm25_mid
# -2d_IDW_p2_pm25_mid
# -1d_co_mid
# -1d_o3_mid
# -1d_so2_mid
# -1d_no2_mid
# -1d_temperature_mid
# -1d_humidity_mid
# -1d_pressure_mid
# -1d_ws_mid
# -1d_dew_mid
# -1d_scaled_no2_mid+scaled_so2_mid+scaled_o3_mid+scaled_co_mid
# -1d_scaled_co_mid
# -1d_so2_mid+co_mid
# -1d_nearest_pm25_mid
# -1d_IDW_p1_pm25_mid
# -1d_IDW_p1.2_pm25_mid
# -1d_IDW_p1.5_pm25_mid
# -1d_IDW_p2_pm25_mid
# 1d_co_mid
# 1d_o3_mid
# 1d_so2_mid
# 1d_no2_mid
# 1d_temperature_mid
# 1d_humidity_mid
# 1d_pressure_mid
# 1d_ws_mid
# 1d_dew_mid
# 1d_scaled_no2_mid+scaled_so2_mid+scaled_o3_mid+scaled_co_mid
# 1d_scaled_co_mid
# 1d_so2_mid+co_mid
# 1d_nearest_pm25_mid
# 1d_IDW_p1_pm25_mid
# 1d_IDW_p1.2_pm25_mid
# 1d_IDW_p1.5_pm25_mid
# 1d_IDW_p2_pm25_mid
# 2d_co_mid
# 2d_o3_mid
# 2d_so2_mid
# 2d_no2_mid
# 2d_temperature_mid
# 2d_humidity_mid
# 2d_pressure_mid
# 2d_ws_mid
# 2d_dew_mid
# 2d_scaled_no2_mid+scaled_so2_mid+scaled_o3_mid+scaled_co_mid
# 2d_scaled_co_mid
# 2d_so2_mid+co_mid
# 2d_nearest_pm25_mid
# 2d_IDW_p1_pm25_mid
# 2d_IDW_p1.2_pm25_mid
# 2d_IDW_p1.5_pm25_mid
# 2d_IDW_p2_pm25_mid
# Country
# City
# year_month
# year_month_day
# month_day
# month_day_city
# month_day_country
# nearest_city

# %% [markdown]
# #### for tuning

# %%
models = []

train_df_ = copy.deepcopy(train_df1)
test_df_ = copy.deepcopy(test_df1)

oof_df = train_df_[["id"]]
oof_df["oof"] = -1

from lightgbm import early_stopping
from lightgbm import log_evaluation

target_en_dic_bycity = {}
part_target_en_fillna = target_en_fillna[["City", "year", "month", "day", "pm25_mid"]]
for city in tqdm(part_target_en_fillna["City"].unique()):
    target_en_dic_bycity[city] = part_target_en_fillna.query(f"City == '{city}'")["pm25_mid"].values 

for i in range(NUM_FOLDS):
    model = get_tree_model("lgb")()
    train_data = train_df_[train_df_["kfold"] != i].reset_index(drop = True)
    valid_data = train_df_[train_df_["kfold"] == i].reset_index(drop = True)
    print("-" * 5 + f"FOLD {i + 1}/{NUM_FOLDS}" + "-"*5)
    print(f"train_data nums: {len(train_data)}, valid_data nums: {len(valid_data)}")

    # fold内での最近傍を探す
    train_data = train_df_[train_df_["kfold"] != i].reset_index(drop = True)
    print(len(train_data["City"].unique()))

    # 同じfoldの中で最近傍な都市があった場合はその年のtarget_encodingを実施
    # nearest_city_fold_df = copy.deepcopy(nearest_city_df)
    fold_cities = train_data["City"].unique()

    fold_nearest_cities = []
    for (base_c, city1, city2, city3, city4, city5) in nearest_sort_cities:
        if city1 in fold_cities:
            nearest_city = city1
        elif city2 in fold_cities:
            nearest_city = city2
        elif city3 in fold_cities:
            nearest_city = city3
        elif city4 in fold_cities:
            nearest_city = city4
        elif city5 in fold_cities:
            nearest_city = city5
        fold_nearest_cities.append([base_c, nearest_city])
    fold_nearest_cities_df = pd.DataFrame(fold_nearest_cities, columns = ["City", "nearest_city"])

    # add city distance
    fold_nearest_cities_df["distance_km"] = -1
    for j in range(fold_nearest_cities_df.shape[0]):
        city, nearest_city = fold_nearest_cities_df.loc[j, ["City", "nearest_city"]]
        dis = nearest_cities[city][nearest_city]
        fold_nearest_cities_df.loc[j, "distance_km"] = dis.km

    target_en_fillna_ = target_en_fillna.rename(columns = {"City": "nearest_city", "pm25_mid": "nearest_pm25_mid"})
    fold_nearest_city_target_en = fold_nearest_cities_df.merge(target_en_fillna_, how = "left", on= "nearest_city")

    train_data = train_data.merge(fold_nearest_city_target_en, how = "left", on = ["City", "year", "month", "day"])
    valid_data = valid_data.merge(fold_nearest_city_target_en, how = "left", on = ["City", "year", "month", "day"])
    
# IDWによる計算(https://mf-atelier.sakura.ne.jp/mf-atelier2/a40/)
    part_target_en_fillna = target_en_fillna[["City", "year", "month", "day", "pm25_mid"]]
    for p in IDW_ps:
        part_target_en_fillna[f"IDW_p{p}_pm25_mid"] = np.nan
        for city in train_cities:
            sum_w = 0
            sum_w_u = 0
            for other_city, dis in nearest_cities[city].items():
                if not other_city in fold_cities:
                    continue
            # fold_nearest_cities_dfに含まれている都市との距離とpm25の値が欲しい
                w = 1 / (dis.km ** p)
                u = target_en_dic_bycity[other_city]
                u_nan_mask = np.nan_to_num(u)
                u_nan_flg = np.isnan(u)
                sum_w_u += w * u_nan_mask
                sum_w += w * (1 - u_nan_flg)
            part_target_en_fillna.loc[part_target_en_fillna["City"] == city, f"IDW_p{p}_pm25_mid"] = sum_w_u / sum_w
    part_target_en_fillna = part_target_en_fillna.drop(columns = ["pm25_mid"])
    train_data = train_data.merge(part_target_en_fillna, how = "left", on = ["City", "year", "month", "day"])
    valid_data = valid_data.merge(part_target_en_fillna, how = "left", on = ["City", "year", "month", "day"])

    # 距離に応じた近傍の都市のpm25_mid    
    for dis in [100, 300, 500, 1000]:
        train_data[f"dis{dis}km_pm25_mid"] = np.nan
        valid_data[f"dis{dis}km_pm25_mid"] = np.nan
        train_data.loc[train_data["distance_km"] <= dis, f"dis{dis}km_pm25_mid"] = train_data.loc[train_data["distance_km"] <= dis, "nearest_pm25_mid"]
        valid_data.loc[valid_data["distance_km"] <= dis, f"dis{dis}km_pm25_mid"] = valid_data.loc[valid_data["distance_km"] <= dis, "nearest_pm25_mid"]

    # 日付をずらす
    train_valid_data = pd.concat([train_data, valid_data])
    days_shift_df = city_year_month_day.merge(train_valid_data[day_columns + ["City", "year", "month", "day"]], on = ["City", "year", "month", "day"], how = "left")
    for day in days: 
        for day_column in day_columns:
            if day == 0:
                continue
            days_shift_df[f"{day}d_{day_column}"] = days_shift_df.groupby("City").shift(day)[day_column]

    days_shift_df = days_shift_df.drop(columns = day_columns)

    train_data = train_data.merge(days_shift_df, how = "left",  on = ["City", "year", "month", "day"])
    valid_data = valid_data.merge(days_shift_df, how = "left",  on = ["City", "year", "month", "day"])

    train_data = train_data.merge(oof_df_[["id", "pseude_pm25_mid"]], how = "left",  on = ["id"])
    valid_data = valid_data.merge(oof_df_[["id", "pseude_pm25_mid"]], how = "left",  on = ["id"])

    # test
    if i == 0:
        test_nearest_cities = []
        for (base_c, city1, city2, city3, city4, city5) in nearest_sort_cities:
            nearest_city = city1
            test_nearest_cities.append([base_c, nearest_city])
        test_nearest_cities_df = pd.DataFrame(test_nearest_cities, columns = ["City", "nearest_city"])
        
        for j in range(test_nearest_cities_df.shape[0]):
            city, nearest_city = test_nearest_cities_df.loc[j, ["City", "nearest_city"]]
            dis = nearest_cities[city][nearest_city]
            test_nearest_cities_df.loc[j, "distance_km"] = dis.km

        test_nearest_city_target_en = test_nearest_cities_df.merge(target_en_fillna_, how="left", on = "nearest_city")
        test_df_ = test_df_.merge(test_nearest_city_target_en, how="left", on=["City", "year", "month", "day"])

        fortest_target_en_fillna = target_en_fillna[["City", "year", "month", "day", "pm25_mid"]]
        for p in IDW_ps:
            fortest_target_en_fillna[f"IDW_p{p}_pm25_mid"] = np.nan
            for city in all_cities:
                sum_w = 0
                sum_w_u = 0
                for other_city, dis in nearest_cities[city].items():
                    if not other_city in train_cities:
                        continue
                # fold_nearest_cities_dfに含まれている都市との距離とpm25の値が欲しい
                    w = 1 / (dis.km ** p)
                    u = target_en_dic_bycity[other_city]
                    u_nan_mask = np.nan_to_num(u)
                    u_nan_flg = np.isnan(u)
                    sum_w_u += w * u_nan_mask
                    sum_w += w * (1 - u_nan_flg)
                fortest_target_en_fillna.loc[fortest_target_en_fillna["City"] == city, f"IDW_p{p}_pm25_mid"] = sum_w_u / sum_w
        fortest_target_en_fillna = fortest_target_en_fillna.drop(columns = ["pm25_mid"])
        test_df_ = test_df_.merge(fortest_target_en_fillna, how = "left", on = ["City", "year", "month", "day"])    
        for dis in [100, 300, 500, 1000]:
            test_df_[f"dis{dis}km_pm25_mid"] = np.nan
            test_df_.loc[test_df_["distance_km"] <= dis, f"dis{dis}km_pm25_mid"] = test_df_.loc[test_df_["distance_km"] <= dis, "nearest_pm25_mid"]

        days_shift_df = city_year_month_day.merge(test_df_[day_columns + ["City", "year", "month", "day"]], on = ["City", "year", "month", "day"], how = "left")
        for day in days:
            for day_column in day_columns:
                if day == 0:
                    continue
                days_shift_df[f"{day}d_{day_column}"] = days_shift_df.groupby("City").shift(day)[day_column]
        days_shift_df = days_shift_df.drop(columns = day_columns)
        test_df_ = test_df_.merge(days_shift_df, how = "left",  on = ["City", "year", "month", "day"])
        test_df_ = test_df_.merge(submit_df_[["id", "pseude_pm25_mid"]], how = "left",  on = ["id"])

        test_df__ = copy.deepcopy(test_df_)

    train_data__ = copy.deepcopy(train_data)
    valid_data__ = copy.deepcopy(valid_data)
    for c in cat_cols:
        le = LabelEncoder()
        le.fit(pd.concat([train_data, valid_data, test_df_])[c])
        train_data__[c] = le.transform(train_data[c])
        valid_data__[c] = le.transform(valid_data[c])
        if i == 0:
            test_df__[c] = le.transform(test_df_[c])

    break

# train_oof = train_df.merge(oof_df[["id", "oof"]], on = "id", how = "left")
# Out:
#   0%|          | 0/302 [00:00<?, ?it/s]
# -----FOLD 1/5-----
# train_data nums: 156755, valid_data nums: 39186
# 192

# %%
lgb_train = lgb.Dataset(train_data__[use_cols], train_data__[target_cols])
lgb_eval = lgb.Dataset(valid_data__[use_cols], valid_data__[target_cols])

def objective(trial):
    params= {
            'boosting': "gbdt",
            'objective': 'rmse',
            'metric': 'rmse',
            'learning_rate': trial.suggest_uniform('learning_rate', 0.001, 0.007),
            "max_depth": trial.suggest_int("max_depth", 8, 32),
            "num_leaves": trial.suggest_int("num_leaves", 2, 64),
            'subsample': 0.7,
            'subsample_freq': 1,
            "min_data_in_leaf": 30,
            "device": "gpu",  
            "seed":2022,
    }

    train_params = {
        "num_boost_round": 50000,
        "callbacks": [
                    lgb.early_stopping(stopping_rounds= 500, verbose=True),
                    lgb.log_evaluation(period = 5000)
        ]
    }
    model = get_tree_model("lgb")()
    gbm = lgb.train(params, lgb_train, valid_sets=lgb_eval, **train_params)
    preds = gbm.predict(valid_data__[use_cols])

    accuracy = np.sqrt(mean_squared_error(valid_data[target_cols], preds))
    return accuracy

# %%
study = optuna.create_study(direction = "minimize")
study.optimize(objective, n_trials = 50)
# Out:
# [I 2022-05-19 03:08:02,179] A new study created in memory with name: no-name-e8ce57a6-da3c-4ebe-9aa8-b4f7ef746fb9
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025228 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.9375
# [10000]	valid_0's rmse: 23.786
# [15000]	valid_0's rmse: 23.7085
# [20000]	valid_0's rmse: 23.6585
# Early stopping, best iteration is:
# [19646]	valid_0's rmse: 23.6575
# [I 2022-05-19 03:19:58,406] Trial 0 finished with value: 23.657459473383074 and parameters: {'learning_rate': 0.004008504805467068, 'max_depth': 29, 'num_leaves': 43}. Best is trial 0 with value: 23.657459473383074.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025316 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 24.2618
# [10000]	valid_0's rmse: 23.9928
# [15000]	valid_0's rmse: 23.8881
# [20000]	valid_0's rmse: 23.8246
# [25000]	valid_0's rmse: 23.7734
# [30000]	valid_0's rmse: 23.7323
# Early stopping, best iteration is:
# [33164]	valid_0's rmse: 23.7078
# [I 2022-05-19 03:40:07,458] Trial 1 finished with value: 23.7077692495801 and parameters: {'learning_rate': 0.0018119217572234929, 'max_depth': 15, 'num_leaves': 43}. Best is trial 0 with value: 23.657459473383074.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025870 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 24.2054
# [10000]	valid_0's rmse: 23.9761
# [15000]	valid_0's rmse: 23.8537
# [20000]	valid_0's rmse: 23.784
# Early stopping, best iteration is:
# [21250]	valid_0's rmse: 23.7667
# [I 2022-05-19 03:45:55,608] Trial 2 finished with value: 23.766661668227055 and parameters: {'learning_rate': 0.004760605086246304, 'max_depth': 23, 'num_leaves': 15}. Best is trial 0 with value: 23.657459473383074.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.024650 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 24.2447
# [10000]	valid_0's rmse: 23.9995
# [15000]	valid_0's rmse: 23.8804
# Early stopping, best iteration is:
# [17984]	valid_0's rmse: 23.8283
# [I 2022-05-19 03:51:46,176] Trial 3 finished with value: 23.8283110579188 and parameters: {'learning_rate': 0.004085210448921696, 'max_depth': 12, 'num_leaves': 19}. Best is trial 0 with value: 23.657459473383074.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025217 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.7561
# [10000]	valid_0's rmse: 23.5973
# [15000]	valid_0's rmse: 23.5196
# [20000]	valid_0's rmse: 23.4819
# Early stopping, best iteration is:
# [21188]	valid_0's rmse: 23.4775
# [I 2022-05-19 04:07:16,735] Trial 4 finished with value: 23.477535540657488 and parameters: {'learning_rate': 0.004913149687225274, 'max_depth': 17, 'num_leaves': 58}. Best is trial 4 with value: 23.477535540657488.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025000 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.896
# [10000]	valid_0's rmse: 23.7211
# [15000]	valid_0's rmse: 23.6438
# [20000]	valid_0's rmse: 23.5765
# Early stopping, best iteration is:
# [20432]	valid_0's rmse: 23.5712
# [I 2022-05-19 04:18:30,407] Trial 5 finished with value: 23.571246443749025 and parameters: {'learning_rate': 0.0044073497578258096, 'max_depth': 10, 'num_leaves': 39}. Best is trial 4 with value: 23.477535540657488.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.026422 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 24.1827
# [10000]	valid_0's rmse: 23.9429
# [15000]	valid_0's rmse: 23.8303
# [20000]	valid_0's rmse: 23.7547
# Early stopping, best iteration is:
# [21518]	valid_0's rmse: 23.7339
# [I 2022-05-19 04:24:42,279] Trial 6 finished with value: 23.73392749717469 and parameters: {'learning_rate': 0.005223455300598924, 'max_depth': 17, 'num_leaves': 15}. Best is trial 4 with value: 23.477535540657488.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.026859 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.8398
# [10000]	valid_0's rmse: 23.674
# [15000]	valid_0's rmse: 23.6009
# Early stopping, best iteration is:
# [16956]	valid_0's rmse: 23.5823
# [I 2022-05-19 04:38:47,060] Trial 7 finished with value: 23.582288981603313 and parameters: {'learning_rate': 0.003751772408453062, 'max_depth': 17, 'num_leaves': 61}. Best is trial 4 with value: 23.477535540657488.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.035539 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 24.1715
# [10000]	valid_0's rmse: 23.9542
# [15000]	valid_0's rmse: 23.8366
# Early stopping, best iteration is:
# [18656]	valid_0's rmse: 23.7893
# [I 2022-05-19 04:47:48,249] Trial 8 finished with value: 23.789301221269238 and parameters: {'learning_rate': 0.003183203284284533, 'max_depth': 29, 'num_leaves': 30}. Best is trial 4 with value: 23.477535540657488.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025748 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 24.5729
# [10000]	valid_0's rmse: 24.2104
# [15000]	valid_0's rmse: 24.0637
# [20000]	valid_0's rmse: 23.9774
# [25000]	valid_0's rmse: 23.9148
# Early stopping, best iteration is:
# [25794]	valid_0's rmse: 23.9069
# [I 2022-05-19 04:54:24,446] Trial 9 finished with value: 23.906888917817426 and parameters: {'learning_rate': 0.002767537015806609, 'max_depth': 28, 'num_leaves': 12}. Best is trial 4 with value: 23.477535540657488.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.027132 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.6392
# [10000]	valid_0's rmse: 23.5199
# [15000]	valid_0's rmse: 23.4551
# Early stopping, best iteration is:
# [15675]	valid_0's rmse: 23.4459
# [I 2022-05-19 05:07:12,277] Trial 10 finished with value: 23.445867100824675 and parameters: {'learning_rate': 0.00684489881190499, 'max_depth': 23, 'num_leaves': 64}. Best is trial 10 with value: 23.445867100824675.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.029355 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.6524
# Early stopping, best iteration is:
# [9468]	valid_0's rmse: 23.5279
# [I 2022-05-19 05:14:59,541] Trial 11 finished with value: 23.527924633032235 and parameters: {'learning_rate': 0.00694443413549631, 'max_depth': 23, 'num_leaves': 62}. Best is trial 10 with value: 23.445867100824675.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025101 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.7002
# [10000]	valid_0's rmse: 23.5547
# Early stopping, best iteration is:
# [13742]	valid_0's rmse: 23.4927
# [I 2022-05-19 05:24:39,545] Trial 12 finished with value: 23.492653754934683 and parameters: {'learning_rate': 0.006437177130190214, 'max_depth': 21, 'num_leaves': 53}. Best is trial 10 with value: 23.445867100824675.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025084 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.7852
# [10000]	valid_0's rmse: 23.6314
# [15000]	valid_0's rmse: 23.5538
# Early stopping, best iteration is:
# [15674]	valid_0's rmse: 23.5449
# [I 2022-05-19 05:35:46,011] Trial 13 finished with value: 23.54490396111227 and parameters: {'learning_rate': 0.005824789980283101, 'max_depth': 25, 'num_leaves': 53}. Best is trial 10 with value: 23.445867100824675.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025504 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.7588
# [10000]	valid_0's rmse: 23.5913
# [15000]	valid_0's rmse: 23.5181
# [20000]	valid_0's rmse: 23.4828
# Early stopping, best iteration is:
# [20209]	valid_0's rmse: 23.4809
# [I 2022-05-19 05:49:43,682] Trial 14 finished with value: 23.480934295914487 and parameters: {'learning_rate': 0.00574898229602124, 'max_depth': 18, 'num_leaves': 53}. Best is trial 10 with value: 23.445867100824675.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.026279 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.6644
# [10000]	valid_0's rmse: 23.5003
# [15000]	valid_0's rmse: 23.4454
# Early stopping, best iteration is:
# [14890]	valid_0's rmse: 23.4421
# [I 2022-05-19 06:01:53,398] Trial 15 finished with value: 23.442088513508367 and parameters: {'learning_rate': 0.006990480376555733, 'max_depth': 32, 'num_leaves': 62}. Best is trial 15 with value: 23.442088513508367.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.036475 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 25.2416
# [10000]	valid_0's rmse: 24.6471
# [15000]	valid_0's rmse: 24.3784
# [20000]	valid_0's rmse: 24.226
# [25000]	valid_0's rmse: 24.1207
# Early stopping, best iteration is:
# [26241]	valid_0's rmse: 24.1035
# [I 2022-05-19 06:04:48,294] Trial 16 finished with value: 24.103507603487657 and parameters: {'learning_rate': 0.0066892082784406415, 'max_depth': 27, 'num_leaves': 3}. Best is trial 15 with value: 23.442088513508367.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025280 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.7551
# Early stopping, best iteration is:
# [8353]	valid_0's rmse: 23.6258
# [I 2022-05-19 06:10:30,078] Trial 17 finished with value: 23.625837604869783 and parameters: {'learning_rate': 0.006041269730390155, 'max_depth': 32, 'num_leaves': 48}. Best is trial 15 with value: 23.442088513508367.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025389 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 24.6811
# [10000]	valid_0's rmse: 24.2458
# [15000]	valid_0's rmse: 24.0942
# [20000]	valid_0's rmse: 24.0014
# [25000]	valid_0's rmse: 23.9339
# [30000]	valid_0's rmse: 23.8925
# [35000]	valid_0's rmse: 23.8559
# [40000]	valid_0's rmse: 23.8198
# [45000]	valid_0's rmse: 23.7908
# Early stopping, best iteration is:
# [45297]	valid_0's rmse: 23.7884
# [I 2022-05-19 06:32:58,368] Trial 18 finished with value: 23.788362607421988 and parameters: {'learning_rate': 0.0012378755397954157, 'max_depth': 31, 'num_leaves': 32}. Best is trial 15 with value: 23.442088513508367.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.026419 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.6218
# [10000]	valid_0's rmse: 23.5085
# Early stopping, best iteration is:
# [10768]	valid_0's rmse: 23.5017
# [I 2022-05-19 06:41:42,085] Trial 19 finished with value: 23.501725644428944 and parameters: {'learning_rate': 0.006984705608483586, 'max_depth': 25, 'num_leaves': 63}. Best is trial 15 with value: 23.442088513508367.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025393 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.7293
# [10000]	valid_0's rmse: 23.5858
# [15000]	valid_0's rmse: 23.531
# Early stopping, best iteration is:
# [14619]	valid_0's rmse: 23.5283
# [I 2022-05-19 06:52:25,315] Trial 20 finished with value: 23.52830180925724 and parameters: {'learning_rate': 0.005486742240691924, 'max_depth': 21, 'num_leaves': 56}. Best is trial 15 with value: 23.442088513508367.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025451 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.6055
# [10000]	valid_0's rmse: 23.4596
# Early stopping, best iteration is:
# [13477]	valid_0's rmse: 23.4238
# [I 2022-05-19 07:03:13,817] Trial 21 finished with value: 23.423796927574383 and parameters: {'learning_rate': 0.006227713518081605, 'max_depth': 14, 'num_leaves': 64}. Best is trial 21 with value: 23.423796927574383.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.026379 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5000]	valid_0's rmse: 23.5951
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [8964]	valid_0's rmse: 23.4474
# [I 2022-05-19 07:09:59,629] Trial 22 finished with value: 23.44741532072059 and parameters: {'learning_rate': 0.006293362775363529, 'max_depth': 8, 'num_leaves': 64}. Best is trial 21 with value: 23.423796927574383.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025183 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.7442
# [10000]	valid_0's rmse: 23.5914
# [15000]	valid_0's rmse: 23.5018
# Early stopping, best iteration is:
# [16888]	valid_0's rmse: 23.4859
# [I 2022-05-19 07:20:25,082] Trial 23 finished with value: 23.485916517373933 and parameters: {'learning_rate': 0.006335147265945823, 'max_depth': 12, 'num_leaves': 48}. Best is trial 21 with value: 23.423796927574383.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025361 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.6417
# [10000]	valid_0's rmse: 23.4816
# [15000]	valid_0's rmse: 23.4174
# Early stopping, best iteration is:
# [19445]	valid_0's rmse: 23.3876
# [I 2022-05-19 07:34:32,786] Trial 24 finished with value: 23.38760724982968 and parameters: {'learning_rate': 0.006541049736017258, 'max_depth': 14, 'num_leaves': 58}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.029682 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.7222
# Early stopping, best iteration is:
# [8441]	valid_0's rmse: 23.5941
# [I 2022-05-19 07:41:09,694] Trial 25 finished with value: 23.594055033841162 and parameters: {'learning_rate': 0.0053198037016550246, 'max_depth': 14, 'num_leaves': 57}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.026359 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 24.0518
# [10000]	valid_0's rmse: 23.8805
# [15000]	valid_0's rmse: 23.7586
# [20000]	valid_0's rmse: 23.6851
# Early stopping, best iteration is:
# [20861]	valid_0's rmse: 23.6796
# [I 2022-05-19 07:49:34,411] Trial 26 finished with value: 23.679590992488826 and parameters: {'learning_rate': 0.00598543162661151, 'max_depth': 13, 'num_leaves': 26}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025439 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.6847
# [10000]	valid_0's rmse: 23.5402
# [15000]	valid_0's rmse: 23.4511
# Early stopping, best iteration is:
# [18958]	valid_0's rmse: 23.4112
# [I 2022-05-19 08:01:10,966] Trial 27 finished with value: 23.411178725637576 and parameters: {'learning_rate': 0.006433649296340787, 'max_depth': 10, 'num_leaves': 50}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.026086 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.8351
# [10000]	valid_0's rmse: 23.6649
# [15000]	valid_0's rmse: 23.5773
# Early stopping, best iteration is:
# [15822]	valid_0's rmse: 23.5701
# [I 2022-05-19 08:10:42,931] Trial 28 finished with value: 23.570098350805853 and parameters: {'learning_rate': 0.005561460452810177, 'max_depth': 8, 'num_leaves': 48}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.031418 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.8863
# [10000]	valid_0's rmse: 23.7146
# [15000]	valid_0's rmse: 23.6199
# [20000]	valid_0's rmse: 23.5587
# Early stopping, best iteration is:
# [22475]	valid_0's rmse: 23.5409
# [I 2022-05-19 08:22:44,809] Trial 29 finished with value: 23.54086842489389 and parameters: {'learning_rate': 0.004798059996878392, 'max_depth': 10, 'num_leaves': 39}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.026731 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.7801
# [10000]	valid_0's rmse: 23.6049
# [15000]	valid_0's rmse: 23.5281
# [20000]	valid_0's rmse: 23.481
# Early stopping, best iteration is:
# [22311]	valid_0's rmse: 23.4669
# [I 2022-05-19 08:35:13,109] Trial 30 finished with value: 23.466856179587392 and parameters: {'learning_rate': 0.0064300948899788145, 'max_depth': 10, 'num_leaves': 43}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.034272 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.6333
# [10000]	valid_0's rmse: 23.4863
# Early stopping, best iteration is:
# [13724]	valid_0's rmse: 23.4339
# [I 2022-05-19 08:45:34,459] Trial 31 finished with value: 23.433941499722238 and parameters: {'learning_rate': 0.0065664821614657915, 'max_depth': 19, 'num_leaves': 58}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.024641 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.6611
# [10000]	valid_0's rmse: 23.496
# [15000]	valid_0's rmse: 23.4243
# Early stopping, best iteration is:
# [15611]	valid_0's rmse: 23.419
# [I 2022-05-19 08:57:06,653] Trial 32 finished with value: 23.4190349283765 and parameters: {'learning_rate': 0.006029143522182452, 'max_depth': 19, 'num_leaves': 58}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025772 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.7253
# [10000]	valid_0's rmse: 23.5651
# [15000]	valid_0's rmse: 23.4698
# [20000]	valid_0's rmse: 23.4294
# Early stopping, best iteration is:
# [21190]	valid_0's rmse: 23.4253
# [I 2022-05-19 09:10:57,020] Trial 33 finished with value: 23.425309840859647 and parameters: {'learning_rate': 0.006075302818958672, 'max_depth': 15, 'num_leaves': 51}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.026164 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.8631
# [10000]	valid_0's rmse: 23.698
# [15000]	valid_0's rmse: 23.6135
# Early stopping, best iteration is:
# [15601]	valid_0's rmse: 23.6035
# [I 2022-05-19 09:20:06,346] Trial 34 finished with value: 23.603450139130434 and parameters: {'learning_rate': 0.005029167463366116, 'max_depth': 15, 'num_leaves': 43}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.028777 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.7448
# Early stopping, best iteration is:
# [7600]	valid_0's rmse: 23.6318
# [I 2022-05-19 09:25:54,348] Trial 35 finished with value: 23.63182959744681 and parameters: {'learning_rate': 0.005703257461056771, 'max_depth': 11, 'num_leaves': 57}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.032373 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.9549
# [10000]	valid_0's rmse: 23.7874
# Early stopping, best iteration is:
# [13500]	valid_0's rmse: 23.7013
# [I 2022-05-19 09:33:21,228] Trial 36 finished with value: 23.70134731450682 and parameters: {'learning_rate': 0.004304082163644786, 'max_depth': 15, 'num_leaves': 38}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025379 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.6629
# [10000]	valid_0's rmse: 23.5078
# Early stopping, best iteration is:
# [9789]	valid_0's rmse: 23.5058
# [I 2022-05-19 09:40:56,367] Trial 37 finished with value: 23.505822677984053 and parameters: {'learning_rate': 0.006144901857449977, 'max_depth': 13, 'num_leaves': 59}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025826 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.827
# [10000]	valid_0's rmse: 23.6681
# [15000]	valid_0's rmse: 23.5687
# [20000]	valid_0's rmse: 23.5178
# [25000]	valid_0's rmse: 23.4859
# Early stopping, best iteration is:
# [25039]	valid_0's rmse: 23.4853
# [I 2022-05-19 09:57:24,643] Trial 38 finished with value: 23.485326422706116 and parameters: {'learning_rate': 0.004557800415840708, 'max_depth': 16, 'num_leaves': 50}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025635 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.8828
# [10000]	valid_0's rmse: 23.7345
# [15000]	valid_0's rmse: 23.6507
# Early stopping, best iteration is:
# [18635]	valid_0's rmse: 23.6132
# [I 2022-05-19 10:11:00,766] Trial 39 finished with value: 23.61324738392137 and parameters: {'learning_rate': 0.003647429400898676, 'max_depth': 19, 'num_leaves': 55}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.026628 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.6699
# [10000]	valid_0's rmse: 23.5062
# [15000]	valid_0's rmse: 23.4352
# Early stopping, best iteration is:
# [17063]	valid_0's rmse: 23.4206
# [I 2022-05-19 10:23:11,569] Trial 40 finished with value: 23.420637166023923 and parameters: {'learning_rate': 0.005206001409650346, 'max_depth': 9, 'num_leaves': 60}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025013 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5000]	valid_0's rmse: 23.7037
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10000]	valid_0's rmse: 23.5208
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15000]	valid_0's rmse: 23.4269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [18542]	valid_0's rmse: 23.4076
# [I 2022-05-19 10:35:56,778] Trial 41 finished with value: 23.40757289025359 and parameters: {'learning_rate': 0.005352233328445832, 'max_depth': 8, 'num_leaves': 59}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025362 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.6719
# Early stopping, best iteration is:
# [9444]	valid_0's rmse: 23.5067
# [I 2022-05-19 10:43:01,792] Trial 42 finished with value: 23.506673259601037 and parameters: {'learning_rate': 0.005506210472781122, 'max_depth': 9, 'num_leaves': 60}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025674 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.8376
# [10000]	valid_0's rmse: 23.6718
# [15000]	valid_0's rmse: 23.5723
# [20000]	valid_0's rmse: 23.525
# Early stopping, best iteration is:
# [20602]	valid_0's rmse: 23.5193
# [I 2022-05-19 10:55:08,775] Trial 43 finished with value: 23.519296969764863 and parameters: {'learning_rate': 0.00512185021732872, 'max_depth': 11, 'num_leaves': 45}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025256 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.952
# [10000]	valid_0's rmse: 23.7333
# [15000]	valid_0's rmse: 23.6459
# [20000]	valid_0's rmse: 23.5883
# [25000]	valid_0's rmse: 23.5462
# [30000]	valid_0's rmse: 23.5065
# Early stopping, best iteration is:
# [30245]	valid_0's rmse: 23.5038
# [I 2022-05-19 11:17:09,768] Trial 44 finished with value: 23.503784237863506 and parameters: {'learning_rate': 0.002300695221917042, 'max_depth': 9, 'num_leaves': 59}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025238 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.69
# [10000]	valid_0's rmse: 23.5431
# [15000]	valid_0's rmse: 23.4628
# Early stopping, best iteration is:
# [16860]	valid_0's rmse: 23.4478
# [I 2022-05-19 11:28:42,333] Trial 45 finished with value: 23.44776212138566 and parameters: {'learning_rate': 0.005252412817566066, 'max_depth': 12, 'num_leaves': 54}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025823 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.7063
# [10000]	valid_0's rmse: 23.526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [13918]	valid_0's rmse: 23.4677
# [I 2022-05-19 11:37:03,645] Trial 46 finished with value: 23.467725472669496 and parameters: {'learning_rate': 0.006639701154380951, 'max_depth': 8, 'num_leaves': 50}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025219 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.7062
# [10000]	valid_0's rmse: 23.558
# [15000]	valid_0's rmse: 23.4943
# Early stopping, best iteration is:
# [18639]	valid_0's rmse: 23.4692
# [I 2022-05-19 11:50:22,264] Trial 47 finished with value: 23.469186263077102 and parameters: {'learning_rate': 0.0057612907929516285, 'max_depth': 10, 'num_leaves': 60}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025680 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 23.7946
# [10000]	valid_0's rmse: 23.6236
# [15000]	valid_0's rmse: 23.5289
# Early stopping, best iteration is:
# [15662]	valid_0's rmse: 23.5229
# [I 2022-05-19 12:00:49,488] Trial 48 finished with value: 23.52287237397638 and parameters: {'learning_rate': 0.004672875327243808, 'max_depth': 11, 'num_leaves': 52}. Best is trial 24 with value: 23.38760724982968.
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025357 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 500 rounds
# [5000]	valid_0's rmse: 24.1669
# [10000]	valid_0's rmse: 23.9442
# [15000]	valid_0's rmse: 23.8443
# Early stopping, best iteration is:
# [18593]	valid_0's rmse: 23.7848
# [I 2022-05-19 12:07:24,095] Trial 49 finished with value: 23.784800824140902 and parameters: {'learning_rate': 0.004116334745748612, 'max_depth': 9, 'num_leaves': 22}. Best is trial 24 with value: 23.38760724982968.

# %%
print(study.best_params)
# Out:
# {'learning_rate': 0.006541049736017258, 'max_depth': 14, 'num_leaves': 58}

# %% [markdown]
# {'learning_rate': 0.006541049736017258, 'max_depth': 14, 'num_leaves': 58}
#
# 23.38760724982968.

# %% [markdown]
# #### Train

# %%
params= {
        'boosting': 'gbdt',
        'objective': 'rmse',
        'metric': 'rmse',
        'learning_rate': 0.00685,
        "max_depth": 16,
        "num_leaves": 64,
        'subsample': 0.7,
        'subsample_freq': 1,
        "min_data_in_leaf":30, 
        "device": "gpu",  
        "seed":2022,
}

train_params = {
    "num_boost_round": 20000,
    "callbacks": [
                  lgb.early_stopping(stopping_rounds= 1000, verbose=True),
                  lgb.log_evaluation(period = 500)
    ]
}

# %%
len(target_en_fillna.query(f'City == "{city1}"')["pm25_mid"].values)
# Out:
# 1095

# %%
models = []

train_df_ = copy.deepcopy(train_df1)
test_df_ = copy.deepcopy(test_df1)

oof_df = train_df_[["id"]]
oof_df["oof"] = -1

from lightgbm import early_stopping
from lightgbm import log_evaluation

target_en_dic_bycity = {}
part_target_en_fillna = target_en_fillna[["City", "year", "month", "day", "pm25_mid"]]
for city in tqdm(part_target_en_fillna["City"].unique()):
    target_en_dic_bycity[city] = part_target_en_fillna.query(f"City == '{city}'")["pm25_mid"].values 

for i in range(NUM_FOLDS):
    model = get_tree_model("lgb")()
    train_data = train_df_[train_df_["kfold"] != i].reset_index(drop = True)
    valid_data = train_df_[train_df_["kfold"] == i].reset_index(drop = True)
    print("-" * 5 + f"FOLD {i + 1}/{NUM_FOLDS}" + "-"*5)
    print(f"train_data nums: {len(train_data)}, valid_data nums: {len(valid_data)}")

    # fold内での最近傍を探す
    train_data = train_df_[train_df_["kfold"] != i].reset_index(drop = True)
    print(len(train_data["City"].unique()))

    # 同じfoldの中で最近傍な都市があった場合はその年のtarget_encodingを実施
    # nearest_city_fold_df = copy.deepcopy(nearest_city_df)
    fold_cities = train_data["City"].unique()

    fold_nearest_cities = []
    for (base_c, city1, city2, city3, city4, city5) in nearest_sort_cities:
        if city1 in fold_cities:
            nearest_city = city1
        elif city2 in fold_cities:
            nearest_city = city2
        elif city3 in fold_cities:
            nearest_city = city3
        elif city4 in fold_cities:
            nearest_city = city4
        elif city5 in fold_cities:
            nearest_city = city5
        fold_nearest_cities.append([base_c, nearest_city])
    fold_nearest_cities_df = pd.DataFrame(fold_nearest_cities, columns = ["City", "nearest_city"])

    # add city distance
    fold_nearest_cities_df["distance_km"] = -1
    for j in range(fold_nearest_cities_df.shape[0]):
        city, nearest_city = fold_nearest_cities_df.loc[j, ["City", "nearest_city"]]
        dis = nearest_cities[city][nearest_city]
        fold_nearest_cities_df.loc[j, "distance_km"] = dis.km

    target_en_fillna_ = target_en_fillna.rename(columns = {"City": "nearest_city", "pm25_mid": "nearest_pm25_mid"})
    fold_nearest_city_target_en = fold_nearest_cities_df.merge(target_en_fillna_, how = "left", on= "nearest_city")

    train_data = train_data.merge(fold_nearest_city_target_en, how = "left", on = ["City", "year", "month", "day"])
    valid_data = valid_data.merge(fold_nearest_city_target_en, how = "left", on = ["City", "year", "month", "day"])
    
# IDWによる計算(https://mf-atelier.sakura.ne.jp/mf-atelier2/a40/)
    part_target_en_fillna = target_en_fillna[["City", "year", "month", "day", "pm25_mid"]]
    for p in IDW_ps:
        part_target_en_fillna[f"IDW_p{p}_pm25_mid"] = np.nan
        for city in train_cities:
            sum_w = 0
            sum_w_u = 0
            for other_city, dis in nearest_cities[city].items():
                if not other_city in fold_cities:
                    continue
            # fold_nearest_cities_dfに含まれている都市との距離とpm25の値が欲しい
                w = 1 / (dis.km ** p)
                u = target_en_dic_bycity[other_city]
                u_nan_mask = np.nan_to_num(u)
                u_nan_flg = np.isnan(u)
                sum_w_u += w * u_nan_mask
                sum_w += w * (1 - u_nan_flg)
            part_target_en_fillna.loc[part_target_en_fillna["City"] == city, f"IDW_p{p}_pm25_mid"] = sum_w_u / sum_w
    part_target_en_fillna = part_target_en_fillna.drop(columns = ["pm25_mid"])
    train_data = train_data.merge(part_target_en_fillna, how = "left", on = ["City", "year", "month", "day"])
    valid_data = valid_data.merge(part_target_en_fillna, how = "left", on = ["City", "year", "month", "day"])

    # 距離に応じた近傍の都市のpm25_mid    
    for dis in [100, 300, 500, 1000]:
        train_data[f"dis{dis}km_pm25_mid"] = np.nan
        valid_data[f"dis{dis}km_pm25_mid"] = np.nan
        train_data.loc[train_data["distance_km"] <= dis, f"dis{dis}km_pm25_mid"] = train_data.loc[train_data["distance_km"] <= dis, "nearest_pm25_mid"]
        valid_data.loc[valid_data["distance_km"] <= dis, f"dis{dis}km_pm25_mid"] = valid_data.loc[valid_data["distance_km"] <= dis, "nearest_pm25_mid"]

    # 日付をずらす
    train_valid_data = pd.concat([train_data, valid_data])
    days_shift_df = city_year_month_day.merge(train_valid_data[day_columns + ["City", "year", "month", "day"]], on = ["City", "year", "month", "day"], how = "left")
    for day in days: 
        for day_column in day_columns:
            if day == 0:
                continue
            days_shift_df[f"{day}d_{day_column}"] = days_shift_df.groupby("City").shift(day)[day_column]

    days_shift_df = days_shift_df.drop(columns = day_columns)

    train_data = train_data.merge(days_shift_df, how = "left",  on = ["City", "year", "month", "day"])
    valid_data = valid_data.merge(days_shift_df, how = "left",  on = ["City", "year", "month", "day"])

    train_data = train_data.merge(oof_df_[["id", "pseude_pm25_mid"]], how = "left",  on = ["id"])
    valid_data = valid_data.merge(oof_df_[["id", "pseude_pm25_mid"]], how = "left",  on = ["id"])

    # test
    if i == 0:
        test_nearest_cities = []
        for (base_c, city1, city2, city3, city4, city5) in nearest_sort_cities:
            nearest_city = city1
            test_nearest_cities.append([base_c, nearest_city])
        test_nearest_cities_df = pd.DataFrame(test_nearest_cities, columns = ["City", "nearest_city"])
        
        for j in range(test_nearest_cities_df.shape[0]):
            city, nearest_city = test_nearest_cities_df.loc[j, ["City", "nearest_city"]]
            dis = nearest_cities[city][nearest_city]
            test_nearest_cities_df.loc[j, "distance_km"] = dis.km

        test_nearest_city_target_en = test_nearest_cities_df.merge(target_en_fillna_, how="left", on = "nearest_city")
        test_df_ = test_df_.merge(test_nearest_city_target_en, how="left", on=["City", "year", "month", "day"])

        fortest_target_en_fillna = target_en_fillna[["City", "year", "month", "day", "pm25_mid"]]
        for p in IDW_ps:
            fortest_target_en_fillna[f"IDW_p{p}_pm25_mid"] = np.nan
            for city in all_cities:
                sum_w = 0
                sum_w_u = 0
                for other_city, dis in nearest_cities[city].items():
                    if not other_city in train_cities:
                        continue
                # fold_nearest_cities_dfに含まれている都市との距離とpm25の値が欲しい
                    w = 1 / (dis.km ** p)
                    u = target_en_dic_bycity[other_city]
                    u_nan_mask = np.nan_to_num(u)
                    u_nan_flg = np.isnan(u)
                    sum_w_u += w * u_nan_mask
                    sum_w += w * (1 - u_nan_flg)
                fortest_target_en_fillna.loc[fortest_target_en_fillna["City"] == city, f"IDW_p{p}_pm25_mid"] = sum_w_u / sum_w
        fortest_target_en_fillna = fortest_target_en_fillna.drop(columns = ["pm25_mid"])
        test_df_ = test_df_.merge(fortest_target_en_fillna, how = "left", on = ["City", "year", "month", "day"])    
        for dis in [100, 300, 500, 1000]:
            test_df_[f"dis{dis}km_pm25_mid"] = np.nan
            test_df_.loc[test_df_["distance_km"] <= dis, f"dis{dis}km_pm25_mid"] = test_df_.loc[test_df_["distance_km"] <= dis, "nearest_pm25_mid"]

        days_shift_df = city_year_month_day.merge(test_df_[day_columns + ["City", "year", "month", "day"]], on = ["City", "year", "month", "day"], how = "left")
        for day in days:
            for day_column in day_columns:
                if day == 0:
                    continue
                days_shift_df[f"{day}d_{day_column}"] = days_shift_df.groupby("City").shift(day)[day_column]
        days_shift_df = days_shift_df.drop(columns = day_columns)
        test_df_ = test_df_.merge(days_shift_df, how = "left",  on = ["City", "year", "month", "day"])
        test_df_ = test_df_.merge(submit_df_[["id", "pseude_pm25_mid"]], how = "left",  on = ["id"])

        test_df__ = copy.deepcopy(test_df_)

    train_data__ = copy.deepcopy(train_data)
    valid_data__ = copy.deepcopy(valid_data)
    for c in cat_cols:
        le = LabelEncoder()
        le.fit(pd.concat([train_data, valid_data, test_df_])[c])
        train_data__[c] = le.transform(train_data[c])
        valid_data__[c] = le.transform(valid_data[c])
        if i == 0:
            test_df__[c] = le.transform(test_df_[c])

    model.train(
        params,
        train_params = train_params,
        X_train = train_data__[use_cols],
        y_train = train_data__[target_cols],
        X_val = valid_data__[use_cols],
        y_val = valid_data__[target_cols],
    )
    # save model
    with open(os.path.join(SAVE_DIR, f"model_{i}.pkl"), "wb") as p:
        pickle.dump(model, p)
    models.append(model)

    feature_importance = pd.DataFrame()
    feature_importance["feature"] = model.feature_names_
    feature_importance["importance"] = model.feature_importances_
    feature_importance["fold"] = i

    oof = model.predict(
        valid_data__[use_cols]
    )
    oof_df.loc[train_df["kfold"] == i, "oof"] = oof

    # break

train_oof = train_df.merge(oof_df[["id", "oof"]], on = "id", how = "left")
# Out:
#   0%|          | 0/302 [00:00<?, ?it/s]
# -----FOLD 1/5-----
# train_data nums: 156755, valid_data nums: 39186
# 192
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62424
# [LightGBM] [Info] Number of data points in the train set: 156755, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.024683 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.695189
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 20.1093	valid_1's rmse: 24.9652
# [1000]	training's rmse: 18.6961	valid_1's rmse: 24.182
# [1500]	training's rmse: 17.8931	valid_1's rmse: 23.9601
# [2000]	training's rmse: 17.2785	valid_1's rmse: 23.8485
# [2500]	training's rmse: 16.7596	valid_1's rmse: 23.7919
# [3000]	training's rmse: 16.3034	valid_1's rmse: 23.7313
# [3500]	training's rmse: 15.8875	valid_1's rmse: 23.68
# [4000]	training's rmse: 15.4985	valid_1's rmse: 23.6668
# [4500]	training's rmse: 15.1349	valid_1's rmse: 23.6441
# [5000]	training's rmse: 14.7973	valid_1's rmse: 23.6249
# [5500]	training's rmse: 14.475	valid_1's rmse: 23.6029
# [6000]	training's rmse: 14.167	valid_1's rmse: 23.578
# [6500]	training's rmse: 13.8714	valid_1's rmse: 23.5736
# [7000]	training's rmse: 13.5921	valid_1's rmse: 23.5555
# [7500]	training's rmse: 13.3194	valid_1's rmse: 23.5405
# [8000]	training's rmse: 13.0581	valid_1's rmse: 23.5283
# [8500]	training's rmse: 12.8041	valid_1's rmse: 23.5234
# [9000]	training's rmse: 12.5602	valid_1's rmse: 23.5055
# [9500]	training's rmse: 12.3235	valid_1's rmse: 23.4928
# [10000]	training's rmse: 12.0914	valid_1's rmse: 23.4884
# [10500]	training's rmse: 11.8687	valid_1's rmse: 23.48
# [11000]	training's rmse: 11.6503	valid_1's rmse: 23.4739
# [11500]	training's rmse: 11.4392	valid_1's rmse: 23.4678
# [12000]	training's rmse: 11.2327	valid_1's rmse: 23.4664
# [12500]	training's rmse: 11.0317	valid_1's rmse: 23.4582
# [13000]	training's rmse: 10.8354	valid_1's rmse: 23.4506
# [13500]	training's rmse: 10.6454	valid_1's rmse: 23.442
# [14000]	training's rmse: 10.4604	valid_1's rmse: 23.4401
# [14500]	training's rmse: 10.2801	valid_1's rmse: 23.441
# [15000]	training's rmse: 10.1032	valid_1's rmse: 23.437
# [15500]	training's rmse: 9.92868	valid_1's rmse: 23.434
# [16000]	training's rmse: 9.75968	valid_1's rmse: 23.4355
# [16500]	training's rmse: 9.59533	valid_1's rmse: 23.4312
# [17000]	training's rmse: 9.43351	valid_1's rmse: 23.4315
# [17500]	training's rmse: 9.27601	valid_1's rmse: 23.4313
# Early stopping, best iteration is:
# [16650]	training's rmse: 9.54578	valid_1's rmse: 23.4282
# -----FOLD 2/5-----
# train_data nums: 156758, valid_data nums: 39183
# 191
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62428
# [LightGBM] [Info] Number of data points in the train set: 156758, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.030902 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.317361
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 20.2832	valid_1's rmse: 21.2285
# [1000]	training's rmse: 18.8607	valid_1's rmse: 20.8524
# [1500]	training's rmse: 18.0397	valid_1's rmse: 20.6917
# [2000]	training's rmse: 17.4106	valid_1's rmse: 20.6246
# [2500]	training's rmse: 16.8786	valid_1's rmse: 20.5851
# [3000]	training's rmse: 16.4113	valid_1's rmse: 20.5578
# [3500]	training's rmse: 15.9874	valid_1's rmse: 20.5349
# [4000]	training's rmse: 15.5939	valid_1's rmse: 20.5095
# [4500]	training's rmse: 15.2269	valid_1's rmse: 20.4998
# [5000]	training's rmse: 14.8875	valid_1's rmse: 20.4885
# [5500]	training's rmse: 14.5616	valid_1's rmse: 20.4813
# [6000]	training's rmse: 14.2512	valid_1's rmse: 20.4756
# [6500]	training's rmse: 13.9556	valid_1's rmse: 20.4684
# [7000]	training's rmse: 13.6663	valid_1's rmse: 20.4633
# [7500]	training's rmse: 13.3916	valid_1's rmse: 20.4584
# [8000]	training's rmse: 13.1296	valid_1's rmse: 20.4522
# [8500]	training's rmse: 12.8749	valid_1's rmse: 20.451
# [9000]	training's rmse: 12.6254	valid_1's rmse: 20.4489
# [9500]	training's rmse: 12.387	valid_1's rmse: 20.4479
# [10000]	training's rmse: 12.1542	valid_1's rmse: 20.4503
# Early stopping, best iteration is:
# [9477]	training's rmse: 12.3978	valid_1's rmse: 20.4476
# -----FOLD 3/5-----
# train_data nums: 156760, valid_data nums: 39181
# 191
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62411
# [LightGBM] [Info] Number of data points in the train set: 156760, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.025140 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 60.259055
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 20.255	valid_1's rmse: 21.9626
# [1000]	training's rmse: 18.8084	valid_1's rmse: 21.3795
# [1500]	training's rmse: 17.9889	valid_1's rmse: 21.2057
# [2000]	training's rmse: 17.3639	valid_1's rmse: 21.1296
# [2500]	training's rmse: 16.844	valid_1's rmse: 21.0856
# [3000]	training's rmse: 16.381	valid_1's rmse: 21.0538
# [3500]	training's rmse: 15.9613	valid_1's rmse: 21.0273
# [4000]	training's rmse: 15.5731	valid_1's rmse: 21.0078
# [4500]	training's rmse: 15.2088	valid_1's rmse: 20.9991
# [5000]	training's rmse: 14.8641	valid_1's rmse: 20.9885
# [5500]	training's rmse: 14.5384	valid_1's rmse: 20.9787
# [6000]	training's rmse: 14.23	valid_1's rmse: 20.9716
# [6500]	training's rmse: 13.9343	valid_1's rmse: 20.9655
# [7000]	training's rmse: 13.6508	valid_1's rmse: 20.962
# [7500]	training's rmse: 13.3775	valid_1's rmse: 20.9566
# [8000]	training's rmse: 13.112	valid_1's rmse: 20.9536
# [8500]	training's rmse: 12.8599	valid_1's rmse: 20.9494
# [9000]	training's rmse: 12.6149	valid_1's rmse: 20.946
# [9500]	training's rmse: 12.3786	valid_1's rmse: 20.9431
# [10000]	training's rmse: 12.1482	valid_1's rmse: 20.9416
# [10500]	training's rmse: 11.9245	valid_1's rmse: 20.9398
# [11000]	training's rmse: 11.7051	valid_1's rmse: 20.9401
# [11500]	training's rmse: 11.4932	valid_1's rmse: 20.9388
# [12000]	training's rmse: 11.2888	valid_1's rmse: 20.9367
# [12500]	training's rmse: 11.0859	valid_1's rmse: 20.9359
# [13000]	training's rmse: 10.8893	valid_1's rmse: 20.9385
# Early stopping, best iteration is:
# [12464]	training's rmse: 11.1001	valid_1's rmse: 20.9355
# -----FOLD 4/5-----
# train_data nums: 156730, valid_data nums: 39211
# 191
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62421
# [LightGBM] [Info] Number of data points in the train set: 156730, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.46 MB) transferred to GPU in 0.024508 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 59.072621
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 20.1299	valid_1's rmse: 21.9731
# [1000]	training's rmse: 18.6541	valid_1's rmse: 21.3989
# [1500]	training's rmse: 17.8209	valid_1's rmse: 21.2233
# [2000]	training's rmse: 17.1932	valid_1's rmse: 21.1216
# [2500]	training's rmse: 16.6669	valid_1's rmse: 21.057
# [3000]	training's rmse: 16.2016	valid_1's rmse: 21.017
# [3500]	training's rmse: 15.7816	valid_1's rmse: 20.9826
# [4000]	training's rmse: 15.3929	valid_1's rmse: 20.9559
# [4500]	training's rmse: 15.0249	valid_1's rmse: 20.9334
# [5000]	training's rmse: 14.6803	valid_1's rmse: 20.9106
# [5500]	training's rmse: 14.3597	valid_1's rmse: 20.8938
# [6000]	training's rmse: 14.052	valid_1's rmse: 20.8812
# [6500]	training's rmse: 13.7567	valid_1's rmse: 20.873
# [7000]	training's rmse: 13.4729	valid_1's rmse: 20.8649
# [7500]	training's rmse: 13.2002	valid_1's rmse: 20.8546
# [8000]	training's rmse: 12.9389	valid_1's rmse: 20.8483
# [8500]	training's rmse: 12.6857	valid_1's rmse: 20.8445
# [9000]	training's rmse: 12.4419	valid_1's rmse: 20.8354
# [9500]	training's rmse: 12.2076	valid_1's rmse: 20.8336
# [10000]	training's rmse: 11.9783	valid_1's rmse: 20.8299
# [10500]	training's rmse: 11.7541	valid_1's rmse: 20.8259
# [11000]	training's rmse: 11.5381	valid_1's rmse: 20.8222
# [11500]	training's rmse: 11.3279	valid_1's rmse: 20.821
# [12000]	training's rmse: 11.1228	valid_1's rmse: 20.8192
# [12500]	training's rmse: 10.9251	valid_1's rmse: 20.8181
# [13000]	training's rmse: 10.7304	valid_1's rmse: 20.8144
# [13500]	training's rmse: 10.5412	valid_1's rmse: 20.8136
# [14000]	training's rmse: 10.3539	valid_1's rmse: 20.8106
# [14500]	training's rmse: 10.1736	valid_1's rmse: 20.8097
# [15000]	training's rmse: 9.99762	valid_1's rmse: 20.808
# [15500]	training's rmse: 9.82684	valid_1's rmse: 20.8073
# [16000]	training's rmse: 9.65961	valid_1's rmse: 20.8041
# [16500]	training's rmse: 9.49594	valid_1's rmse: 20.8041
# [17000]	training's rmse: 9.33633	valid_1's rmse: 20.8024
# [17500]	training's rmse: 9.17978	valid_1's rmse: 20.8022
# [18000]	training's rmse: 9.02653	valid_1's rmse: 20.8019
# Early stopping, best iteration is:
# [17098]	training's rmse: 9.305	valid_1's rmse: 20.8008
# -----FOLD 5/5-----
# train_data nums: 156761, valid_data nums: 39180
# 191
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 62417
# [LightGBM] [Info] Number of data points in the train set: 156761, number of used features: 261
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 261 dense feature groups (39.47 MB) transferred to GPU in 0.024672 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 58.656422
# Training until validation scores don't improve for 1000 rounds
# [500]	training's rmse: 20.0532	valid_1's rmse: 22.499
# [1000]	training's rmse: 18.6228	valid_1's rmse: 21.8799
# [1500]	training's rmse: 17.8121	valid_1's rmse: 21.7148
# [2000]	training's rmse: 17.1948	valid_1's rmse: 21.6194
# [2500]	training's rmse: 16.6703	valid_1's rmse: 21.5618
# [3000]	training's rmse: 16.2103	valid_1's rmse: 21.5221
# [3500]	training's rmse: 15.7934	valid_1's rmse: 21.4888
# [4000]	training's rmse: 15.4065	valid_1's rmse: 21.4651
# [4500]	training's rmse: 15.0453	valid_1's rmse: 21.4495
# [5000]	training's rmse: 14.7078	valid_1's rmse: 21.4305
# [5500]	training's rmse: 14.3839	valid_1's rmse: 21.4192
# [6000]	training's rmse: 14.0761	valid_1's rmse: 21.4093
# [6500]	training's rmse: 13.7785	valid_1's rmse: 21.394
# [7000]	training's rmse: 13.4983	valid_1's rmse: 21.3847
# [7500]	training's rmse: 13.2262	valid_1's rmse: 21.3759
# [8000]	training's rmse: 12.9652	valid_1's rmse: 21.3619
# [8500]	training's rmse: 12.7136	valid_1's rmse: 21.3547
# [9000]	training's rmse: 12.4708	valid_1's rmse: 21.3505
# [9500]	training's rmse: 12.2357	valid_1's rmse: 21.3401
# [10000]	training's rmse: 12.0064	valid_1's rmse: 21.337
# [10500]	training's rmse: 11.7862	valid_1's rmse: 21.3297
# [11000]	training's rmse: 11.5703	valid_1's rmse: 21.3253
# [11500]	training's rmse: 11.3606	valid_1's rmse: 21.3202
# [12000]	training's rmse: 11.1553	valid_1's rmse: 21.3175
# [12500]	training's rmse: 10.9573	valid_1's rmse: 21.3134
# [13000]	training's rmse: 10.7623	valid_1's rmse: 21.306
# [13500]	training's rmse: 10.5739	valid_1's rmse: 21.3021
# [14000]	training's rmse: 10.389	valid_1's rmse: 21.2989
# [14500]	training's rmse: 10.2112	valid_1's rmse: 21.296
# [15000]	training's rmse: 10.0365	valid_1's rmse: 21.294
# [15500]	training's rmse: 9.86401	valid_1's rmse: 21.2896
# [16000]	training's rmse: 9.6962	valid_1's rmse: 21.2876
# [16500]	training's rmse: 9.52987	valid_1's rmse: 21.2846
# [17000]	training's rmse: 9.3697	valid_1's rmse: 21.2828
# [17500]	training's rmse: 9.21258	valid_1's rmse: 21.2807
# [18000]	training's rmse: 9.05888	valid_1's rmse: 21.2795
# [18500]	training's rmse: 8.90785	valid_1's rmse: 21.2773
# [19000]	training's rmse: 8.75949	valid_1's rmse: 21.2754
# [19500]	training's rmse: 8.6138	valid_1's rmse: 21.2747
# [20000]	training's rmse: 8.47261	valid_1's rmse: 21.2714
# Did not meet early stopping. Best iteration is:
# [20000]	training's rmse: 8.47261	valid_1's rmse: 21.2714

# %%
viz_feature_importances(feature_importance)

# %%
a = np.clip(train_oof["oof"], 0, 450)
oof_score = np.sqrt(mean_squared_error(train_oof["pm25_mid"], a))
oof_score = format(oof_score, ".4f")
print(f"oof score: {oof_score}")

### d_cs_flg 21.89 ###
# Out:
# oof score: 21.4028

# %%
plt.hist(a, bins = 100, label = "predict")
plt.hist(train_oof["pm25_mid"], bins = 100, label = "target", alpha = 0.4)
plt.legend()
plt.show()

# %%
train_oof[["id","pm25_mid", "kfold", "oof"]].to_csv(os.path.join(OOF_DIR, "oof.csv"), index= False)

# %%
models = []
for i in range(NUM_FOLDS):
    with open(os.path.join(SAVE_DIR, f"model_{i}.pkl"), "rb") as p:
        model = pickle.load(p)
    models.append(model)

# %% [markdown]
# # predict

# %%
sum_predict = None
for model in models:
    predict = model.predict(
        test_df__[use_cols],
    )
    if sum_predict is None:
        sum_predict = predict
    else:
        sum_predict += predict

mean_predict = sum_predict / len(models)

# %%
print(len(mean_predict))
print(sample_df.shape)
print(test_df.shape)
# Out:
# 53509
# (53509, 2)
# (53509, 79)

# %%
sample_df.loc[:,"predict"] = np.clip(mean_predict, 0, 450)

# %%
sample_df.head()
# Out:
#        id     predict
# 0  195942   23.084366
# 1  195943   38.736841
# 2  195944   28.050010
# 3  195945   81.830621
# 4  195946  125.911558

# %%
sample_df.to_csv(os.path.join(SUB_DIR, "submission.csv"), index= False, header = False)

# %%
plt.hist(sample_df["predict"], bins = 100)
plt.show()

# %% [markdown]
# # submit

# %%
# !pip install signate > /dev/null
# !mkdir /root/.signate
# !cp /content/drive/MyDrive/signate/signate.json /root/.signate/signate.json
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0+zzzcolab20220506162203 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.9 which is incompatible.
# google-colab 1.0.0 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.

# %%
submission_file = os.path.join(SUB_DIR, "submission.csv")

# %%
comment = f"cv:{oof_score}_" + NOTEBOOK_NAME
comment
# Out:
# 'cv:21.4028_FP049-047'

# %% [markdown]
# # Submit

# %%
# !signate submit --competition-id=624 {submission_file} --note {comment}
# Out:
# You have successfully submitted your predictions.We will send you the submission result to your email address.

# %% [markdown]
# https://signate.jp/competitions/624/submissions

# %%
train_df[["City", "month", "pm25_mid"]].groupby(["City"]).describe()
# Out:
#               month                                                pm25_mid  \
#               count      mean       std  min  25%  50%   75%   max    count
# City
# Adapazarı     962.0  6.536383  3.356269  1.0  4.0  6.0   9.0  12.0    962.0
# Akita         978.0  6.527607  3.436774  1.0  4.0  6.0  10.0  12.0    978.0
# Albuquerque   917.0  6.679389  3.347707  1.0  4.0  7.0  10.0  12.0    917.0
# Andong       1011.0  6.608309  3.431492  1.0  4.0  7.0  10.0  12.0   1011.0
# Antakya       734.0  6.779292  3.200069  1.0  4.0  7.0  10.0  12.0    734.0
# ...             ...       ...       ...  ...  ...  ...   ...   ...      ...
# Zhuzhou      1059.0  6.610954  3.425374  1.0  4.0  7.0  10.0  12.0   1059.0
# Ürümqi       1033.0  6.642788  3.399611  1.0  4.0  7.0  10.0  12.0   1033.0
# İzmit        1013.0  6.553801  3.346923  1.0  4.0  7.0   9.0  12.0   1013.0
# Łódź          753.0  6.701195  3.238681  1.0  4.0  7.0   9.0  12.0    753.0
# Ōita         1057.0  6.621570  3.406298  1.0  4.0  7.0  10.0  12.0   1057.0
#
#                                                                          \
#                   mean        std     min       25%      50%        75%
# City
# Adapazarı    63.232831  35.395245   6.460  39.56125  55.6930   73.47475
# Akita        45.871133  25.458542   6.364  28.59525  40.5160   57.69725
# Albuquerque  42.865439  28.188976   7.736  22.31000  34.6630   57.03700
# Andong       59.396874  31.321281   6.600  37.84050  56.9850   69.45200
# Antakya      58.372569  41.630375   2.125  27.77575  53.3615   68.76650
# ...                ...        ...     ...       ...      ...        ...
# Zhuzhou      88.612365  43.927142  13.978  57.70200  75.5570  117.65500
# Ürümqi       81.598576  57.824517   9.867  47.92700  61.1770   92.37700
# İzmit        57.312069  29.037306   8.437  36.52600  54.2140   68.27100
# Łódź         61.209457  30.803510  11.894  40.49800  56.6420   73.41000
# Ōita         43.637044  20.845038   6.685  26.33400  40.2000   57.08000
#
#
#                  max
# City
# Adapazarı    181.469
# Akita        218.085
# Albuquerque  173.738
# Andong       191.630
# Antakya      286.452
# ...              ...
# Zhuzhou      236.485
# Ürümqi       406.464
# İzmit        176.600
# Łódź         216.704
# Ōita         135.558
#
# [239 rows x 16 columns]

# %%
test_df__[["IDW_p1_pm25_mid", "IDW_p2_pm25_mid"]]
# Out:
#        IDW_p1_pm25_mid  IDW_p2_pm25_mid
# 0            88.870173        76.286241
# 1           107.346374       124.842754
# 2            71.685499        62.255190
# 3           101.722169       127.673318
# 4            79.485027        68.063811
# ...                ...              ...
# 53504        69.574474        92.851303
# 53505        60.366933        57.617545
# 53506        70.186142        94.341643
# 53507        56.957340        49.047047
# 53508        66.775496        58.543084
#
# [53509 rows x 2 columns]

# %%
train_df[["co_cnt", "co_var", "co_min", "co_max", "co_mid"]]
# Out:
#         co_cnt  co_var  co_min  co_max  co_mid
# 0           38   0.850   0.749   2.633   2.590
# 1           47   1.208   2.594   4.828   3.181
# 2           17   0.248   1.190   2.200   1.197
# 3           63  24.186   4.586  14.802  11.044
# 4           47  10.011   4.689  11.100   8.681
# ...        ...     ...     ...     ...     ...
# 195936      12   0.090   0.694   1.301   0.995
# 195937      14   1.743   0.528   3.226   1.256
# 195938     171   5.293   1.975   6.639   6.627
# 195939      31   4.317   2.613   8.767   2.704
# 195940      26   0.003   0.069   0.184   0.120
#
# [195941 rows x 5 columns]

# %%
gen = np.random.default_rng()

rnd = gen.normal(size=38)

print(len(rnd), rnd.mean(), rnd.std())
# Out:
# 38 0.04426733107242086 0.8313547440517077

# %%
plt.hist(train_df[train_df["City"] == "Adapazarı"]["pm25_mid"], bins = 100)
# Out:
# (array([ 1.,  0.,  0.,  2.,  5.,  5., 10.,  9., 13., 17., 19., 22., 14.,
#         17., 22., 20., 25., 25., 16., 27., 19., 20., 23., 21., 27., 27.,
#         32., 38., 47., 41., 31., 34., 13., 22., 18.,  3., 13., 20., 11.,
#         15., 11.,  8.,  7.,  7.,  6.,  3.,  3.,  9.,  6.,  6.,  9.,  4.,
#          2.,  6.,  2.,  4.,  2.,  2.,  4.,  1.,  5.,  2.,  6.,  4.,  9.,
#          7.,  2.,  4.,  2.,  3.,  1.,  1.,  2.,  4.,  2.,  2.,  2.,  2.,
#          4.,  0.,  3.,  2.,  2.,  3.,  4.,  3.,  2.,  7.,  5.,  5.,  1.,
#          3.,  3.,  0.,  2.,  1.,  2.,  2.,  0.,  2.]),
#  array([  6.46   ,   8.21009,   9.96018,  11.71027,  13.46036,  15.21045,
#          16.96054,  18.71063,  20.46072,  22.21081,  23.9609 ,  25.71099,
#          27.46108,  29.21117,  30.96126,  32.71135,  34.46144,  36.21153,
#          37.96162,  39.71171,  41.4618 ,  43.21189,  44.96198,  46.71207,
#          48.46216,  50.21225,  51.96234,  53.71243,  55.46252,  57.21261,
#          58.9627 ,  60.71279,  62.46288,  64.21297,  65.96306,  67.71315,
#          69.46324,  71.21333,  72.96342,  74.71351,  76.4636 ,  78.21369,
#          79.96378,  81.71387,  83.46396,  85.21405,  86.96414,  88.71423,
#          90.46432,  92.21441,  93.9645 ,  95.71459,  97.46468,  99.21477,
#         100.96486, 102.71495, 104.46504, 106.21513, 107.96522, 109.71531,
#         111.4654 , 113.21549, 114.96558, 116.71567, 118.46576, 120.21585,
#         121.96594, 123.71603, 125.46612, 127.21621, 128.9663 , 130.71639,
#         132.46648, 134.21657, 135.96666, 137.71675, 139.46684, 141.21693,
#         142.96702, 144.71711, 146.4672 , 148.21729, 149.96738, 151.71747,
#         153.46756, 155.21765, 156.96774, 158.71783, 160.46792, 162.21801,
#         163.9681 , 165.71819, 167.46828, 169.21837, 170.96846, 172.71855,
#         174.46864, 176.21873, 177.96882, 179.71891, 181.469  ]),
#  <a list of 100 Patch objects>)
